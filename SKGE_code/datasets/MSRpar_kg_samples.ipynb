# %%
#!pip3 install openai
from openai import OpenAI
#from rich import print
import pickle

api_key = "xxxxxx"
client = OpenAI(api_key=api_key)

def get_answer(prompt:str):
    completion = client.chat.completions.create(model="gpt-4o-mini", 
                                                store=True,
                                                messages=[{"role": "user",   # system assistant user function tool developer
                                                       "content": prompt}]) 
    return(completion.choices[0].message.content)

# %% [markdown]
# #### Loading complete dataset and saving complete text sentences and scores

# %%
with open('sts_MSRpar_df.pkl', 'rb') as f:
    msrpar_df = pickle.load(f)      

msrpar_txt_pairs = []
for idx in range(len(msrpar_df)):
    msrpar_txt_pairs.append((msrpar_df.iloc[idx]['sentence1'], msrpar_df.iloc[idx]['sentence2']))

msrpar_scores = msrpar_df['score'].values.tolist()

with open('msrpar_txt.pkl', 'wb') as f:
    pickle.dump([msrpar_txt_pairs, msrpar_scores], f)

# %% [markdown]
# #### Loading a dataset chunk to be treated by AI

# %%
with open('sts_MSRpar_df.pkl', 'rb') as f:
    msrpar_df = pickle.load(f)      

msrpar_scores = msrpar_df['score'].values.tolist()
pairs = []

lte_inf = 240
lte_sup = 250
scores = msrpar_scores[lte_inf:lte_sup]

# for idx in range(len(msrpar_df)):
for idx in range(lte_inf, lte_sup):
    pairs.append(msrpar_df.iloc[idx]['sentence1'])
    pairs.append(msrpar_df.iloc[idx]['sentence2'])

print('msrpar_df length: ', len(msrpar_df))
print('scores lenght: ', len(scores))
print('pairs length:', len(pairs))

scores_250 = msrpar_scores[0:lte_sup]
print('Complete scores length: ', len(scores_250))
# Out:
# msrpar_df length:  250
# scores lenght:  10
# pairs length: 20
# Complete scores length:  250

# %%
for sent in pairs:
    print(sent + '<#>')
# Out:
# The commission estimated California lost $937 million to corporate tax shelters in 2001.<#>
# California's lost tax revenue was mostly due to international corporate tax shelters.<#>
# In other markets, U.S. Treasuries started off on Monday weaker, as stocks rose early.<#>
# In other markets, U.S. Treasuries inched higher as declining stocks raised the appeal of safe-haven debt.<#>
# The technology-laced Nasdaq Composite Index .IXIC was down 25.36 points, or 1.53 percent, at 1,628.26.<#>
# The broader Standard & Poor's 500 Index .SPX gave up 11.91 points, or 1.19 percent, at 986.60.<#>
# The Pentagon had hoped to retain control of the postwar effort, so the decision is a victory for Secretary of State Colin L. Powell.<#>
# The Pentagon had hoped to retain control of the postwar effort, so the decision was seen by some insiders as a victory for Powell and the State Department.<#>
# ...

# %%
msrpar_samples_ds = [
# Vivendi shares closed 1.9 percent at 15.80 euros in Paris after falling 3.6 percent on Monday.
([
    ("Vivendi shares", "closed", "1.9 percent"),
    ("Vivendi shares", "closed at", "15.80 euros"),
    ("Vivendi shares", "closed in", "Paris"),
    ("Vivendi shares", "closed after falling", "3.6 percent"),
    ("Vivendi shares", "closed on", "Monday")
],
# In New York, Vivendi shares were 1.4 percent down at $18.29.
[
    ("Vivendi shares", "were down", "1.4 percent"),
    ("Vivendi shares", "were down at", "$18.29"),
    ("Vivendi shares", "were in", "New York")
]),

# Bremer said one initiative is to launch a US$70 million nationwide program in the next two weeks to clean up 
# neighborhoods and build community projects.
([
    ("Bremer", "said about", "initiative"),
    ("initiative", "is to launch", "program"),
    ("program", "is", "nationwide"),
    ("program", "is to launch in", "next two weeks"),
    ("program", "has", "US$70 million"),
    ("program", "to clean up", "neighborhoods"),
    ("program", "to build", "community projects"),
],
# Bremer said he would launch a $70-million program in the next two weeks to clean up neighborhoods across Iraq and 
# build community projects, but gave no details.
[
    ("Bremer", "said about", "program"),
    ("program", "has", "$70-million"),
    ("program", "is to launch in", "next two weeks"),
    ("program", "to clean up", "neighborhoods"),
    ("neighborhoods", "are across", "Iraq"),
    ("program", "to build", "community projects"),
    ("Bremer", "gave", "no details")
]),

# Governor Gray Davis estimated yesterday that the fires could cost nearly $2 billion.
([
    ("Gray Davis", "is", "Governor"),
    ("Gray Davis", "estimated", "fires cost"),
    ("fires cost", "could be", "nearly $2 billion"),
    ("Gray Davis", "estimated", "yesterday"),
],
# State officials estimated the cost at nearly $2 billion.
[
    ("State officials", "estimated", "cost"),
    ("cost", "is at", "nearly $2 billion"),
]),

# The American Express Corp. has pledged at least $3 million of more than $5 million needed.
([
    ("American Express Corp.", "has pledged", "at least $3 million"),
    ("at least $3 million", "are part of", "more than $5 million"),
    ("more than $5 million", "are", "needed"),
],
# The city had requested federal funds, but withdrew that request when American Express pledged at least $3 million.
[
    ("city", "had", "request"),
    ("request", "was of", "federal funds"),
    ("city", "withdrew", "request"),
    ("request", "is withdrawn due to", "American Express"),
    ("American Express", "pledged", "at least $3 million"),
]),

# Claudette, the first hurricane of the Atlantic storm season, hit the mid-Texas coast July 15 with 85-mph wind.
([   
    ("Claudette", "is", "hurricane"), 
    ("Claudette", "is", "first of Atlantic storm season"), 
    ("Claudette", "hit", "mid-Texas coast"), 
    ("Claudette", "hit on", "July 15"), 
    ("Claudette", "hit with", "wind"),
    ("wind", "was", "85-mph")
],
# Claudette, the first hurricane of the Atlantic storm season, hit the mid-Texas coast July 15, classified as a 
# Category 1 hurricane with maximum sustained winds of 85 mph.
[
    ("Claudette", "is", "hurricane"), 
    ("Claudette", "is", "first of the Atlantic storm season"), 
    ("Claudette", "hit", "mid-Texas coast"), 
    ("Claudette", "hit on", "July 15"), 
    ("Claudette", "classified as", "Category 1 hurricane"), 
    ("Claudette", "hit with", "sustained winds"), 
    ("sustained winds", "were", "maximum of 85 mph"), 
]),
 
# Results from No. 2 U.S. soft drink maker PepsiCo Inc. (nyse: PEP - news - people) were likely to be in the spotlight.
([
    ("PepsiCo Inc.", "has", "results"),   
    ("PepsiCo Inc.", "is a", "soft drink maker"), 
    ("PepsiCo Inc.", "traded on", "NYSE: PEP"), 
    ("PepsiCo Inc.", "is", 'No. 2 U.S. soft drink maker'), 
    ('results', 'were likely to be in', 'spotlight')
],
# Wall Street was also waiting for aluminum maker Alcoa Inc. (nyse: PEP - news - people) to report earnings after the close.
[
    ("Wall Street", "was waiting for", "Alcoa Inc."), 
    ("Alcoa Inc.", "is a", "aluminum maker"), 
    ("Alcoa Inc.", "traded on", "NYSE:PEP"),
    ("Alcoa Inc.", "to report", "earnings"), 
    ("Alcoa Inc.", "to report", "after the close"),
]),

# Taylor's aides warn an abrupt departure could trigger more chaos, a view shared by many in Liberia and, 
# in private, even by mediators.
([
    ("Taylor's aides", "warn", "abrupt departure"), 
    ("abrupt departure", "could trigger", "more chaos"),
    ("more chaos", "is a", "view"),
    ("view", "is shared by", "many in Liberia"),
    ("view", "is shared by", "mediators in private")
],
# His aides warn an abrupt departure could trigger more bloodshed, a view shared by many in Liberia.
[
    ("His aides", "warn", "an abrupt departure"), 
    ("an abrupt departure", "could trigger", "more bloodshed"),
    ("more bloodshed", "is a", "view"),
    ("view", "is shared by", "many in Liberia")
]),

# But Odette is the first to form over the Caribbean Sea in December, the Center said.
([
    ("Center", "said about", "Odette"),
    ("Odette", "is", "first to form"),
    ("first to form", "is over", "Caribbean Sea"), 
    ("Odette", "forms in", "December"), 
],
# It is the first named storm to develop in the Caribbean in December.
[
    ("It", "is", "storm"),
    ("It", "is", "first named"),
    ("It", "developed in", "Caribbean"), 
    ("It", "developed in", "December"), 
]),
 
# The AFL-CIO is waiting until October to decide if it will endorse a candidate.
([
    ("The AFL-CIO", "waiting until", "October"), 
    ("The AFL-CIO", "waiting", "decision"),
    ("decision", "will be", "if it will endorse a candidate")
],
# The AFL-CIO announced Wednesday that it will decide in October whether to endorse a candidate before the primaries.
[
    ("The AFL-CIO", "announced", "Wednesday"), 
    ("The AFL-CIO", "announced about", "decision"),
    ("decision", "will be in", "October"),
    ("decision", "will be", "wether to endorse a candidate"),
    ("decision", "will be", "before the primaries")
]),
 
# It was developed with consultation from more than 300 leaders in academia, industry, government and the public.
([
    ("It", "was developed with", "consultation"),
    ("consultation", "was from", "leaders"),
    ("leaders", "were", "more than 300"),
    ("leaders", "were in", "academia"), 
    ("leaders", "were in", "industry"),
    ("leaders", "were in", "government"), 
    ("leaders", "were in", "the public")
],
# The plan, called The NIH Roadmap, was developed over 14 months with help from more than 300 consultants 
# in industry and academia.
[
    ("The NIH Roadmap", "is a", "plan"), 
    ("The NIH Roadmap", "was developed over", "14 months"), 
    ("The NIH Roadmap", "was developed with", "help"), 
    ("help", "was from", "consultants"),
    ("consultants", "were", "more than 300"),
    ("consultants", "were in", "industry"), 
    ("consultants", "were in", "academia")
]),

# Local police authorities are treating the explosion as a criminal matter and nothing has been ruled out.
([
    ("Local police authorities", "are treating", "explosion"), 
    ("explosion", "is treated as", "criminal matter"),
    ("Local police authorities", "has been ruled out", "nothing")
],
# Acting New Haven Police Chief Francisco Ortiz said police were treating the explosion as a criminal matter.
[
    ("Francisco Ortiz", "is", "Acting New Haven Police Chief"),
    ("Francisco Ortiz", "said about", "explosion"), 
    ("police", "were treating", "explosion"),
    ("explosion", "is treated as", "criminal matter")
]),
    
# Chiron already has nearly 20 percent acceptances from PowderJect's shareholders.
([
    ("Chiron", "has", "acceptances"),
    ("acceptances", "are", "nearly 20 percent"),
    ("nearly 20 percent", "is from", "PowderJect's shareholders")
],
# Chiron has acceptances from holders of nearly 20 percent of PowderJect shares.
[
    ("Chiron", "has", "acceptances"),
    ("acceptances", "are from", "holders"),
    ("holders", "have", "nearly 20 percent"),
    ("nearly 20 percent", "is from", "PowderJect shares")
]),

# 'We believe we are fully prepared to roll out the [touch-screen] machines for the 2004 presidential primary,’ 
# said Gilles W. Burger, State Board of Elections chairman.
([
    ("Gilles W. Burger", "is", "State Board of Elections chairman"),
    ("Gilles W. Burger", "said", "We believe we are fully prepared"),
    ("We believe we are fully prepared", "to roll out", "[touch-screen] machines"),
    ("[touch-screen] machines", "to roll out", "for the 2004 presidential primary")
],
# 'We believe we are fully prepared to roll out the revised Diebold machines,’ said Gilles W. Burger, 
# chairman of the Maryland State Board of Elections.
[
    ("Gilles W. Burger", "is", "chairman of the Maryland State Board of Elections"),
    ("Gilles W. Burger", "said", "We believe we are fully prepared"),
    ("We believe we are fully prepared", "to roll out", "revised Diebold machines")
]),

# Analysts expected earnings of 27 cents a share on revenue of $17.7 billion, Thomson First Call says.
([
    ("Thomson First Call", "says about", "Analysts"),
    ("Analysts", "expected", "earnings of 27 cents a share"),
    ("Analysts", "expected", "revenue of $17.7 billion"),
],
# Hewlett-Packard is putting in for a second-quarter profit of $659 million, or 29 cents a share, on revenue of $18 billion.
[
    ("Hewlett-Packard", "is putting in for", "profit of $659 million"), 
    ("profit of $659 million", "is for", "second-quarter"),
    ("Hewlett-Packard", "is putting in for", "29 cents a share"), 
    ("Hewlett-Packard", "is putting in for", "revenue of $18 billion")
]),

# Another was in serious condition at Northwest Medical Center in Springdale.
([
    ("Another", "was in", "serious condition"),
    ("Another", "was at", "Northwest Medical Center"),
    ("Northwest Medical Center", "is in", "Springdale")
],
# At Northwest Medical Center of Washington County in Springdale, one child is in serious condition.
[
    ("one child", "is in", "serious condition"),
    ("one child", "is at", "Northwest Medical Center"),
    ("Northwest Medical Center", "is of", "Washington County"),
    ("Northwest Medical Center", "is in", "Springdale")
]),

# Sean Harrigan, president of the California Public Employees' Retirement System, also suggested paring down 
# the NYSE's 27-member board, changing its composition and making it more accountable.
([
    ("Sean Harrigan", "is", "president of the California Public Employees' Retirement System"),
    ("Sean Harrigan", "suggested paring down", "NYSE's 27-member board"), 
    ("NYSE's 27-member board", "to change", "composition"), 
    ("NYSE's 27-member board", "to make", "more accountable")
],
# Sean Harrigan, president of the California Public Employees' Retirement System, also suggested paring 
# the NYSE's 27-member board and allotting more seats to investors outside the securities industry.
[
    ("Sean Harrigan", "is", "president of the California Public Employees' Retirement System"),
    ("Sean Harrigan", "suggested paring", "NYSE's 27-member board"), 
    ("NYSE's 27-member board", "to allot", "more seats to investors"),
    ("more seats to investors", "to be", "outside the securities industry")
]),

# The Swedish central bank was also meeting on Wednesday and widely expected to announce a cut on Thursday.
([
    ("The Swedish central bank", "was meeting on", "Wednesday"), 
    ("The Swedish central bank", "is widely expected to announce", "cut"),
    ("cut", "is widely expected to announce on", "Thursday")
],
# The Swedish central bank, also meeting on Wednesday, is widely expected to announce a cut on Thursday 
# of as much as half a percentage point.
[
    ("The Swedish central bank", "was meeting on", "Wednesday"),
    ("The Swedish central bank", "is widely expected to announce", "cut"),
    ("cut", "is widely expected to announce on", "Thursday"),
    ("cut", "is widely expected to announce of as", "much as half a percentage point") 
]),

# His 1996 Chevrolet Tahoe was found abandoned in a Virginia Beach, Va., parking lot June 25.
([
    ("His 1996 Chevrolet Tahoe", "was found", "abandoned"),
    ("His 1996 Chevrolet Tahoe", "was found in", "a parking lot"),
    ("His 1996 Chevrolet Tahoe", "was found in", "Virginia Beach"),
    ("Virginia Beach", "is in", "Va."),
    ("His 1996 Chevrolet Tahoe", "was found on", "June 25")
],
# His sport utility vehicle was found June 25, abandoned without its license plates in Virginia Beach, Va.
[
    ("His sport utility vehicle", "was found on", "June 25"), 
    ("His sport utility vehicle", "was found", "abandoned"),
    ("His sport utility vehicle", "was found", "without its license plates"),
    ("His sport utility vehicle", "was found in", "Virginia Beach"),
    ("Virginia Beach", "is in", "Va.")
]),

# Heatley was sixth in the league in goals last season with 41 and ninth in points with 89.
([
    ("Heatley", "was", "sixth in the league in goals"),
    ("Heatley's goals", "were", "41"),
    ("Heatley's goals", "were in", "last season"), 
    ("Heatley", "was", "ninth in the league in points"),
    ("Heatley's points", "were", "89"),
    ("Heatley's points", "were in", "last season")
],
# Heatley led Atlanta in scoring last season with a team-record 41 goals and 48 assists.
[
    ("Heatley", "led", "Atlanta in scoring"),
    ("Heatley", "led", "last season"),
    ("Heatley", "led", "with a team-record"), 
    ("team-record", "is", "41 goals"),
    ("team-record", "is", "48 assists")
]),

# 'Tony's not feeling well,’ Spurs coach Gregg Popovich said.
([
    ("Gregg Popovich", "is", "Spurs coach"),
    ("Gregg Popovich", "said", "Tony's not feeling well")
],
# 'We're thrilled to be up 3-2,’ Coach Gregg Popovich said Wednesday.
[
    ("Gregg Popovich", "is", "coach"),
    ("Gregg Popovich", "said", "We're thrilled to be up 3-2"),
    ("Gregg Popovich", "said on", "Wednesdey")
]),

# Electronic Data Systems Corp. Thursday said the Securities and Exchange Commission has asked the company 
# for documents related to its large contract with the U.S. Navy.
([ 
    ('Electronic Data Systems Corp.', 'said about', 'Securities and Exchange Commission'),
    ('Securities and Exchange Commission', 'has asked', 'Electronic Data Systems Corp.'),
    ('Securities and Exchange Commission', 'asked for', 'documents'),
    ('documents', 'related to', 'large contract'),
    ('large contract', 'is with', 'U.S. Navy'),
],
# In a regulatory filing, EDS said the SEC had asked for information related to its troubled IT outsourcing 
# contract with the US Navy.
[
    ('EDS', 'said in', 'regulatory filing'),
    ('EDS', 'said about', 'SEC'),
    ('SEC', 'had asked for', 'information'),
    ('information', 'related to', 'troubled IT outsourcing contract'),
    ('troubled IT outsourcing contract', 'is with', 'U.S. Navy'),
]),

# As well as the dolphin scheme, the chaos has allowed foreign companies to engage in damaging logging 
# and fishing operations without proper monitoring or export controls.
([
    ('dolphin scheme', 'has allowed', 'foreign companies'),
    ('chaos', 'has allowed', 'foreign companies'),
    ('foreign companies', 'to engage in', 'logging operations'),
    ('foreign companies', 'to engage in', 'fishing operations'),
    ('loggin operations', 'are', 'damaging'),
    ('fishing operations', 'are', 'damaging'),
    ('logging operations', 'are without', 'proper monitoring'),
    ('logging operations', 'are without', 'export controls'),
    ('fishing operations', 'are without', 'proper monitoring'),
    ('fishing operations', 'are without', 'export controls'),
],
# Internal chaos has allowed foreign companies to set up damaging commercial logging and fishing operations 
# without proper monitoring or export controls
[
    ('Internal chaos', 'has allowed', 'foreign companies'),
    ('foreign companies', 'to set up', 'logging operations'),
    ('foreign companies', 'to set up', 'fishing operations'),
    ('logging operations', 'are', 'damaging'),
    ('fishing operations', 'are', 'damaging'),
    ('logging operations', 'are', 'commercial'),
    ('fishing operations', 'are', 'commercial'),
    ('logging operations', 'are without', 'proper monitoring'),
    ('logging operations', 'are without', 'export controls'),
    ('fishing operations', 'are without', 'proper monitoring'),
    ('fishing operations', 'are without', 'export controls'),
]),

# The next court session will be when the three-judge tribunal announces its verdict in mid-February.
([
    ('next session', 'is of', 'court'),
    ('next session', 'will be in', 'mid-February'),
    ('tribunal', 'is', 'three-judge'),
    ('tribunal', 'will announce', 'verdict'),
    ('tribunal', 'will announce in', 'mid-February'),
    ('verdict', 'will be in', 'mid-February'),
],
# The court's three-judge tribunal was expected to give its verdict next February.
[
    ('tribunal', 'is', 'three-judge'),
    ('three-judge', 'are from', 'court'),
    ('tribunal', 'was expected to give', 'verdict'),
    ('verdict', 'was expected', 'next February'),
]),

# The consensus among Wall Street analysts was for a loss of 28 cents a share.
([
    ('consensus', 'was among', 'analysts'),
    ('analysts', 'are from', 'Wall Street'),
    ('consensus', 'was for', 'loss'),
    ('loss', 'is of', '28 cents a share'),
],
# Analysts surveyed by First Call were expecting sales of $723 million and a loss of 28 cents a share.
[
    ('Analysts', 'surveyed by', 'First Call'),
    ('Analysts', 'were expecting', 'sales'),
    ('sales', 'are of', '$723 million'),
    ('Analysts', 'were expecting', 'loss'),
    ('loss', 'is of', '28 cents a share'),
]),

# The civilian unemployment rate improved marginally last month -- slipping to 6.1 percent -- even as 
# companies slashed payrolls by 93,000.
([
    ('unemployment rate', 'is', 'civilian'),
    ('unemployment rate', 'improved', 'marginally'),
    ('unemployment rate', 'improved', 'last month'),
    ('unemployment rate', 'slipping to', '6.1 percent'),
    ('companies', 'slashed', 'payrolls'),
    ('payrolls', 'slashed by', '93,000'),
],
# The civilian unemployment rate improved marginally last month _ sliding down to 6.1 percent _ as companies 
# slashed payrolls by 93,000 amid continuing mixed signals about the nation's economic health.
[
    ('unemployment rate', 'is', 'civilian'),
    ('unemployment rate', 'improved', 'marginally'),
    ('unemployment rate', 'improved', 'last month'),
    ('unemployment rate', 'sliding down to', '6.1 percent'),
    ('companies', 'slashed', 'payrolls'),
    ('payrolls', 'slashed by', '93,000'),
    ('signals', 'are', 'mixed'),
    ('signals', 'are', 'continuing'),
    ('signals', 'are about', 'economic health'),
    ('economic health', 'is of', 'nation')
]),

# Moffitt said the results need to be replicated in another study before testing of individuals for presence 
# of the long or short versions of the gene will be pursued.
([
    ('Moffitt', 'said about', 'results'),
    ('results', 'need to be', 'replicated results'),
    ('replicated results', 'are from', 'another study'),
    ('replicated results', 'are before pursuing', 'testing of individuals'),
    ('testing of individuals', 'is for', 'presence of the long version of the gene'),
    ('testing of individuals', 'is for', 'presence of the short version of the gene'),
],
# Professor Moffitt said the results needed to be replicated before pursuing testing of individuals for the presence 
# of the long or short versions of the gene.
[
    ('Professor Moffitt', 'said about', 'results'),
    ('results', 'needed to be', 'replicated results'),
    ('replicated results', 'before pursuing', 'testing of individuals'),
    ('testing of individuals', 'is for', 'presence of the long version of the gene'),
    ('testing of individuals', 'is for', 'presence of the short version of the gene'),
]),

# 'The compensation committee will prohibit securities industry directors from sitting on it.
([
    ('compensation committee', 'will prohibit', 'directors'),
    ('directors', 'are from', 'securities industry'),
    ('directors', 'will be prohibited from', 'sitting on'),
    ('sitting on', 'is on', 'compensation committee')
],
# 'The exchange also said its five-person compensation committee will consist only of directors from outside 
# the securities industry.
[
    ('exchange', 'said about', 'compensation committee'),
    ('compensation committee', 'is', 'five-person'),
    ('compensation committee', 'will consist of', 'directors'),
    ('directors', 'will be from', 'outside the securities industry'),
]),

# Q: Can I buy coverage for prescription drugs right away?
([
    ('Can I', 'buy', 'coverage'),
    ('coverage', 'is for', 'prescription drugs'),
    ('coverage', 'is', 'right away')
],
# Congress has added a new benefit - an option to buy insurance coverage for prescription drugs.
[
    ('Congress', 'has added', 'benefit'),
    ('benefit', 'is', 'new'),
    ('benefit', 'is', 'option'),
    ('option', 'is to buy', 'insurance coverage'),
    ('insurance coverage', 'is for', 'prescription drugs'),
]),

# Shares of Mandalay closed down eight cents to $29.42, before the earnings were announced.'
([
    ('Shares', 'are of', 'Mandalay'),
    ('Shares', 'closed down', 'eight cents'),
    ('Shares', 'closed down to', '29.42'),
    ('Shares', 'closed down before', 'earnings were announced'),
],
# Shares of Mandalay closed down 8 cents at $29.42 Thursday.
[
    ('Shares', 'are of', 'Mandalay'),
    ('Shares', 'closed down', '8 cents'),
    ('Shares', 'closed down at', '29.42'),
    ('Shares', 'closed down on', 'Thursday'),
]),

# In 1999, the building's owners, the Port Authority of New York and New Jersey, issued guidelines 
# to upgrade the fireproofing to a thickness of 1{ inches.
([
    ('Port Authority of New York and New Jersey', 'is', 'building\'s owners'),
    ('Port Authority of New York and New Jersey', 'issued', 'guidelines'),
    ('guidelines', 'were issued', 'in 1999'),
    ('guidelines', 'to upgrade', 'fireproofing'),
    ('fireproofing', 'upgraded to a', 'thickness of 1{ inches'),
],
# The NIST discovered that in 1999 the Port Authority issued guidelines to upgrade the fireproofing 
# to a thickness of 1 1/2 inches.
[
    ('NIST', 'discovered', 'guidelines'),
    ('guidelines', 'were issued', 'in 1999'),
    ('guidelines', 'were issued by', 'Port Authority'),
    ('guidelines', 'to upgrade', 'fireproofing'),
    ('fireproofing', 'upgraded to a', 'thickness of 1 1/2 inches'),
]),

# The dollar was last at $1.1149 to the euro, close to its strongest level since April 30.
([
    ('dollar', 'was last at', '$1.1149 to the euro'),
    ('dollar', 'is close to', 'strongest level'),
    ('strongest level', 'is since', 'April 30'),
],
# The dollar pushed as high as $1.1115 to the euro in early trade, extending Tuesday's one percent 
# rally to hit its strongest level since April 30.
[
    ('dollar', 'pushed as', 'high as $1.1115 to the euro'),
    ('dollar', 'pushed in', 'early trade'),
    ('dollar', 'extending', 'Tuesday\'s one percent rally'),
    ('dollar', 'to hit', 'strongest level'),
    ('strongest level', 'is since', 'April 30'),
]),

# The single currency rose as far as 135.13 yen , matching a record high hit shortly after the euro's 
# launch in January 1999.
([
    ('single currency', 'rose as far as', '135.13 yen'),
    ('single currency', 'is matching', 'record high'),
    ('record high', 'hit shortly after', 'euro\'s launch'),
    ('euro\'s launch', 'was in', 'January 1999'),
],
# The single currency rose as far as 135.26 yen , its highest level since the introduction of the 
# single currency in January 1999.
[
    ('single currency', 'rose as far as', '135.26 yen'),
    ('135.26 yen', 'is', 'highest level'),
    ('highest level', 'is since', 'introduction of single currency'),
    ('introduction of single currency', 'was in', 'January 1999'),
]),

# A New Castle County woman has become the first Delaware patient to contract the West Nile virus this year, 
# the state's Department of Health reported.
([
    ('state\'s Department of Health', 'reported about', 'woman'),
    ('woman', 'is from', 'New Castle County'),
    ('New Castle County', 'is in', 'Delaware'),
    ('woman', 'has become', 'first patient'),
    ('first patient', 'is in', 'Delaware'),
    ('first patient', 'to contract', 'West Nile virus'),
    ('West Nile virus', 'contracted', 'this year'),
],
# A 62-year-old West Babylon man has contracted the West Nile virus, the first human case in Suffolk County this year, 
# according to the county health department.
[
    ('man', 'is', '62-year-old'),
    ('man', 'is from', 'West Babylon'),
    ('West Babylon', 'is in', 'Suffolk County'),
    ('man', 'has contracted', 'West Nile virus'),
    ('man', 'is', 'first human case'),
    ('first human case', 'to contract', 'West Nile virus'),
    ('first human case', 'is in', 'Suffolk County'),
    ('first human case', 'is in', 'this year'),
    ('first human case', 'according to', 'county health department'),
]),

# He also reaffirmed his wish to resolve the North Korean nuclear crisis peacefully.
([
    ('He', 'reaffirmed', 'wish'),
    ('wish', 'is to resolve', 'North Korean nuclear crisis'),
    ('wish', 'is to resolve', 'peacefully')
],
#But the North Korean nuclear crisis has dominated his time in office.
[
    ('North Korean nuclear crisis', 'has dominated', 'time'),
    ('time', 'has been', 'in office')
]),

# A rebel who was captured said more than 2,000 insurgents were involved in the attack.
([
    ('rebel', 'was', 'captured'),
    ('rebel', 'said about', 'insurgents'),
    ('insurgents', 'were', 'more than 2,000'),
    ('insurgents', 'were involved in', 'attack'),
],
# A captured rebel said 2,100 combatants had been involved in the offensive.
[
    ('rebel', 'is', 'captured'),
    ('rebel', 'said about', 'combatants'),
    ('combatants', 'were', '2100'),
    ('combatants', 'had been involved in', 'offensive')
]),

# Kyi, a U.N. envoy says, as Japan adds to growing international pressure by saying it will halt 
# its hefty economic aid unless Suu Kyi is freed.
([
    ("U.N. envoy", "says about", "Suu Kyi"),
    ("U.N. envoy", "says about", "Japan"),
    ("Japan", "adds to growing", "international pressure"),
    ("Japan", "is saying about", "its hefty economic aid"),
    ("Japan", "will halt", "its hefty economic aid"),
    ("its hefty economic aid", "will halt unless", "freedom"),
    ("freedom", "is for", "Suu Kyi")
],
# JAPAN added to growing international pressure on Burma yesterday, threatening to halt its hefty economic 
# aid unless the military government released pro-democracy leader Aung San Suu Kyi.
[
    ("JAPAN", "added to growing", "international pressure"),
    ("JAPAN", "added to growing", "yesterday"),
    ("international pressure", "is on", "Burma"),
    ("JAPAN", "threatens to halt", "its hefty economic aid"),
    ("hefty economic aid", "halt unless", "release"),
    ("release", "is of", "pro-democracy leader"),
    ("pro-democracy leader", "is", "Aung San Suu Kyi"),
    ("release", "is to be made by", "military government")
]),

# Wal-Mart, Kohl's Corp., Family Dollar Stores Inc., and Big Lots Inc. were among the merchants posting 
# May sales that fell below Wall Street's modest expectations.
([
    ("Wal-Mart", "posted about", "May sales"),
    ("Kohl's Corp.", "posted about", "May sales"),
    ("Family Dollar Stores Inc.", "posted about", "May sales"),
    ("Big Lots Inc.", "posted about", "May sales"),
    ("other merchants", "posted about", "May sales"),
    ("May sales", "fell below", "Wall Street's modest expectations"),
    ("expectations", "were", "modest"),
    ("expectations", "were of", "Wall Street")
],
# Wal- Mart, Kohl's Corp., Family Dollar Stores Inc., and Big Lots Inc. posted May sales that fell below 
# Wall Street's modest expectations.
[
    ("Wal-Mart", "posted about", "May sales"),
    ("Kohl's Corp.", "posted about", "May sales"),
    ("Family Dollar Stores Inc.", "posted about", "May sales"),
    ("Big Lots Inc.", "posted about", "May sales"),
    ("May sales", "fell below", "Wall Street's modest expectations"),
    ("expectations", "were", "modest"),
    ("expectations", "were of", "Wall Street")
]),

# Mr Eddington warned yesterday that the future of the airline was "in the hands of the negotiators".
([
    ("Mr Eddington", "warned", "yesterday"),
    ("Mr Eddington", "warned about", "future of the airline"),
    ("future of the airline", "is in", "hands of the negotiators")
],
# "The future of BA is in the hands of the negotiators," Eddington told British Broadcasting Corp. television on Sunday.
[
    ("Eddington", "told about", "future of BA"),
    ("Eddington", "told", "British Broadcasting Corp. television"),
    ("future of BA", "is in", "hands of the negotiators"),
    ("Eddington", "told on", "sunday")
]),

# "Both of these kids are in wonderful physical condition right now," he said during a press briefing at the hospital.
([
    ("he", "said during", "press briefing"),
    ("press briefing", "was at", "hospital"),
    ("he", "said about", "Both of these kids"),
    ("Both of these kids", "are in", "physical condition"),
    ("physical condition", "is", "wonderful"),
    ("physical condition", "is","right now")
],
# "Both of these kids are in wonderful physical condition right now," said Goodrich, also director of 
# pediatric neurosurgery at the Children's Hospital at Montefiore.
[
    ("Goodrich", "is", "director of pediatric neurosurgery"),
    ("Goodrich", "said about", "Both of these kids"),
    ("Both of these kids", "are in", "physical condition"),
    ("physical condition", "is", "wonderful"),
    ("physical condition", "is", "right now"),
    ("Goodrich", "is at", "Children's Hospital"),
    ("Children's Hospital", "is at", "Montefiore")
]),

# On the cell's surface, the foreign components are recognised by other cells that then realise it is infected and kill it.
([
    ("foreign components", "are recognised by", "other cells"),
    ("foreign components", "are recognised on", "cell's surface"),
    ("other cells", "realise", "infection"),
    ("infection", "is in", "foreign components"),
    ("other cells", "kill", "foreign components")
],
# The foreign bits are recognized by other cells that realize it is infected and kill it.
[
    ("foreign bits", "are recognized by", "other cells"),
    ("other cells", "realize", "infection"),
    ("infection", "is in", "foreign bits"),
    ("other cells", "kill", "foreign bits")
]),

# Trading in Loral was halted yesterday; the shares closed on Monday at $3.01.
([
    ("trading", "is in", "Loral"),
    ("trading", "was halted", "yesterday"),
    ("shares", "are from", "Loral"),
    ("shares", "closed on", "Monday"),
    ("shares", "closed at", "$3.01")
],
# The New York Stock Exchange suspended trading yesterday in Loral, which closed at $3.01 Friday.
[
    ("The New York Stock Exchange", "suspended", "trading"),
    ("The New York Stock Exchange", "suspended", "yesterday"),
    ("The New York Stock Exchange", "suspended in", "Loral"),
    ("Loral", "closed at", "$3.01"),
    ("Loral", "closed on", "Friday"),
]),

# Knox County Health Department is following national Centers for Disease Control and Prevention Protocol 
# to contain infection.
([
    ("Health Department", "is in", "Knox County"),
    ("Health Department", "is following", "Protocol"),
    ("Protocol", "is", "national"),
    ("Protocol", "is from", "Centers for Disease Control and Prevention") 
],
# The health department spokesperson added the department is following Centers for Disease Control protocol.
[
    ("spokesperson", "is from", "health department"),
    ("spokesperson", "added about", "health departmentl"),
    ("health department", "is following", "protocol"),
    ("protocol", "is from", "Centers for Disease Control")
]),

# Schools Chancellor Joel Klein said the push for higher standards and accountability "is showing results."
([
    ("Joel Klein", "is", "Schools Chancellor"),
    ("Joel Klein", "said about", "push for higher standards"),
    ("Joel Klein", "said about", "push for accountability"),
    ("push for higher standards", "is showing", "results"),
    ("push for higher accountability", "is showing", "results")
],
# Schools Chancellor Joel Klein said he was pleased by the results.
[
    ("Joel Klein", "is", "Schools Chancellor"),
    ("Joel Klein", "said about", "results"),
    ("results", "were pleased for", "Joel Klein")
]),

# One witness told Anatolian he saw the plane on fire while it was still in the air.
([
    ("One witness", "told", "Anatolian"),
    ("One witness", "saw", "plane"), 
    ("plane", "was on", "fire"),
    ("plane", "was still in", "air")
],
# One witness told the Anatolian news agency he saw the plane on fire in mid-air.
[
    ("One witness", "told", "news agency"),
    ("news agency", "is", "Anatolian"),
    ("One witness", "saw", "plane"),
    ("plane", "was on", "fire"),
    ("plane", "was in", "mid-air")
]),

# He proposed a system under which it would take fewer and fewer votes to overcome a filibuster.
([
    ("He", "proposed", "system"),
    ("system", "is to take", "fewer and fewer votes"), 
    ("fewer and fewer votes", "are to overcome", "filibuster")
],
# Frist proposed a process in which it would take gradually fewer votes to overcome filibusters 
# preventing final votes on judicial confirmations.
[
    ("Frist", "proposed", "process"),
    ("process", "is to take gradually", "fewer votes"),
    ("fewer votes", "are to overcome", "filibusters"),
    ("fewer votes", "are to preventing", "final votes"),
    ("final votes", "are on", "judicial confirmations")
]),

# Hormone replacement therapy that combines estrogen and progestin doubles a woman's risk of breast cancer, 
# a British study of more than a million women has found.
([
    ("therapy", "is", "Hormone replacement"),
    ("therapy", "combines", "estrogen and progestin"),
    ("therapy", "doubles", "risk"),
    ("risk", "is", "breast cancer"),
    ("risk", "is for", "woman"),
    ("British study", "has found about", "therapy"),
    ("British study", "on", "women"),
    ("women", "were", "more than a million")
],
# A major British study has added to the evidence that hormone replacement therapy increases the risk of breast cancer, 
# especially when women receive a combination of estrogen and progestin.
[
    ("British study", "is", "major"),
    ("British study", "added", "evidence"),
    ("evidence", "is about", "therapy"),
    ("therapy", "is", "hormone replacement"),
    ("therapy", "increases", "risk"),
    ("risk", "is", "breast cancer"),
    ("risk", "is especially in", "women"),
    ("risk", "increases with", "combination"),
    ("combination", "is of", "estrogen and progestin"),
]),

# Barbini's comments came Tuesday, the second day of the Ministerial Conference and Expo on
# Agricultural Science and Technology.
([
    ("Barbini", "made", "comments"),
    ("comments", "came", "Tuesday"),
    ("comments", "came", "second day"),
    ("second day", "was of", "Ministerial Conference and Expo"),
    ("Ministerial Conference and Expo", "is on", "Agricultural Science and Technology")
],
# U.S. Agriculture Secretary Ann Veneman kicks off the three-day Ministerial Conference and Expo on 
# Agricultural Science and Technology on Monday.
[
    ("ann Veneman", "is", "U.S. Agriculture Secretary"),
    ("Ann Veneman", "kicks off", "Ministerial Conference and Expo"),
    ("Ministerial Conference and Expo", "lasts", "three days"),
    ("Ministerial Conference and Expo", "is on", "Agricultural Science and Technology"),
    ("Ministerial Conference and Expo", "kicked off on", "Monday")
]),

# Yesterday, shares closed up 29 cents, or 0.54 percent, at $54.32.
([
    ("shares", "closed", "Yesterday"),
    ("shares", "closed up", "29 cents"),
    ("shares", "closed up", "0.54 percent"),
    ("shares", "closed at", "$54.32")
],
# Amazon's shares yesterday closed at $54.32 on the Nasdaq Stock Market, up 29 cents.
[
    ("shares", "are of", "Amazon"),
    ("shares", "closed", "yesterday"),
    ("shares", "closed at", "$54.32"), 
    ("shares", "closed  on", "Nasdaq Stock Market"),
    ("shares", "closed up", "29 cents")
]),

# Lawtey is not the first faith-based program in Florida's prison system.
([
    ("Lawtey", "is", "program"),
    ("Lawtey", "is", "faith-based"),
    ("Lawtey", "is not", "first"),
    ("first", "is in", "prison system"),
    ("prison system", "is in", "Florida") 
],
# But Lawtey is the first entire prison to take that path.
[
    ("Lawtey", "is", "prison"),
    ("Lawtey", "is", "first"),
    ("first", "to take", "that path")
]),

# The transaction will grant Handspring stockholders 0.09 of a share of Palm--and no shares 
# of PalmSource--for each share of Handspring common stock.
([
    ("stockholders", "are of", "Handspring"),
    ("transaction", "will grant", "stockholders"),
    ("stockholders", "will have", "0.09 of a share of Palm"),
    ("stockholders", "will have", "no shares of PalmSource"),
    ("0.09 of a share of Palm", "will be for", "each share"),
    ("no shares of PalmSource", "will be for", "each share"),
    ("each share", "is of", "common stock"),
    ("common stock", "is of", "Handspring")
],
# Under the proposed terms of the transaction, and following the spinoff of PalmSource, 
# Palm will exchange 0.09 shares for each share of Handspring.
[
    ("transaction", "has", "proposed terms"),
    ("Palm", "is", "spinoff of PalmSource"),
    ("proposed terms", "are about", "exchange of shares"),
    ("exchange of shares", "includes", "Palm"),
    ("exchange of shares", "includes", "Handspring"),
    ("Palm", "will exchange", "0.09 shares"),
    ("0.09 shares", "will be exchanged for", "each share"),
    ("each share", "is of", "Handspring")
]),

# The giant rock was first observed on August 24 by Lincoln Near-Earth Asteroid Research Program, 
# based in Socorro, New Mexico.
([
    ("giant rock", "was observed on", "August 24"), 
    ("giant rock", "was observed by", "Lincoln Near-Earth Asteroid Research Program"), 
    ("Lincoln Near-Earth Asteroid Research Program", "is based in", "Socorro"), 
    ("Socorro", "is in", "New Mexico")
],
# The rock was first observed by the Lincoln Near Earth Asteroid Research Program, also known as LINEAR.
[
    ("rock", "was", "first observed"),
    ("first observed", "was by", "Lincoln Near Earth Asteroid Research Program"), 
    ("Lincoln Near Earth Asteroid Research Program", "is known as", "LINEAR")
]),

# "We need to change old habits and seriously rethink business-as-usual."
([
    ("we", "need to change", "old habits"), 
    ("we", "need to rethink", "business-as-usual"),
    ("we", "need to rethink", "seriously"),
],
# He urged employees to "avoid complacency" and to "change old habits and seriously rethink business-as-usual."
[
    ("He", "urged", "employees"), 
    ("He", "urged to avoid", "complacency"), 
    ("He", "urged to change", "old habits"), 
    ("He", "urged to rethink", "business-as-usual"),
    ("He", "urged to rethink", "seriously")
]),

# "These despicable acts were committed by killers whose only faith is hate," Bush said, 
# adding that the United States will find the killers.
([
    ("Bush", "said about", "despicable actss"),
    ("despicable acts", "were committed by", "killers"), 
    ("killers", "have", "only faith"),
    ("only faith", "is", "hate"), 
    ("United States", "will find", "killers")
],
# These despicable acts were committed by killers whose only faith is hate and the United States will find 
# the killers and they will learn the meaning of American justice.
[
    ("despicable acts", "were committed by", "killers"), 
    ("killers", "have", "only faith"),
    ("only faith", "is", "hate"),
    ("United States", "will find", "killers"), 
    ("killers", "will learn", "meaning"),
    ("meaning", "is of", "American justice")
]),

# There are a total of 659 women enrolled at the academy, the report said.
([
    ("report", "said about", "women enrolled"),
    ("women enrolled", "are", "659"),
    ("women enrolled", "are at", "academy"),
],
# There were 659 women enrolled at the academy at the time of the survey.
[
    ("women enrolled", "were at", "academy"),
    ("women enrolled", "were", "659"),
    ("women enrolled", "were at", "time"),
    ("survey", "was at", "time"),
]),

# It is a national concern that will touch virtually every American," Abraham said.
([
    ("Abraham", "said about", "national concern"),
    ("national concern", "will touch", "virtually every American")
],
# The impact of natural-gas shortages "will touch virtually every American," Energy Secretary Spencer Abraham 
# warned yesterday.
[
    ("Spencer Abraham", "is", "Energy Secretary"),
    ("Spencer Abraham", "warned about", "impact"),  
    ("impact", "is of", "natural-gas shortages"),
    ("Spencer Abraham", "warned", "yesterday"),
    ("impact", "will touch", "virtually every American"), 
]),

# In the United States, 20.7 percent of all women smoke.
([
    ("woman", "are in", "United States"),
    ("20.7 percent", "is of", "women"), 
    ("20.7 percent", "are", "smokers")
],
# Nevada is where the most women smoke, 28 percent.
[
    ("Nevada", "is where", "most women smoke"), 
    ("most women smoke", "is", "28 percent")
]),

# It has a margin of error of plus or minus 4 percentage points.
([
    ("It", "has", "margin of error"),
    ("margin of error", "is of", "plus or minus 4 percentage points")
],
# That poll had 712 likely voters and sampling error of plus or minus 3.7 percentage points.
[
    ("poll", "had", "voters"), 
    ("voters", "were", "712 likely"),
    ("poll", "had", "sampling error"),
    ("sampling erro", "was of", "plus or minus 3.7 percentage points")
]),

# Shares of MONY were gaining $2.57, or 9%, to $31.90 in after-hours trading on Instinet.
([
    ("Shares", "were of", "MONY"), 
    ("Shares", "were gaining", "$2.57"), 
    ("Shares", "were gaining", "9%"), 
    ("Shares", "were gaining to", "$31.90"), 
    ("Shares", "were gaining in", "after-hours trading"),
    ("after-hours trading", "was on", "Instinet")
],
# MONY shares rose 8.76 per cent to $31.90 in after-hours trading in New York.
[
    ("shares", "were of", "MONY"), 
    ("shares", "rose", "8.76 percent"), 
    ("shares", "rose to", "$31.90"), 
    ("Shares", "rose in", "after-hours trading"),
    ("after-hours trading", "was in", "New York")
]),

# Diana was at her lowest ebb when she wrote the letter to Paul Burrell claiming there was a plot to kill her.
([
    ("Diana", "was at", "lowest ebb"), 
    ("Diana", "wrote", "letter"),
    ("letter", "was for", "Paul Burrell"), 
    ("letter", "claimed there was", "plot"),
    ("plot", "was to kill", "Diana")
],
# Burrell said Diana wrote a letter in October 1996 claiming there was a plot to kill her in a smash and gave it 
# to him to keep as insurance.
[
    ("Burrell", "said about", "Diana"), 
    ("Diana", "wrote", "letter"),
    ("letter", "was wrote in", "October 1996"), 
    ("letter", "claimed there was", "plot"), 
    ("plot", "was to kill", "Diana"),
    ("plot", "was to kill in", "smash"),
    ("letter", "was given to", "Burrell"), 
    ("letter", "was to keep as", "insurance")
]),

# Gillespie sent a letter to CBS President Leslie Moonves asking for a historical review or a disclaimer.
([
    ("Gillespie", "sent", "letter"), 
    ("Leslie Moonves", "is", "CBS President"),
    ("letter", "was sent to", "Leslie Moonves"),
    ("letter", "asked for", "a historical review"), 
    ("letter", "asked for", "a disclaimer")
],
# Republican National Committee Chairman Ed Gillespie issued a letter Friday to CBS Television 
# President Leslie Moonves.
[
    ("Ed Gillespie", "is", "Republican National Committee Chairman"),
    ("Leslie Moonves", "is", "CBS Television President"),
    ("Ed Gillespie", "issued", "letter"), 
    ("letter", "was issued on", "Friday"), 
    ("letter", "was issued to", "Leslie Moonves")
]),

# "Let's show we won't let them off," said Marc Blondel, leader of the Force Ouvriere union.
([
    ("Marc Blondel", "is", "leader"),
    ("leader", "is of", "Force Ouvriere union"),
    ("Marc Blondel", "said", "Let's show we won't let them off"), 
],
# "The movement to defend pensions is gaining momentum, and we won't give up," said Marc Blondel, 
# leader of the Force Ouvriere union.
[
    ("Marc Blondel", "is", "leader"),
    ("leader", "is of", "Force Ouvriere union"),
    ("Marc Blondel", "said about", "movement to defend pensions"),
    ("movement to defend pensions", "is gaining", "momentum"),
    ("Marc Blondel", "said about", "Force Ouvriere union"),
    ("Force Ouvriere union", "won't give up", "")
]),

# Contrary to what PeopleSoft management would have you believe, Oracle intends to fully support PeopleSoft 
# customers and products for many years to come.
([
    ("Oracle", "intends to", "fully support"),
    ("fully support", "is for", "PeopleSoft customers"), 
    ("fully support", "is for", "PeopleSoft products"),
    ("fully support", "is for", "many years to come"),
    ("PeopleSoft management", "would have you believe on", "contrary"),
],
# Ellison said that contrary to the contentions of PeopleSoft management, Oracle intends to 
# "fully support PeopleSoft customers and products" for many years to come.
[
    ("Ellison", "said about", "contentions"),
    ("contentions", "are of", "PeopleSoft management"),
    ("contentions", "are on", "contrary"),
    ("Ellison", "said about", "Oracle"),
    ("Oracle", "intends to", "fully support"),
    ("fully support", "is for", "PeopleSoft customers"), 
    ("fully support", "is for", "PeopleSoft products"),
    ("fully support", "is for", "many years to come"),
]),

# Under Mexican law, bounty hunting is considered a form of kidnapping.
([
    ("Mexico", "has", "law"),
    ("law", "is about", "bounty hunting"),
    ("bounty hunting", "is considered", "form of kidnapping"), 
],
# Bounty hunting is illegal in Mexico, and the bounty hunter was charged with kidnapping.
[
    ("bounty hunting", "is", "illegal in Mexico"), 
    ("bounty hunter", "makes", "bounty hunting"),
    ("bounty hunter", "was charged with", "kidnapping")
]),

# The announcements were made at the International Broadcasting Convention (IBC) in Amsterdam.
([
    ("IBC", "is", "International Broadcasting Convention"),
    ("International Broadcasting Convention", "was in", "Amsterdam"),
    ("announcements", "were made at", "International Broadcasting Convention"), 
],
# The submission was on Monday, but the announcement was made Friday at the 
# International Broadcasting Convention in Amsterdam.
[
    ("submission", "was on", "Monday"), 
    ("announcement", "was made on", "Friday"), 
    ("announcement", "was from", "submission"), 
    ("International Broadcasting Convention", "was in", "Amsterdam"),
    ("announcement", "was made at", "International Broadcasting Convention in Amsterdam")
]),

# Its keywords are supported by Chinese language Web portals.
([
    ("Web portals", "are in", "Chinese language"),
    ("keywords", "are supported by", "Web portals")
],
# Chinese language Web portals also support 3721 keywords, the Web site said.
[   
    ("Web site", "said about", "Web portals"),
    ("Web portals", "are in", "Chinese language"),
    ("Web portals", "support", "3721 keywords"), 
]),

# The consensus estimate of analysts polled by Thomson First Call called for a profit of $1.70 per share.
([
    ("Thomson First Call", "polled", "analysts"),
    ("analysts", "have", "consensus estimate"),
    ("consensus estimate", "called for", "profit"),
    ("profit", "is of", "$1.70 per share"),
],
# Analysts polled by Reuters Research, a unit of Reuters Group Plc, on average forecast profit of $1.69 per share.
[
    ("Reuters Research", "is", "unit of Reuters Group Plc"),
    ("Reuters Research", "polled", "analysts"),
    ("analysts", "forecast", "profit"),
    ("profit", "is of", "$1.69 per share"),
]),

# Initial autopsy reports show they died of dehydration, hyperthermia and suffocation.
([  
    ("reports", "are from", "Initial autopsy"),
    ("reports", "show about", "they"),
    ("they", "died of", "dehydration"), 
    ("they", "died of", "hyperthermia"), 
    ("they", "died of", "suffocation")
],
# Two more died later, and initial autopsy reports show they succumbed to dehydration, hypothermia and suffocation.
[
    ("Two more", "died", "later"), 
    ("reports", "are from", "initial autopsy"),
    ("reports", "show about", "Two more"),
    ("Two more", "succumbed to", "dehydration"), 
    ("Two more", "succumbed to", "hypothermia"), 
    ("Two more", "succumbed to", "suffocation")
]),

# Authorities appealed to the public Friday to come forward and provide what could be the key to solving 
# the sniper-style shootings that have killed three people outside area convenience stores.
([
    ("authorities", "appealed to", "public"), 
    ("authorities", "appealed on", "Friday"),
    ("authorities", "appealed to", "come forward"),
    ("authorities", "appealed to provide what could be", "key"),
    ("key", "is to solving", "shootings"),
    ("shootings", "were", "sniper-style"),
    ("shootings", "have killed", "three people"),
    ("shootings", "have killed", "outside area convenience stores")
],
# Authorities looked to the public yesterday for help in solving the deadly 
# sniper-style shootings of three people outside Charleston-area convenience stores.
[
    ("authorities", "looked to", "public"), 
    ("authorities", "looked", "yesterday"), 
    ("authorities", "looked for", "help"), 
    ("help", "is in solving", "shootings"), 
    ("shootings", "were", "deadly"),
    ("shootings", "were", "sniper-style"), 
    ("shootings", "killed", "three people"), 
    ("shootings", "killed", "outside convenience stores"),
    ("outside convenience stores", "is in", "Charleston-area")
]),

# Second comes HP (27 percent with $2.9 billion, up just 0.4 percent).
([
    ("HP", "comes", "second"), 
    ("HP", "comes with", "27 percent"),
    ("HP", "comes with", "$2.9 billion"),
    ("HP", "ups", "just 0.4 percent"),
],
# HP fell to second place with server sales growing 0.4 percent to $2.9 billion.
[
    ("HP", "fell to", "second place"),
    ("HP", "fell with", "server sales"),
    ("server sales", "growing", "0.4 percent"), 
    ("server sales", "growing to", "$2.9 billion"), 
]),

# U.S. forces recently apprehended some 40 suspected foreign militants near the Syrian border 
# and are now interrogating them.
([
    ("U.S. forces", "recently apprehended", "some 40"),
    ("some 40", "are", "suspected foreign militants"), 
    ("suspected foreign militants", "were", "near the Syrian border"), 
    ("U.S. forces", "are interrogating", "some 40")
],
# The Third Armored Cavalry Regiment recently apprehended about 40 suspected fighters near the Syrian border,
#  officials said.
[
    ("officials", "said about", "Third Armored Cavalry Regiment"),
    (" Third Armored Cavalry Regiment", "recently apprehended", "about 40"),
    ("about 40", "are", "suspected fighters"), 
    ("suspected fighters", "were", "near the Syrian border"), 
]),

# That compares with a profit of $1 million, or breakeven, on $1.39 billion in revenue during the same period last year.
([
    ("That", "compares with", "profit"),
    ("profit", "is", "$1 million"),
    ("profit", "is", "breakeven"),
    ("profit", "was during", "same period"),
    ("revenue", "was", "$1.39 billion"),
    ("revenue", "was during", "same period"),
    ("same period", "is in", "last year")
],
# Total revenue for the second quarter was $1.48 billion, up 7% from $1.39 billion in the same period last year.
[
    ("total revenue", "is for", "second quarter"),
    ("total revenue", "was", "$1.48 billion"),
    ("total revenue", "up", "7%"),
    ("total revenue", "up from", "$1.39 billion"),
    ("$1.39 billion", "was during", "same period"),
    ("same period", "is in", "last year")
]),

# Bolivia's army fought to stop columns of protesters from streaming into the food-starved capital on Wednesday 
# as a popular uprising against the president spread.
([
    ("army", "is of", "Bolivia"),
    ("army", "fought to stop", "columns of protesters"),
    ("army", "fought on", "Wednesday"),
    ("army", "fought to stop from", "streaming"),
    ("streaming", "was into", "food-starved capital"),
    ("president", "is of", "Bolivia"),
    ("popular uprising", "is against", "president"),
    ("popular uprising", "is", "spreading")
],
# Bolivia's army fought to stop a column of dynamite-wielding miners from streaming into the besieged capital on Wednesday, 
# leaving two dead as a popular uprising against the President spread.
[
    ("army", "is of", "Bolivia"),
    ("army", "fought to stop", "column"),
    ("column", "is of", "dynamite-wielding miners"),
    ("army", "fought to stop from", "streaming"),
    ("streaming", "was into", "besieged capital"),
    ("army", "fought on", "Wednesday"),
    ("army", "leaved", "two dead"),
    ("President", "is of", "Bolivia"),
    ("popular uprising", "is against", "President"),
    ("popular uprising", "is", "spreading")
]),

# The A920 comes with a printer, scanner, and copier for $89.
([
    ("A920", "comes with", "printer"),
    ("A920", "comes with", "scanner"),
    ("A920", "comes with", "copier"),
    ("A920", "is for", "$89")
],
# Dell's Personal All-in-One A920 is an entry-level device that combines printer, scanner and copier functions for $89.
[
    ("Personal All-in-One A920", "is from", "Dell"),
    ("Personal All-in-One A920", "is", "entry-level device"),
    ("Personal All-in-One A920", "combines", "functions"),
    ("functions", "are", "printer"),
    ("functions", "are", "scanner"),
    ("functions", "are", "copier"),
    ("Personal All-in-One A920", "is for", "$89")
]),

# But in the first 30 seconds after Young entered the ring, the family knew it was an uneven match, Meyers said.
([
    ("family", "is of", "Young"),
    ("Meyers", "said about", "Young"),
    ("Meyers", "said about", "family"),
    ("Young", "entered", "ring"),
    ("family", "knew in", "first 30 seconds"),
    ("first 30 seconds", "were after", "entry"),
    ("entry", "was of", "Young"),
    ("entry", "was in", "ring"),
    ("family", "knew", "uneven match"),
],
# But in the first 30 seconds of the bout, family members knew it was an uneven match, Jodie Meyers, Stacy Young's sister, said.
[
    ("Jodie Meyers", "is", "sister"),
    ("sister", "is of", "Stacy Young"),
    ("family members", "are of", "Stacy Young"),
    ("Stacy Young", "had", "bout"),
    ("family members", "knew in", "first 30 seconds"),
    ("first 30 seconds", "were of", "bout"),
    ("family members", "knew", "uneven match"),
]),

# Singapore reported no suspected SARS cases Wednesday, but officials quarantined 70 people who had contact 
# with the Taiwanese patient.
([
    ("Singapore", "reported", "no suspected SARS cases"),
    ("Singapore", "reported on", "Wednesday"),
    ("officials", "are of", "Singapore"),
    ("officials", "quarantined", "70 people"),
    ("70 people", "had contact with", "Taiwanese patient")
],
# Still, Singapore quarantined 70 people who had been in close contact with the scientist.
[
    ("Singapore", "quarantined", "70 people"),
    ("70 people", "had been in", "close contact"),
    ("close contact", "was with", "scientist")
]),

# Downstream at Mount Vernon, the Skagit River was expected to crest at 36 feet 
# -- 8 feet above flood stage -- tonight, Burke said.
([
    ("Burke", "said about", "Skagit River"),
    ("Skagit River", "was expected to crest", "Downstream at Mount Vernon"),
    ("Skagit River", "was expected to crest at", "36 feet"),
    ("36 feet", "are", "8 feet above flood stage"),
    ("Skagit River", "was expected to crest", "tonight"),
],
# The Skagit was expected to crest during the night at 38 feet at Mount Vernon, 
# 10 feet above flood stage, the National Weather Service said.
[
    ("National Weather Service", "said about", "Skagit"),
    ("Skagit", "was expected to crest during", "night"),
    ("Skagit", "was expected to crest at", "38 feet"),
    ("Skagit", "was expected to crest at", "Mount Vernon"),
    ("36 feet", "are", "10 feet above flood stage"),
]),

# On Monday, the Dow declined 5.25, or 0.1 percent, at 8,983.80, having shed 2.3 percent last week.
([
    ("Dow", "declined on", "Monday"),
    ("Dow", "declined", "5.25"),
    ("Dow", "declined", "0.1 percent"),
    ("Dow", "declined at", "8,983.80"),
    ("Dow", "declined having shed", "2.3 percent"),
    ("2.3 percent", "had been shed", "last week")
],
# In early trading, the Dow Jones industrial average was down 39.94, or 0.4 percent, at 8,945.50, having slipped 3.61 points Monday.
[   
    ("Dow Jones industrial average", "was down", "In early trading"),
    ("Dow Jones industrial average", "was down", "39.94"),
    ("Dow Jones industrial average", "was down", "0.4 percent"),
    ("Dow Jones industrial average", "was down at", "8,945.50"),
    ("Dow Jones industrial average", "was down having slipped", "3.61 points"),
    ("Dow Jones industrial average", "was down having slipped", "Monday"),
]),

# The injured were taken to hospitals in Jefferson City and Columbia, a college town about 30 miles to the north.
([
    ("injured", "were taken to", "hospitals"),
    ("hospitals", "were in", "Jefferson City"),
    ("hospitals", "were in", "Columbia"),
    ("Columbia", "is", "college town"),
    ("Columbia", "is about", "30 miles to the north")
],
# The injured were taken to hospitals in Jefferson City and Columbia, about 48km north; 
# their conditions were not immediately available.
[
    ("injured", "were taken to", "hospitals"),
    ("hospitals", "were in", "Jefferson City"),
    ("hospitals", "were in", "Columbia"),
    ("Columbia", "is", "about 48km north"),
    ("injured", "had", "conditions"),
    ("conditions", "were not", "immediately available")
]),

# The dollar was at 117.85 yen against the Japanese currency, up 0.1 percent.
([
    ("dollar", "was at", "117.85 yen"),
    ("dollar", "was against", "Japanese currency"),
    ("dollar", "was up", "0.1 percent")
],
# Against the Swiss franc the dollar was at 1.3289 francs, up 0.5 percent on the day.
[
    ("dollar", "wass against", "Swiss franc"),
    ("dollar", "was at", "1.3289 francs"),
    ("dollar", "was up", "0.5 percent"),
    ("dollar", "was up on", "day"),
]),

# In addition to O'Connor, Rehnquist's majority opinion was joined by Justices David Souter,
# Ruth Bader Ginsburg, and Stephen Breyer.
([
    ("majority opinion", "was of", "Rehnquist"),
    ("majority opinion", "was joined by", "O'Connor"),
    ("majority opinion", "was joined by", "Justices"),
    ("Justices", "includes", "David Souter"),
    ("Justices", "includes", "Ruth Bader Ginsburg"),
    ("Justices", "includes", "Stephen Breyer")
],
# Joining him in the majority opinion were Justices Sandra Day O'Connor, David H. Souter, 
# Ruth Bader Ginsburg and Stephen G. Breyer.
[
    ("majority opinion", "was of", "him"),
    ("Justices", "were joining", "majority opinion"),
    ("Justices", "includes", "Sandra Day O'Connor"),
    ("Justices", "includes", "David H. Souter"),
    ("Justices", "includes", "Ruth Bader Ginsburg"),
    ("Justices", "includes", "Stephen G. Breyer")
]),

# Martin, 58, will be freed today after serving two thirds of his five-year sentence for the manslaughter 
# of 16-year-old Fred Barras.
([
    ("Martin", "has", "58"),
    ('Martin', 'will be freed', 'today'),
    ('Martin', 'will be freed after', 'serving'),
    ('serving', 'is of', 'two thirds'),
    ('two thirds', 'were of', 'sentence'),
    ('sentence', 'was', 'five-year'),
    ('sentence', 'was for', 'manslaughter'),
    ('manslaughter', 'was of', 'Fred Barras'),
    ('Fred Barras', 'was', '16-year-old')
],
# Martin served two thirds of a five-year sentence for the manslaughter of Barras and for wounding Fearon.
[   
    ('Martin', 'served', 'two thirds'), 
    ('two thirds', 'were of', 'sentence'),
    ('sentence', 'was', 'five-year'),
    ('sentence', 'was for', 'manslaughter'),
    ('manslaughter', 'was of', 'Fred Barras'),
    ('sentence', 'was for wounding', 'Fearon')
]),

# IDEC shareholders would own 50.5 percent of the stock of the combined company, 
# and Biogen shareholders the remaining 49.5 percent.
([
    ('IDEC shareholders', 'would own', '50.5 percent'),
    ('50.5 percent', 'is of', 'stock'),
    ('stock', 'is of', 'combined company'),
    ('Biogen shareholders', 'would own', '49.5 percent'),
    ('49.5 percent', 'is of', 'stock'),
],
# The companies said Idec holders would own about 50.5 percent of the stock of the combined company. 
[
    ('companies', 'said about', 'Idec holders'),
    ('Idec holders', 'would own about', '50.5 percent'),
    ('50.5 percent', 'is of', 'stock'),
    ('stock', 'is of', 'combined company')
]),

# Nonetheless, the open-source guru insisted, "This attack was wrong, and it was dangerous to our goals.
([
    ('open-source guru', 'insisted about', 'attack'),
    ('attack', 'was', 'wrong'),
    ('attack', 'was', 'dangerous to our goals'),
],
# "This attack was wrong, and it was dangerous to our goals," Raymond said.
[
    ('Raymond', 'said about', 'attack'),
    ('attack', 'was', 'wrong'),
    ('attac', 'was', 'dangerous to our goals')
]),

# Frank Quattrone, the former Credit Suisse First Boston technology investment-banking guru, 
# reportedly pleaded not guilty Tuesday to charges of obstruction of justice and witness tampering.
([
    ('Frank Quattrone', 'was', 'guru'),
    ('guru', 'was of', 'technology investment-banking'),
    ('guru', 'was in', 'Credit Suisse First Boston'),
    ('Frank Quattrone', 'pleaded', 'not guilty'),
    ('Frank Quattrone', 'pleaded on', 'Tuesday'),
    ('not guilty', 'was to','charges'),
    ('charges', 'were of', 'obstruction of justice'), 
    ('charges', 'were of', 'witness tampering')
],
# NEW YORK -(Dow Jones)- Former star investment banker Frank Quattrone pleaded not guilty Tuesday 
# to criminal charges of obstruction of justice and witness tampering.
[   
    ('Dow Jones', 'inform about', 'Frank Quattrone'),
    ('Dow Jones', 'inform from', 'NEW YORK'),
    ('Frank Quattrone', 'pleaded', 'not guilty'),
    ('Frank Quattrone', 'pleaded on', 'Tuesday'),
    ('not guilty', 'was to','criminal charges'),
    ('criminal charges', 'were of', 'obstruction of justice'), 
    ('criminal charges', 'were of', 'witness tampering')
]),

# The blue-chip Dow Jones industrial average .DJI fell 86.56 points, or 0.94 percent, to 9,109.99, 
# after giving up more than 1 percent earlier.
([
    ('DJI', 'is', 'Dow Jones industrial average'),
    ( 'Dow Jones industrial average', 'is', 'blue-chip'),
    ('Dow Jones industrial average', 'fell', '86.56 points'),
    ('Dow Jones industrial average', 'fell', '0.94 percent'),
    ('Dow Jones industrial average', 'fell to', '9,109.99'),
    ('Dow Jones industrial average', 'fell after giving up earlier', 'more than 1 percent'),
],
# The Dow Jones industrial average .DJI fell 79.43 points, or 0.86 percent, to 9,117.12 on Friday.
[
    ('DJI', 'is', 'Dow Jones industrial average'),
    ('Dow Jones industrial average', 'fell', '79.43 points'),
    ('Dow Jones industrial average', 'fell', '0.86 percent'),
    ('Dow Jones industrial average', 'fell to', '9,117.12'),
    ('Dow Jones industrial average', 'fell on', 'Friday'),
]),

# The Dow Jones industrial average ended the day down 10.89 at 9,837.94, after advancing 111.04 Wednesday.
([
    ('Dow Jones industrial average', 'ended down', 'day'),
    ('Dow Jones industrial average', 'ended down', '10.89'),
    ('Dow Jones industrial average', 'ended down at', '9,837.94'),
    ('Dow Jones industrial average', 'ended down after', 'advancing 111.04'),
    ('advancing 111.04', 'was on', 'Wednesday')
],
# The Dow Jones industrial average fell 10.89 points, or 0.11 percent, to 9,837.94.
[
    ('Dow Jones industrial average', 'fell', '10.89 points'),
    ('Dow Jones industrial average', 'fell', '0.11 percent'),
    ('Dow Jones industrial average', 'fell to', '9,837.94')
]),

# Perry has since called two special legislative sessions to try force the redistricting plan through.
([
    ('Perry', 'has called', 'sessions'),
    ('sessions', 'are', 'two special legislative'),
    ('sessions', 'are to try force through', 'redistricting plan'),
],
# Since then, Texas Gov. Rick Perry has called two special sessions trying to push the measure through.
[
    ('Rick Perry', 'is', 'Texas Gov.'),
    ('Rick Perry', 'has called', 'two special sessions'),
    ('two special sessions', 'are for trying to push through', 'measure')
]),

# The agency will "consider as timely any tax returns or payments due" Aug. 15 if they are submitted by Aug. 22.
([
    ('agency', 'will consider', 'tax returns'),
    ('agency', 'will consider', 'payments'),
    ('agency', 'will consider', 'timely'),
    ('tax returns', 'due by', 'Aug. 15'),
    ('payments', 'due by', 'Aug. 15'),
    ('tax returns', 'to be summited by', 'Aug. 22'),
    ('payments', 'to be summited by', 'Aug. 22'),
],
# The agency said it would consider as timely any tax returns or payments due from Friday through Aug. 22 
# if they are completed by Aug. 22.
[
    ('agency', 'said about', 'tax returns'),
    ('agency', 'said about', 'payments'),
    ('agency', 'would consider', 'timely'),
    ('tax returns', 'due from', 'Friday'),
    ('payments', 'due from', 'Friday'),
    ('tax returns', 'due through', 'Aug. 22'),
    ('payments', 'due through', 'Aug. 22'),
    ('tax returns', 'to be completed by', 'Aug. 22'),
    ('payments', 'to be completed by', 'Aug. 22'),
]),

# Democrats currently hold a 17-15 advantage in the state's congressional delegation.
([
    ('Democrats', 'currently hold', 'advantage'),
    ('advantage', 'is', '17-15'),
    ('advantage', 'is in', 'congressional delegation'),
    ('congressional delegation', 'is of', 'state')
],
# The Texas congressional delegation now is 17-15 Democratic.
[
    ('congressional delegation', 'is of', 'Texas'),
    ('congressional delegation', 'is', '17-15 Democratic'),
    ('congressional delegation', 'is', 'now'),
]),

# Chaudhry was released 56 days later and the Fiji military installed an all-indigenous government led by Qarase, 
# who won democratic elections in September 2001.
([
    ('Chaudhry', 'was released', '56 days later'),
    ('Fiji military', 'installed', 'government'),
    ('government', 'was', 'all-indigenous'),
    ('government', 'was led by', 'Qarase'),
    ('Qarase', 'won', 'democratic elections'),
    ('democratic elections', 'were in', 'September 2001')
],
# The Fijian military installed an all-indigenous government led by Mr Qarase, who won democratic elections in September 2001.
[
    ('Fijian military', 'installed', 'government'),
    ('government', 'was', 'all-indigenous'),
    ('government', 'was led by', 'Mr Qarase'),
    ('Mr Qarase', 'won', 'democratic elections'),
    ('democratic elections', 'were in', 'September 2001')
]),

# New legit download service launches with PC users in mind.
([
    ("download service", "is", "new"),
    ("download service", "is", "legit"),
    ("download service", "launches with", "PC users in mind"),
],
# BuyMusic is the first subscription-free paid download music service for PC users.
[   
    
    ("BuyMusic", "is", "service"),
    ("service", "is", "first"),
    ("service", "is", "subscription-free"),
    ("service", "is", "paid download music"),
    ("service", "is for", "PC users"),
]),

# The 30-year bond US30YT=RR rose 22/32 for a yield of 4.31 percent, versus 4.35 percent at Wednesday's close.
([
    ("bond US30YT=RR", "is", "30-year"),
    ("bond US30YT=RR", "rose", "22/32"), 
    ("bond US30YT=RR", "rose for", "yield of 4.31 percent"), 
    ("bond US30YT=RR", "rose versus", "4.35 percent"), 
    ("4.35 percent", "was at", "Wednesday's close")
],
# The 30-year bond US30YT=RR grew 1-3/32 for a yield of 4.30 percent, down from 4.35 percent late Wednesday.
[
    ("bond US30YT=RR", "is", "30-year"),
    ("bond US30YT=RR", "grew", "1-3/32"), 
    ("bond US30YT=RR", "grew for", "yield of 4.30 percent"), 
    ("bond US30YT=RR", "down from", "4.35 percent"),
    ("4.35 percent", "was", "late Wednesday")
]),

# Last week, his lawyers asked Gov. Mark R. Warner to grant clemency, but the governor declined to intervene.
([
    ("Mark R. Warner", "is", "Gov."),
    ("lawyers", "asked", "Mark R. Warner"), 
    ("lawyers", "asked to grant", "clemency"), 
    ("lawyers", "asked", "Last week"), 
    ("Mark R. Warner", "declined to intervene in", "clemency")
],
# Last week, his lawyers asked Warner to grant clemency under certain conditions that would have lead to a new sentencing hearing.
[
    ("lawyers", "asked", "Warner"), 
    ("lawyers", "asked", "Last week"), 
    ("lawyers", "asked to grant", "clemency"),
    ("clemency", "was asked under", "certain conditions"), 
    ("conditions", "would have lead to", "new sentencing hearing")
]),

# Gov. Linda Lingle and members of her staff were at the Navy base and watched the launch.
([
    ("Linda Lingle", "is", "Gov."),
    ("Linda Lingle", "was at", "Navy base"), 
    ("staff", "is of", "Linda Lingle"),
    ("members", "are of", "staff"),
    ("members", "were at", "Navy base"),
    ("Linda Lingle", "watched", "launch"),
    ("members", "watched", "launch"),
],
# Gov. Linda Lingle and other dignitaries are scheduled to be at the base to watch the launch.
[
    ("Linda Lingle", "is", "Gov."),
    ("Linda Lingle", "is scheduled to be at", "base"), 
    ("other dignitaries", "are scheduled to be at", "base"),
    ("Linda Lingle", "is to watch", "launch"),
    ("other dignitaries", "are to watch", "launch")
]),

# The best the investigators can do is nitpick about the process and substance of isolated business decisions ... 
# and question his competence as a manager."
([
    ("best", "cand do", "investigators"),
    ("best", "is", "nitpick about", "process"),
    ("best", "is", "nitpick about", "substance"),
    ("process", "is of", "isolated business decisions"), 
    ("substance", "is of", "isolated business decisions"), 
    ("best", "is question", "his competence"),
    ("his competence", "is as", "manager")
],
# Ebbers' lawyer, Reid Weingarten, said despite the thorough investigation, 
# "the best the investigators can do is nitpick about the process and substance of isolated business decisions."
[
    ("Reid Weingarten", "is", "Ebbers' lawyer"),
    ("Reid Weingarten", "said about", "best"),
    ("Reid Weingarten", "said about", "investigators"),
    ("Reid Weingarten", "said despite", "investigation"),
    ("investigation", "is", "thorough"),
    ("best", "cand do", "investigators"),
    ("best", "is", "nitpick about", "process"),
    ("best", "is", "nitpick about", "substance"),
    ("process", "is of", "isolated business decisions"), 
    ("substance", "is of", "isolated business decisions"),
]),

# The Justice Department filed suit Thursday against the state of Mississippi for failing to end 
# what federal officials call "disturbing" abuse of juveniles and "unconscionable" conditions at two state-run facilities.
([
    ("Justice Department", "filed", "suit"), 
    ("Justice Department", "filed", "Thursday"), 
    ("Justice Department", "filed against", "state of Mississippi"), 
    ("state of Mississippi", "failing to end", "disturbing abuse of juveniles"), 
    ("state of Mississippi", "failing to end", "unconscionable conditions"), 
    ("disturbing abuse of juveniles", "is at", "two state-run facilities"),
    ("unconscionable conditions", "are at", "two state-run facilities"),
    ("disturbing abuse of juveniles", "are called by", "federal officials"),
    ("unconscionable conditions", "are called by", "federal officials"),
],
# The Justice Department filed a civil rights lawsuit Thursday against the state of Mississippi, 
# alleging abuse of juvenile offenders at two state-run facilities.
[
    ("Justice Department", "filed", "civil rights lawsuit"),
    ("Justice Department", "filed", "Thursday"), 
    ("Justice Department", "filed against", "state of Mississippi"), 
    ("civil rights lawsuit", "alleging",  "abuse of juvenile offenders"),
    ("abuse of juvenile offenders", "is at", "two state-run facilities")
]),

# The Chelsea defender Marcel Desailly has been the latest to speak out.
([
    ("Marcel Desailly", "is", "Chelsea defender"),
    ("Marcel Desailly", "has been", "latest to speak out")
],
# Marcel Desailly, the France captain and Chelsea defender, believes the latter is true.
[
    ("Marcel Desailly", "is", "France captain"),
    ("Marcel Desailly", "is", "Chelsea defender"),
    ("Marcel Desailly", "believes", "latter is true")
]),

# She was the only woman in her unit and a member of Teamsters Local 995.
([
    ("She", "was", "only woman"),
    ("only woman", "was in", "unit"), 
    ("She", "was", "member"),
    ("member", "is of", "Teamsters Local 995")
],
# She was the only woman employed as a warehouse worker and heavy equipment operator and the only woman in her Teamsters local
[
    ("She", "was", "only woman"),
    ("only woman", "employed as", "warehouse worker"), 
    ("only woman", "employed as", "heavy equipment operator"), 
    ("only woman", "was in", "Teamsters local")
]),

# Special police detained Khodorkovsky early on Saturday in the Siberian city of Novosibirsk, 
# where his plane had made a refuelling stop.
([
    ("Special police", "detained", "Khodorkovsky"), 
    ("Special police", "detained early on", "Saturday"), 
    ("Special police", "detained in", "Novosibirsk"), 
    ("Novosibirsk", "is", "Siberian city"), 
    ("Khodorkovsky", "had", "plane"),
    ("plane", "had made", "refuelling stop"),
    ("refuelling stop", "was in", "Novosibirsk")
],
# Police detained Khodorkovsky early on Saturday when his jet made a refueling stop in the Siberian city of Novosibirsk.
[
    ("Police", "detained", "Khodorkovsky"), 
    ("Police", "detained early on", "Saturday"), 
    ("Special police", "detained in", "Novosibirsk"),
    ("Novosibirsk", "is", "Siberian city"), 
    ("Khodorkovsky", "had", "jet"),
    ("jet", "made", "refuelling stop"),
    ("refuelling stop", "was in", "Novosibirsk")
]),

# Sony Ericsson also said it would shut down its GSM/UMTS R&D center in Munich, Germany, to increase profitability.
([
    ("Sony Ericsson", "said about", "GSM/UMTS R&D center"),
    ("GSM/UMTS R&D center", "is of", "Sony Ericsson"),
    ("GSM/UMTS R&D center", "is in", "Munich"),
    ("Munich", "is in", "Germany"),
    ("Sony Ericsson", "would shut down", "GSM/UMTS R&D center"),
    ("Sony Ericsson", "would shut down to increase", "profitability"),
],
# Sony Ericsson also said it plans to close its R&D site in Munich, Germany, for GSM and UMTS handsets.
[
    ("Sony Ericsson", "said about", "R&D site"),
    ("R&D site", "is of", "Sony Ericsson"),
    ("R&D site", "is in", "Munich"),
    ("Munich", "is in", "Germany"),
    ("R&D site", "is for", "GSM and UMTS handsets"),
    ("Sony Ericsson", "plans to close", "R&D site"), 
]),

# But the country is scrambling to prevent it spreading to the vast countryside where most of its 1.3 billion people live.
([
    ('country', 'is scrambling to prevent', 'spreading'),
    ('country', 'has', '1.3 billion people'),
    ('spreading', 'is of', 'it'),
    ('spreading', 'is to', 'vast countryside'),
    ('most of people', 'live in', 'vast countryside'),
    ('most of people', 'is of', '1.3 billion people')
],
# China is scrambling to stop the disease from spreading to the countryside, where most of its 1.3 billion people live.
[
    ('China', 'is scrambling to stop', 'disease spreading'),
    ('disease spreading', 'is to', 'countryside'),
    ('China', 'has', '1.3 billion people'),
    ('most of people', 'live in', 'countryside'),
    ('most of people', 'is of', '1.3 billion people')
]),

# Kansas Department of Health and Environment records show there were 88 abortions performed on girls age 14 and younger last year.
([
    ('Department of Health and Environment records', 'is of', 'Kansas'),
    ('Department of Health and Environment records', 'show about', 'abortions'),
    ('abortions','were', '88'),
    ('abortions','were performed on', 'girls'),
    ('girls', 'were', 'age 14 and younger'),
    ('abortions','were performed', 'last year'),
],
# Statistics from the Kansas Department of Health and Environment show that 11,844 abortions were performed in the state last year.
[
    ('Department of Health and Environment records', 'is of', 'Kansas'),
    ('Statistics', 'are from', 'Department of Health and Environment'),
    ('Statistics', 'show about', 'abortions'),
    ('abortions','were', '11,844'),
    ('abortions', 'were performed in', 'state'),
    ('state', 'is', 'Kansas'),
    ('abortions', 'were performed', 'last year')
]),

# "The discovery that the MAP bug is present in the vast majority of Crohn's sufferers means 
# it is almost certainly causing the intestinal inflammation," it said in a statement.
([
    ('statement', 'said about', 'discovery'),
    ('discovery', 'is about', 'MAP bug'),
    ('MAP bug', 'is present in', 'vast majority of sufferers'),
    ('vast majority sufferers', 'are of', 'Crohn'),
    ('discovery', 'means about', 'MAP bug'),
    ('MAP bug', 'is almost certainly causing', 'intestinal inflammation')
],
# The researchers say that the fact the MAP bug is present in the vast majority of Crohns sufferers means 
# it is almost certainly causing the intestinal inflammation.
[
    ('researchers', 'say abount', 'MAP bug'),
    ('researchers', 'say', 'fact'),
    ('fact', 'is about', 'MAP bug'),
    ('MAP bug', 'is present in', 'vast majority of sufferers'),
    ('vast majority of sufferers', 'are of', 'Crohn'),
    ('fact', 'means about', 'MAP bug'),
    ('MAP bug', 'is almost certainly causing', 'intestinal inflammation')
]),

# The life expectancy for boys born in 2001 was 74.4 years, up two years since 1990.
([
    ('life expectancy', 'is for', 'boys'),
    ('boys', 'are born in', '2001'),
    ('life expectancy', 'was', '74.4 years'),
    ('life expectancy', 'up', 'two years'),
    ('life expectancy', 'up since', '1990')
],
# According to the report, average life expectancy has increased by nearly two years since 1990.
[
    ('report', 'is about', 'average life expectancy'),
    ('average life expectancy', 'has increased by', 'nearly two years'),
    ('average life expectancy', 'has increased since', '1990')
]),

# For the full 12-month period, high-speed cable modem connections increased by 49 percent.
([
    ('full period', 'is', '12-month'),
    ('connections', 'are of', 'high-speed cable modem'),
    ('connections', 'increased for', 'full period'),
    ('connections', 'increased by', '49 percent'),
],
# For the full year period ending June 30, 2003, high-speed lines increased by 45 percent.
[
    ('full year period', 'ending', 'June 30, 2003'),
    ('high-speed lines', 'increased by', '45 percent'),
    ('high-speed lines', 'increased for', 'full year period'),
]),

# We believe the report is fully consistent with what the courts have ruled ... 
# that the department's actions are fully within the law.
([
    ('we', 'believe about', 'report'),
    ('report', 'is', 'fully consistent'), 
    ('fully consistent', 'is with what', 'courts have ruled'),
    ('courts have ruled', 'is about', 'department\'s actions'),
    ('department\'s actions', 'are', 'fully within the law')
],
# Comstock said several federal courts have ruled that the detentions are fully within the law.
[
    ('Comstock', 'said about', 'several federal courts'),
    ('several federal courts', 'have ruled about', 'detentions'),
    ('detentions', 'are fully within', 'law')
]),

# Indeed, Mr. Weill, a self-described workaholic, said he planned to remain very involved in the company.
([
    ('Mr. Weill', 'is self-described as', 'workaholic'),
    ('Mr. Weill', 'said about', 'Mr. Weill'), 
    ('Mr. Weill', 'planned to remain', 'very involved'),
    ('Mr. Weill', 'planned to remain in', 'company')
],
# Still, Mr. Weill will remain very much a power at the company.
[
    ('Mr. Weill', 'will remain', 'very much a power'),
    ('Mr. Weill', 'will remain at', 'company')
]),

# Gregory Parseghian, a former investment banker, was appointed chief executive.
([
    ('Gregory Parseghian', 'is', 'former investment banker'),
    ('Gregory Parseghian', 'was appointed', 'chief executive')
],
# Greg Parseghian was appointed the new chief executive.
[
    ('Greg Parseghian', 'was appointed', 'new chief executive')
]),

# The report cites the marriage of the alleged operational commander of the Bali bombings, Mukhlas, to Farida, 
# a "highly cosmopolitan and well-educated young woman".
([
    ('report', 'cites about', 'Mukhlas'),
    ('Mukhlas', 'is', 'alleged operational commander'),
    ('alleged operational commander', 'is of', 'Bali bombings'),
    ('Mukhlas', 'has', 'marriage'),
    ('marriage', 'is to', 'Farida'),
    ('Farida', 'is', 'highly cosmopolitan'),
    ('Farida', 'is', 'well-educated'),
    ('Farida', 'is', 'young woman'),
],
# The report cites the marriage of the alleged operational commander of the Bali bombings, Mukhlas, 
# as an example of how JI uses marriage to grow.
[   
    ('report', 'cites about', 'Mukhlas'),
    ('Mukhlas', 'is', 'alleged operational commander'),
    ('alleged operational commander', 'is of', 'Bali bombings'),
    ('Mukhlas', 'has', 'marriage'),
    ('marriage', 'is', 'example'),
    ('example', 'is of how', 'JI uses marriage'),
    ('JI uses marriage', 'is to', 'grow')
]),

# The Cradle of Liberty Council isn't the first one to buck the national group's stance.
([
    ('Cradle of Liberty Council', 'is', 'not first one'),
    ('not first one', 'is to buck', 'national group\'s stance')
],
# Philadelphia's council is not the first to defy the national policy.
[
    ('council', 'is of', 'Philadelphia'),
    ('council', 'is', 'not first'),
    ('not first', 'is to defy', 'national policy')
]),

# "It''s absurd," Funny Cide's trainer Barclay Tagg said.
([
    ('Funny Cide', 'is', 'trainer'),
    ('trainer', 'is of', 'Barclay Tagg'),
    ('Funny Cide', 'said', 'it\'s absurd')
],
# Meanwhile, Funny Cide's trainer, Barclay Tagg, called the allegations "ridiculous."
[
    ('Funny Cide', 'is', 'trainer'),
    ('trainer', 'is of', 'Barclay Tagg'),
    ('Funny Cide', 'called about', 'allegations'),
    ('allegations', 'are', 'ridiculous')
]),

# Last year, Cuban officials said none of nearly two dozen nominated Cuban musicians received U.S. visas 
# on time to attend the Grammys in Los Angeles.
([
    ('Cuban officials', 'said', 'last year'),
    ('Cuban officials', 'said about', 'nominated Cuban musicians'),
    ('nominated Cuban musicians', 'were', 'nearly two dozen'),
    ('nominated Cuban musicians', 'did not receive', 'U.S. visas'),
    ('nominated Cuban musicians', 'did not receive', 'on time'),
    ('U.S. visas', 'were to attend', 'Grammys'),
    ('Grammys', 'were in', ' Los Angeles')
],
# Cuban officials said that last year none of about two dozen nominated Cuban musicians received U.S. visas 
# in time to attend the Latin Grammys.
[
    ('Cuban officials', 'said about', 'nominated Cuban musicians'),
    ('nominated Cuban musicians', 'were', 'about two dozen'),
    ('nominated Cuban musicians', 'did not receive', 'U.S. visas'),
    ('nominated Cuban musicians', 'did not receive', 'in time'),
    ('nominated Cuban musicians', 'did not receive', 'last year'),
    ('U.S. visas', 'were to attend', 'Latin Grammys'),
]),

# The American conservatives are clearly in the minority within the Episcopal Church.
([
    ('American conservatives', 'are in', 'minority'), 
    ('minority', 'is within', 'Episcopal Church')
],
# The letter indicates the Vatican's interest in bolstering conservatives within the Episcopal Church.
[
    ('letter', 'indicates about', 'Vatican\'s interest'),
    ('Vatican\'s interest', 'is in bolstering', 'conservatives'),
    ('Vatican\'s interest', 'is in bolstering within', 'Episcopal Church'),
]),

# The New York senator's new book, "Living History," appears a certain bestseller.
([
    ('New York senator', 'has', 'new book'),
    ('new book', 'is', 'Living History'),
    ('new book', 'appears', 'certain bestseller')
],
# Hillary Clinton, the New York senator and former first lady, has a book out Monday titled Living History.
[
    ('Hillary Clinton', 'is', 'New York senator'),
    ('Hillary Clinton', 'is', 'former first lady'),
    ('Hillary Clinton', 'has', 'book'),
    ('book', 'is out', 'Monday'),
    ('book', 'is titled', 'Living History')
]),

# "Canada is a small country, and it needs companies like this, deals like this."
([
    ('Canada', 'is', 'small country'),
    ('Canada', 'needs', 'companies like this'),
    ('Canada', 'needs', 'deals like this')
],
# A passionate nationalist, Mr. D'Alessandro said: "Canada is a small country, and we need more companies like this."
[
    ('Mr. D\'Alessandro', 'is', 'passionate nationalist'),
    ('Mr. D\'Alessandro', 'said about', 'Canada'),
    ('Canada', 'is', 'small country'),
    ('Mr. D\'Alessandro', 'said about', 'companies like this'),
    ('we', 'need more', 'companies like this'),
]),

# Police official S.K. Tonapi told Reuters at least 40 people had been killed and more than 100 wounded.
([
    ('S.K. Tonapi', 'is', 'Police official'),
    ('S.K. Tonapi', 'told', 'Reuters'),
    ('S.K. Tonapi', 'told about', 'people killed'),
    ('people killed', 'had been', 'at least 40'),
    ('S.K. Tonapi', 'told about', 'people wounded'),
    ('people wounded', 'had been', 'more than 100'),
],
# State interior ministry spokesman Vasant Pitke told Reuters that at least 42 people had been killed and 112 injured.
[
    ('Vasant Pitke', 'is', 'spokesman'),
    ('spokesman', 'is of', 'interior ministry'),
    ('interior ministry', 'is of', 'state'),
    ('Vasant Pitke', 'told', 'Reuters'),
    ('Vasant Pitke', 'told about', 'people killed'),
    ('people killed', 'had been', 'at least 42'),
    ('Vasant Pitke', 'told about', 'people injured'),
    ('people injured', 'had been', '112'),
]),

# "Jeremy's a good guy," Barber said, adding: "Jeremy is living the dream life of the New York athlete.
([
    ('Barber', 'said about', 'Jeremy'),
    ('Jeremy', 'is', 'good guy'),
    ('Jeremy', 'is living', 'dream life'),
    ('dream life', 'is of', 'New York athlete')
],
# He also said Shockey is "living the dream life of a New York athlete.
[
    ('He', 'said about', 'Shockey'),
    ('Shockey', 'is living', 'dream'),
    ('dream life', 'is of', 'New York athlete')
]),

# But Mitsubishi Tokyo Financial (JP:8306: news, chart, profile) declined 3,000 yen, or 0.65 percent, to 456,000 yen.
([
    ('Mitsubishi Tokyo Financial', 'is', 'JP:8306'),
    ('Mitsubishi Tokyo Financial', 'declined', '3,000 yen'),
    ('Mitsubishi Tokyo Financial', 'declined', '0.65 percent'),
    ('Mitsubishi Tokyo Financial', 'declined to', '456,000 yen'),
],
# Sumitomo Mitsui Financial (JP:8316: news, chart, profile) was down 2.5 percent at 198,000 yen.
[
    ('Sumitomo Mitsui Financial', 'is', 'JP:8316'),
    ('Sumitomo Mitsui Financial', 'was down', '2.5 percent'),
    ('Sumitomo Mitsui Financial', 'was down at', '198,000 yen')
]),

# About 1,557 genes on chromosome 6 are thought to be functional.
([
    ('genes', 'are on', 'chromosome 6'),
    ('genes', 'are', 'About 1,557'),
    ('genes', 'are thought to be', 'functional')
],
# The remaining 1,557 genes are believed to be all functional.
[
    ('1,557 genes', 'are', 'remaining'),
    ('1,557 genes', 'are believed to be', 'all functional')
]),

# In the second quarter, Anadarko now expects volume of 46 million BOE, down from 48 million BOE.
([
    ('Anadarko', 'expects in', 'second quarter'),
    ('Anadarko', 'expects', 'volume'),
    ('volume', 'is of', '46 million BOE'),
    ('volume', 'is down from', '48 million BOE')
],
# Production for the second quarter was cut to 46 million barrels from 48 million barrels.
[
    ('Production', 'is for', 'second quarter'),
    ('Production', 'was cut to', '46 million barrels'),
    ('Production', 'was cut from', '48 million barrels')
]),

# U.S. troops encountered no resistance during the five-hour sweep near Tikrit, 
# Saddam Hussein's hometown and the center of a region of Baath Party supporters
([
    ("U.S. troops", "encountered", "no resistance"),
    ("no resistance", "during", "five-hour sweep"),
    ("five-hour sweep", "was near", "Tikrit"),
    ("Tikrit", "is", "Saddam Hussein's hometown"),
    ("Tikrit", "is", "center of a region"),
    ("center of a region", "is of", "Baath Party supporters")
],
# Tikrit is Saddam Hussein's hometown and the region around it is known as a hotbed of Baath Party supporters 
# and former high-ranking Iraqi military officials.
[
    ("Tikrit", "is", "Saddam Hussein's hometown"),
    ("region", "is around", "Tikrit"),
    ("region", "is known as", "hotbed"),
    ("hotbed", "is of", "Baath Party supporters"),
    ("region", "is known as", "former high-ranking officials"),
    ("former high-ranking officials", "are of", "Iraqi military")
]),

# Miodrag Zivkovic, of the Liberal Alliance of Montenegro, won 31 percent of the vote 
# while the independent Dragan Hajdukovic got four percent.
([
    ("Miodrag Zivkovic", "is of", "Liberal Alliance of Montenegro"),
    ("Miodrag Zivkovic", "won", "31 percent"),
    ("31 percent", "was of", "vote"),
    ("Dragan Hajdukovic", "got", "four percent"),
    ("four percent", "was of", "vote"),
],
# Miodrag Zivkovic, the leader of the pro-independence opposition Liberal Alliance, came in second with 31 percent of the vote.
[
    ("Miodrag Zivkovic", "is", "leader"), 
    ("leader", "of", "Liberal Alliance"),
    ("Liberal Alliance", "is", "pro-independence opposition"),
    ("Miodrag Zivkovic", "came in", "second"),
    ("Miodrag Zivkovic", "has", "31 percent of the vote"),
    ("Liberal Alliance", "is", "pro-independence opposition")
]),

# In the year-ago period, Pearson posted a 26 million pre-tax profit.
([
    ("Pearson", "posted in", "year-ago period"),
    ("Pearson", "posted", "26 million"),
    ("26 million", "were of", "pre-tax profit")
],
# A year ago the firm posted a profit of 26 million pounds.
[
    ("firm", "posted", "year ago"),
    ("firm", "posted", "profit"),
    ("profit", "was of", "26 million pounds")
]),

# Through Thursday, Oracle said 34.75 million PeopleSoft shares had been tendered.
([
    ("Oracle", "said through", "Thursday"),
    ("Oracle", "said", "34.75 million shares"),
    ("34.75 million shares", "are of", "PeopleSoft"),
    ("34.75 million shares", "had been", "tendered"),
],
# Some 34.7 million shares have been tendered, Oracle said in a statement.
[   
    ("Oracle", "said about", "Some 34.7 million shares"),
    ("Some 34.7 million shares", "have been", "tendered"),
    ("Oracle", "said in", "statement")
]),

# Yucaipa owned Dominick's before selling the chain to Safeway in 1998 for $2.5 billion.
([
    ("Yucaipa", "owned", "Dominick's"),
    ("Dominick's", "was", "chain"),
    ("Yucaipa", "sold", "Dominick's"),
    ("Yucaipa", "sold to", "Safeway"),
    ("Yucaipa", "sold in", "1998"),
    ("Yucaipa", "sold for", "$2.5 billion")
],
# Yucaipa bought Dominick's in 1995 for $693 million and sold it to Safeway for $1.8 billion in 1998.
[
    ("Yucaipa", "bought", "Dominick's"),
    ("Yucaipa", "bought in", "1995"),
    ("Yucaipa", "bought for", "$693 million"),
    ("Yucaipa", "sold", "Dominick's"),
    ("Yucaipa", "sold to", "Safeway"),
    ("Yucaipa", "sold for", "$1.8 billion"),
    ("Yucaipa", "sold in", "1998"),
]),

# Graves reported from Albuquerque, Villafranca from Austin and Ratcliffe from Laredo.
([
    ("Graves", "reported from", "Albuquerque"),
    ("Villafranca", "reported from", "Austin"),
    ("Ratcliffe", "reported from", "Laredo")
],
# Pete Slover reported from Laredo and Gromer Jeffers from Albuquerque.
[
    ("Pete Slover", "reported from", "Laredo"),
    ("Gromer Jeffers", "reported from", "Albuquerque")
]),

# A 25 percent increase would raise undergraduate tuition to about $5,247 annually, including miscellaneous, campus-based fees.
([
    ("25 percent increase", "would raise", "undergraduate tuition"),
    ("undergraduate tuition", "would be raised to", "about $5,247 annually"),
    ("$5,247 annually", "includes", "miscellaneous"),
    ("$5,247 annually", "includes", "campus-based fees")
],
# The 25 percent hike takes annual UC undergraduate tuition to $4,794 and graduate fees to $5,019.
[
    ("25 percent hike", "takes", "UC undergraduate tuition"),
    ("UC undergraduate tuition", "is", "annual"),
    ("UC undergraduate tuition", "is taken to", "$4,794"),
    ("25 percent hike", "takes", "graduate fees"),
    ("graduate fees", "are taken to", "$5,019")
]),

# Authorities said the scientist properly quarantined himself at home after he developed SARS symptoms Dec. 10. 
([
    ("Authorities", "said about", "scientist"), 
    ("scientist", "properly quarantined", "scientist"),
    ("scientist", "properly quarantined", "at home"),
    ("scientist", "properly quarantined when developed", "symptons"),
    ("symptons", "were of", "SARS"),
    ("symptons", "were on", "Dec. 10"),
],
# The scientist also quarantined himself at home as soon as he developed SARS symptoms, officials said.
[
    ("officials", "said about", "scientist"), 
    ("scientist", "quarantined", "scientist"),
    ("scientist", "quarantined at", "home"),
    ("scientist", "quarantined as soon as developed", "symptons"),
    ("symptons", "were of", "SARS")
]),

# The support will come as a free software upgrade called WebVPN for current customers that have support contracts.
([
    ("support", "will come as", "free software upgrade"),
    ("free software upgrade", "is called", "WebVPN"),
    ("support", "is for", "current customers"),
    ("current customers", "have", "contracts"),
    ("contracts", "are of", "support")
],
# The upgrade will be available as a free download for current customers with SmarNet support in January 2004.
[
    ("upgrade", "will be available as", "free download"),
    ("free download", "is for", "current customers"),
    ("current customers", "have", "support"),
    ("support", "is of", "SmarNet"),
    ("upgrade", "will be available in", "January 2004")
]),

# Hilsenrath and Klarman each were indicted on three counts of securities fraud.
([
    ("Hilsenrath", "was indicted on", "three counts"), 
    ("Hilsenrath", "was indicted of", "securities fraud"),
    ("Klarman", "was indicted on", "three counts"),
    ("Klarman", "was indicted of", "securities fraud"),
],
# Klarman was charged with 16 counts of wire fraud.
[
    ("Klarman", "was charged with", "16 counts"),
    ("16 counts", "are of", "wire fraud")
]),

# The new sensor -- dubbed CANARY for ''cellular analysis and notification of antigen risks and yields'' -- 
# hijacks this natural process with two important changes.
([
    ("new sensor", "is dubbed", "CANARY"),
    ("CANARY", "stands for", "cellular analysis and notification of antigen risks and yields"),
    ("new sensor", "hijacks", "natural process"),
    ("natural process", "has", "two changes"),
    ("changes", "are", "important")
],
# The team has named the sensor Canary, for cellular analysis and notification of antigen risks and yields.
[
    ("team", "has named", "the sensor"),
    ("sensor", "has been named", "Canary"),
    ("Canary", "stands for", "cellular analysis and notification of antigen risks and yields")
]),

# One, Fort Carson-based Sgt. Ernest Bucklew, 33, had been on his way home to attend his mother's funeral in Pennsylvania.
([
    ("Ernest Bucklew", "is", "Sgt."),
    ("Ernest Bucklew", "is", "33"),
    ("Ernest Bucklew", "is based at", "Fort Carson"),
    ("Ernest Bucklew", "had been on", "way home"), 
    ("Ernest Bucklew", "to attend", "funeral"),
    ("funeral", "is of", "mother"),
    ("mother", "was of", "Ernest Bucklew"),
    ("funeral", "is in", "Pennsylvania")
],
# Sgt. Ernest Bucklew, 33, was coming home from Iraq to bury his mother in Pennsylvania.
[
    ("Ernest Bucklew", "is", "Sgt."),
    ("Ernest Bucklew", "is", "33"),
    ("Ernest Bucklew", "was coming", "home"), 
     ("Ernest Bucklew", "was coming from", "Iraq"),
    ("Ernest Bucklew", "was coming to bury", "mother"),
    ("mother", "was of", "Ernest Bucklew"),
    ("mother", "is in", "Pennsylvania")
]),

# Waksal has pleaded guilty to securities fraud and is to be sentenced next week.
([
    ("Waksal", "has pleaded", "guilty"),
    ("guilty", "is to", "securities fraud"),
    ("Waksal", "is to be sentenced", "next week")
],
# Waksal pleaded guilty to insider trading charges last year, and he is scheduled to be sentenced June 10.
[
    ("Waksal", "pleaded", "guilty"),
    ("guilty", "is to", "insider trading charges"),
    ("Waksal", "pleaded", "last year"),
    ("Waksal", "is scheduled to be sentenced on", "June 10")
]),

# The device plays Internet radio streams and comes with a 30-day trial of RealNetworks' Rhapsody music service.
([
    ("The device", "plays", "Internet radio streams"),
    ("The device", "comes with", "30-day trial"),
    ("30-day trial", "is for", "Rhapsody"),
    ("Rhapsody", "is of", "RealNetworks"),
    ("Rhapsody", "is", "music service"),
],
# The product also streams Internet radio and comes with a 30-day free trial for 
# RealNetworks' Rhapsody digital music subscription service.
[
    ("product", "streams", "Internet radio"),
    ("product", "comes with", "a 30-day free trial"),
    ("30-day free trial", "is for", "Rhapsody"),
    ("Rhapsody", "is of", "RealNetworks"),
    ("Rhapsody", "is", "subscription service"),
    ("subscription service", "is of", "digital music")
]),

# The dollar fell as low as $1.1624 per euro from $1.1486 on Friday, and traded at $1.1594 at 10:15 a.m. in London.
([
    ("dollar", "fell as low as", "$1.1624 per euro"),
    ("dollar", "fell from", "$1.1486 on Friday"),
    ("dollar", "traded at", "$1.1594"),
    ("dollar", "traded at",  "10:15 a.m."), 
    ("dollar", "traded in", "London")
],
# The dollar dropped to $1.1564 per euro at 7:30 a.m. in London from $1.1486 on Friday.
[
    ("dollar", "dropped to", "$1.1564 per euro"),
    ("dollar", "dropped at", "7:30 a.m."),
    ("dollar", "dropped in", "London"),
    ("dollar", "dropped from", "$1.1486"),
    ("dollar", "dropped on", "Friday")
]),

# During the hearing, Morales expressed "sincere regrets and remorse" for his actions.
([
    ("Morales", "expressed", "sincere regrets"),
    ("Morales", "expressed", "sincere remorse"),
    ( "sincere regrets", "were expressed for", "his actions"),
    ( "sincere remorse", "was expressed for", "his actions")
],
# Morales, who pleaded guilty in July, expressed "sincere regret and remorse" for his crimes.
[   
    ("Morales", "pleaded", "guilty"),
    ("Morales", "pleaded in", "July"),
    ("Morales", "expressed", "sincere regret"),
    ("Morales", "expressed", "sincere remorse"),
    ("sincere regret", "was expressed for", "his crimes"),
    ("sincere remorse", "was expressed for", "his crimes"),
]),

# Site Finder has been visited 65 million times since its introduction, Galvin said.
([
    ("Galvin", "said about", "Site Finder"),
    ("Site Finder", "has been visited", "65 million times"),
    ("65 million times", "occurred since", "introduction"),
],
# Through Sunday, Sept. 21, Site Finder has been visited over 65 million times by Internet users.
[
    ("Site Finder", "has been visited", "over 65 million times"),
    ("over 65 million times", "occurred through", "Sunday, Sept. 21"),
    ("Site Finder", "has been visited by", "Internet users")
]),

# According to SunnComm's Peter Jacobs, "MediaMax performs exactly as 'advertised' to the companies who purchased it.
([
    ("Peter Jacobs", "is of", "SunnCom"),
    ("Peter Jacobs", "said about", "MediaMax"),
    ("MediaMax", "performs", "exactly as 'advertised'"),
    ("exactly as 'advertised'", "is to", "companies who purchased it")
],
# "MediaMax performs EXACTLY as "advertised" to the companies who purchased it," Jacobs said in the statement.
[
    ("Jacobs", "said about", "MediaMax"),
    ("Jacobs", "said in", "statement"),
    ("MediaMax", "performs", "EXACTLY as 'advertised'"),
    ("EXACTLY as 'advertised'", "is to", "companies who purchased it"),
]),

# He was tracked to Atlanta where he was arrested on Tuesday night.
([
    ("He", "was tracked to", "Atlanta"),
    ("He", "was arrested in", "Atlanta"),
    ("He", "was arrested on", "Tuesday night")
],
# He was arrested in Atlanta, Georgia, on Monday night by police acting on a tip-off.
[
    ("He", "was arrested in", "Atlanta, Georgia"),
    ("Atlanta", "is in", "Georgia"),
    ("He", "was arrested on", "Monday night"),
    ("He", "was arrested by", "police"),
    ("police", "acted on", "tip-off")
]),

# The Bush administration blames Hussein loyalists and foreign Muslim militants who have entered Iraq 
# to fight U.S. troops for the wave of bombings and guerrilla attacks.
([
    ("Bush administration", "blames", "Hussein loyalists"),
    ("Bush administration", "blames", "foreign Muslim militants"),
    ("foreign Muslim militants", "have entered", "Iraq"),
    ("foreign Muslim militants", "have entered to", "fight U.S. troops"),
    ("Hussein loyalists", "are blamed for", "wave of bombings"),
    ("Hussein loyalists", "are blamed for", "wave of guerrilla attacks"),
    ("foreign Muslim militants", "are blamed for", "wave of bombings"),
    ("foreign Muslim militants", "are blamed for", "wave of guerrilla attacks")
],
# The Bush administration blames the wave of bombings and guerrilla attacks on Saddam loyalists 
# and foreign Muslim militants who have entered Iraq to fight U.S. troops.
[
    ("Bush administration", "blames", "wave of bombings"),
    ("Bush administration", "blames", "wave of guerrilla attacks"),
    ("wave of bombings", "is blamed on", "Saddam loyalists"),
    ("wave of guerrilla attacks", "is blamed on", "Saddam loyalists"),
    ("wave of bombings", "is blamed on", "foreign Muslim militants"),
    ("wave of guerrilla attacks", "is blamed on", "foreign Muslim militants"),
    ("foreign Muslim militants", "have entered", "Iraq"),
    ("foreign Muslim militants", "have entered to", "fight U.S. troops")
]),

# It later emerged that he had broken his right thigh and bones in his right wrist and elbow.
([
    ("he", "had broken", "right thigh"),
    ("he", "had broken", "bones in his right wrist"),
    ("he", "had broken", "bones in his right elbow"),
],
# Tour doctors later confirmed that he had broken his right leg near the hip and also sustained wrist and elbow fractures.
[
    ("Tour doctors", "confirmed", "later"),
    ("Tour doctors", "confirmed", "he"),
    ("he", "had broken", "right leg"),
    ("right leg", "is near", "hip"),
    ("he", "had sustained", "wrist fractures"),
    ("he", "had sustained", "elbow fractures")
]),

# The Senate agreed Tuesday to lift a 10-year-old ban on the research and development of low-yield nuclear weapons.
([
    ("Senate", "agreed to lift", "ban"),
    ("ban", "is", "10-year-old"),
    ("ban", "is on", "research and development"),
    ("research and development", "are of", "low-yield nuclear weapons")
],
# Both the House and Senate bills would end the ban on research and development of low-yield nuclear weapons.
[
    ("House bill", "would end", "ban"),
    ("Senate bill", "would end", "ban"),
    ("ban", "is on", "research and development"),
    ("research and development", "are of", "low-yield nuclear weapons")
]),

# Some 95 million Americans -- half of all households -- invest in mutual funds.
([
    ("Some 95 million Americans", "invest in", "mutual funds"),
    ("Some 95 million Americans", "are", "half of all households")
],
# About half of all U.S. households have money in mutual funds.
[
    ("About half of all U.S. households", "have", "money"), 
    ("money", "is in", "mutual funds")
]),

# The House has passed prescription-drug legislation in the last two sessions, but the Senate has failed to do so.
([
    ("House", "has passed", "prescription-drug legislation"),
    ("prescription-drug legislation", "was passed in", "last two sessions"),
    ("Senate", "has failed to pass", "prescription-drug legislation")
],
# The House has passed bills the past two Congresses, but the Senate has not.
[
    ("House", "has passed", "bills"),
    ("bills", "were passed in", "past two Congresses"),
    ("Senate", "has not passed", "bills")
]),

# The elderly and those with weakened immune systems are also urged to protect against mosquito bites.
([
    ("elderly", "are urged to protect against", "mosquito bites"),
    ("those with weakened immune systems", "are urged to protect against", "mosquito bites")
],
# But for the elderly and those with weakened immune systems, it can be fatal.
[
    ("it", "can be", "fatal"),
    ("it", "can be fatal for", "the elderly"),
    ("it", "can be fatal for", "those with weakened immune systems")
]),

# Ms Lafferty's lawyer, Thomas Ezzell, told a Kentucky newspaper: "My understanding of this is that there is 
# a lower percentage of successful impregnations with frozen.
([
    ("Ms Lafferty", "has", "lawyer"),
    ("lawyer", "is", "Thomas Ezzell"),
    ("Thomas Ezzell", "told", "Kentucky newspaper"),
    ("Thomas Ezzell", "told about", "frozen"),
    ("Thomas Ezzell", "has", "understanding"),
    ("understanding", "is about", "frozen"),
    ("frozen", "has", "lower percentage"),
    ("lower percentage", "is of", "successful impregnations"),
    ("successful impregnations", "are with", "frozen")
],
# "My understanding of this is that there is a lower percentage of successful impregnations with frozen," Ezzell said.
[
    ("Ezzell", "said about", "frozen"),
    ("Thomas Ezzell", "has", "understanding"),
    ("understanding", "is about", "frozen"),
    ("frozen", "has", "lower percentage"),
    ("lower percentage", "is of", "successful impregnations"),
    ("successful impregnations", "are with", "frozen")
]),

# Klarman was arrested by FBI agents in the Hamptons, an exclusive summer resort enclave east of New York City.
([
    ("Klarman", "was arrested by", "FBI agents"),
    ("Klarman", "was arrested in", "Hamptons"),
    ("Hamptons", "is", "exclusive summer resort enclave"), 
    ("Hamptons", "is at", "east of New York City")
],
# Klarman was arrested by FBI agents Monday morning at his home in New York.
[
    ("Klarman", "was arrested by", "FBI agents"),
    ("Klarman", "was arrested on", "Monday morning"),
    ("Klarman", "was arrested at", "home"), 
    ("home", "is in", "New York")
]),

# The bishop told police he thought he had hit a dog or a cat or that someone had thrown a rock at his vehicle.
([
    ("bishop", "told", "police"),
    ("bishop", "thought", "he had hit a dog"),
    ("bishop", "thought", "he had hit a cat"),
    ("the bishop", "thought", "someone had thrown a rock"),
    ("someone had thrown a rock", "was at", "his vehicle")
],
# Bishop O'Brien, aged 67, had told police he thought he had hit a dog or cat.
[
    ("O'Brien", "is", "Bishop"),
    ("O'Brien", "is", "aged 67"),
    ("O'Brien", "had told", "police"),
    ("O'Brien", "thought", "he had hit a dog"),
    ("O'Brien", "thought", "he had hit a cat"),
]),

# A promotional poster, complete with countdown dial, reminds readers of the upcoming release 
# of "Harry Potter and the Order of the Phoenix."
([
    ("promotional poster", "is completed with", "countdown dial"),
    ("promotional poster", "reminds", "readers"),
    ("promotional poster", "reminds", "upcoming release"),
    ("upcoming release", "is of", "Harry Potter and the Order of the Phoenix"),
    
],
# The crates are full of hardback copies of "Harry Potter and the Order of the Phoenix."
[
    ("crates", "are full of", "hardback copies"),
    ("hardback copies", "are of", "Harry Potter and the Order of the Phoenix")
]),

# "Further testing is still under way, but at this stage, given the early detection, 
# the outlook in such instances would be positive," the specialist said yesterday.
([
    ("the specialist", "said", "Further testing is still under way"),
    ("the specialist", "said", "the outlook in such instances would be positive"),
    ("the outlook", "is positive", "given the early detection")
],
# "But at this stage, given the early detection, the outlook in such instances would be positive," he said.
[
    ("he", "said about", "outlook"),
    ("outlook", "is at", "stage"),
    ("outlook", "is in", "such instances"),
    ("outlook", "would be", "positive"),
    ("positive", "is given", "early detection")
]),

# In morning trading, the Dow Jones industrial average was up 40.12, or 0.5 percent, at 8,571.69, having fallen 51 points Monday.
([
    ("Dow Jones industrial average", "was up in", "morging trading"),
    ("Dow Jones industrial average", "was up", "40.12"),
    ("Dow Jones industrial average", "was up", "0.5 percent"),
    ("Dow Jones industrial average", "was up at", "8,571.69"),
    ("Dow Jones industrial average", "having fallen", "51 points Monday")
],
# In New York, the Dow Jones industrial average a gauge of 30 blue chip stocks was up 3.29 points or 0.04 per cent to 8,585.97.
[
    ("Dow Jones industrial average", "was up in", "New York"),
    ("Dow Jones industrial average", "is", "gauge"), 
    ("gauge", "is of", "30 blue chip stocks"),
    ("Dow Jones industrial average", "was up", "3.29 points"),
    ("Dow Jones industrial average", "was up", "0.04 per cent"),
    ("Dow Jones industrial average", "was up at", "8,585.97"),
]),

# Rich media doubled its share, increasing from 3% in Q2 2002 to 6% in Q2 2003.
([
    ("Rich media", "doubled", "share"),
    ("share", "increasing from", "3%"),
    ("3%", "was in", "Q2 2002"),
    ("share", "increasing to", "6%"),
    ("6%", "was in", "Q2 2003")
],
# Rich Media interactive ad formats doubled their share from 3% in second quarter of 2002, to 6% in the second quarter of 2003.
[
    ("Rich Media", "has", "interactive ad formats"),   
    ("interactive ad formats", "doubled", "share"),
    ("share", "doubled from", "3%"),
    ("3%", "was in", "second quarter of 2002"),
    ("share", "doubled to", "6%"),
    ("6%", "was in", "second quarter of 2003")
]),

# It will take time to oust die-hard remnants of Saddam Hussein's deposed regime in Iraq, 
# Defense Secretary Donald H. Rumsfeld said Tuesday.
([
    ("Donald H. Rumsfeld", "is", "Defense Secretary"),
    ("Donald H. Rumsfeld", "said", "Tuesday"),
    ("Donald H. Rumsfeld", "said about", "deposed regime"),
    ("deposed regime", "is in", "Iraq"),
    ("deposed regime", "is of", "Saddam Hussein"),
    ("deposed regime", "has", "die-hard remnants"),
    ("time", "will be taken to oust", "die-hard remnants"),
],
# Defense Secretary Donald H. Rumsfeld said Tuesday it will take time to locate die-hard remnants of 
# Saddam Hussein's deposed regime in Iraq.
[
    ("Donald H. Rumsfeld", "is", "Defense Secretary"),
    ("Donald H. Rumsfeld", "said", "Tuesday"),
    ("Donald H. Rumsfeld", "said about", "deposed regime"),
    ("deposed regime", "is of", "Saddam Hussein"),
    ("deposed regime", "is in", "Iraq"),
    ("deposed regime", "has", "die-hard remnants"),
    ("time", "will be taken to locate", "die-hard remnants"),
]),

# Sayliyah was the command base for the Iraq war, but Central Command sent hundreds who ran the war back home to Tampa, Florida.
([
    ("Sayliyah", "was", "command base"),
    ("command base", "was for", "Iraq war"),
    ("Central Command", "sent", "hundreds"),
    ("Central Command", "sent to", "Tampa"),
    ("Tampa", "is in", "Florida"),
    ("hundreds", "ran", "Iraq war"),
    ("hundres", "are to back", "home"),
],
# As Sayliyah was the command base for the Iraq war, but hundreds who ran the war have returned to the United States.
[
    ("Sayliyah", "was", "command base"),
    ("command base", "was for", "Iraq war"),
    ("hundreds", "ran", "Iraq war",),
    ("hundreds", "have returned to", "United States")
]),

# SCO says the pricing terms for a license will not be announced for weeks.
([
    ("SCO", "says about", "pricing terms"), 
    ("pricing terms", "are for", "license"),
    ("pricing terms", "will not be announced for", "weeks")
],
# Details on pricing will be announced within a few weeks, McBride said.
[
    ("McBride", "said about", "details on pricing"),
    ("details on pricing", "will be announced", "within a few weeks"),
]),

# Sources within the racing industry have told the Daily Bulletin that Fontana will get a second NASCAR race 
# on Labor Day weekend starting next season.
([
    ("Sources", "are within", "racing industry"),
    ("Sources", "told", "Daily Bulletin"),
    ("Sources", "told about", "Fontana"),
    ("Fontana", "will get", "second NASCAR race"),
    ("second NASCAR race", "starting", "next season"),
    ("second NASCAR race", "will be on", "Labor Day weekend")
],
# Sources in the racing industry said Fontana will get a second NASCAR race on Labor Day weekend starting next season.
[
    ("Sources", "are in", "racing industry"),
    ("Sources", "said about", "Fontana"),
    ("Fontana", "will get", "second NASCAR race"),
    ("second NASCAR race", "starting", "next season"),
    ("second NASCAR race", "will be on", "Labor Day weekend")
]),

# The Dow Jones industrial average .DJI ended up 56.79 points, or 0.67 percent, at 8,588.36 -- its highest level since January 17.
([
    ("DJI", "is", "Dow Jones industrial average"),
    ("Dow Jones industrial average", "ended up", "56.79 points"),
    ("Dow Jones industrial average", "ended up", "0.67 percent"),
    ("Dow Jones industrial average", "ended up at", "8,588.36"),
    ("8,588.36", "is", "highest level"), 
    ("highest level", "is since", "January 17")
],
# The Dow Jones Industrial Average ($DJ: news, chart, profile) rose 56 points, or 0.7 percent, to 8,588.
[
    ("DJ", "is", "Dow Jones industrial average"),
    ("Dow Jones Industrial Average", "rose", "56 points"),
    ("Dow Jones Industrial Average", "rose", "0.7 percent"),
    ("Dow Jones Industrial Average", "rose to", "8,588")
]),

# Dennehy, who transferred to Baylor last year after getting kicked off the University of New Mexico Lobos for temper tantrums, 
# had begun to read the Bible daily.
([
    ("Dennehy", "transferred to", "Baylor"),
    ("Dennehy", "transferred", "last year"),
    ("Dennehy", "transferred after", "getting kicked off"),
    ("Dennehy", "getting kicked off", "University of New Mexico Lobos"),
    ("Dennehy", "getting kicked off for", "temper tantrums"),
    ("Dennehy", "had begunn to read daily", "Bible")
],
# Dennehy, who transferred to Baylor last year after getting kicked off the University of New Mexico Lobos for 
# temper tantrums, became a born-again Christian in June 2002.
[
    ("Dennehy", "transferred to", "Baylor"),
    ("Dennehy", "transferred", "last year"),
    ("Dennehy", "transferred after", "getting kicked off"),
    ("Dennehy", "getting kicked off", "University of New Mexico Lobos"),
    ("Dennehy", "getting kicked off for", "temper tantrums"),
    ("Dennehy", "became", "born-again Christian"),
    ("born-again Christian", "was in", "June 2002")
]),

# Bashir felt he was being tried by opinion not on the facts, Mahendradatta told Reuters.
([
    ("Mahendradatta", "told", "Reuters"),
    ("Mahendradatta", "told about", "Bashir"),
    ("Bashir", "felt was being tried by", "opinion"),
    ("Bashir", "felt was being tried not on", "facts"),
],
# Bashir also felt he was being tried by opinion rather than facts of law, he added.
[   
    ("Bashir", "added about", "Bashir"),
    ("Bashir", "felt was being tried by", "opinion"),
    ("Bashir", "felt was not being tried on", "facts of law")
]),

# Schofield got Toepfer to admit on cross-examination that she ignored many of O'Donnell's suggestions and projects.
([
    ("Schofield", "got from", "Toepfer"),
    ("Schofield", "got on", "cross-examination"),
    ("Toepfer", "was on", "cross-examination"),
    ("Toepfer", "admitted she ignored", "many suggestions"),
    ("Toepfer", "admitted she ignored", "many projects"),
    ("many suggestions", "were of", "O'Donnell"),
    ("many projects", "were of", "O'Donnell")
],
# But under cross-examination by O'Donnell's attorney, Lorna Schofield, 
# Toepfer conceded she had ignored many of O'Donnell's suggestions and projects.
[
    ("Lorna Schofield", "is", "attorney"),
    ("attorney", "is of", "O'Donnell"),
    ("Toepfer", "was under", "cross-examination"),
    ("cross-examination", "was by", "Lorna Schofield"),
    ("Toepfer", "conceded she had ignored", "many suggestions"),
    ("Toepfer", "conceded she had ignored", "many projects"),
    ("many suggestions", "were of", "O'Donnell"),
    ("many projects", "were of", "O'Donnell")
]),

# In that case, the court held that Cincinnati had violated the First Amendment in banning only 
# the advertising pamphlets in the interest of aesthetics.
([
    ("court", "held in", "that case"),
    ("court", "held about", "Cincinnati"),
    ("Cincinnati", "had violated", "First Amendment"),
    ("Cincinnati", "banning only", "advertising pamphlets"),
    ("Cincinnati", "banning only in", "interest of aesthetics")
],
# In that case, the court held that the city of Cincinnati had violated the First Amendment in banning, 
# in the interest of aesthetics, only the advertising pamphlets.
[
    ("court", "held in", "that case"),
    ("court", "held about", "city of Cincinnati"),
    ("city of Cincinnati", "had violated", "First Amendment"),
    ("city of Cincinnati", "banning in", "interest of aesthetics"),
    ("city of Cincinnati", "banning only", "advertising pamphlets")
]),

# Box cutters were used as a weapon by the Sept. 11, 2001, hijackers and have since been banned as carry-on items.
([
    ("Box cutters", "were used as", "weapon"),
    ("Box cutters", "were used in", "Sept. 11, 2001"), 
    ("Box cutters", "were used by", "hijackers"),
    ("Box cutters", "have been banned as", "carry-on items"),
    ("Box cutters", "have been banned since", "Sept. 11, 2001")
],
# Box cutters were the weapons used by the 19 hijackers in the Sept. 11, 2001, attacks.
[
    ("Box cutters", "were", "weapons"),
    ("Box cutters", "were used by", "19 hijackers"),
    ("Box cutters", "were used in", "attacks"),
    ("attacks", "were on", "Sept. 11, 2001")
]),

# On July 22, Moore announced he would appeal the case directly to the U.S. Supreme Court.
([
    ("Moore", "announced about", "Moore"),
    ("Moore", "announced", "on July 22"),
    ("Moore", "would appeal", "case"),
    ("Moore", "would appeal directly to", "U.S. Supreme Court"),
],
# Moore of Alabama says he will appeal his case to the nation's highest court.
[   
    ("Moore", "is from", "Alabama"),
    ("Moore", "says about", "Moore"), 
    ("Moore", "will appeal", "case"),
    ("Moore", "will appeal to", "highest court"),
    ("highest court", "is of", "nation")
]),

# Southwest said its traffic was up 4.6 percent in the quarter, and it ended the quarter with $2.2 billion in cash.
([
    ("Southwest", "said about", "traffic"),
    ("traffic", "was of", "Southwest"),
    ("traffic", "was up", "4.6 percent"), 
    ("4.6 percent", "was up in", "quarter"),
    ("Southwest", "ended with", "$2.2 billion in cash"),
    ("Southwest", "ended", "quarter") 
],
# Southwest said its traffic was up 4.6 percent in the quarter on a capacity increase of 4.2 percent.
[
    ("Southwest", "said about", "traffic"),
    ("traffic", "was of", "Southwest"),
    ("traffic", "was up", "4.6 percent"),
    ("4.6 percent", "was up in", "quarter"),
    ("traffic", "was up on", "capacity increase"),
    ("capacity increase", "was of", "4.2 percent")
]),

# Four versions of Windows operating systems are targeted: Windows NT, Windows 2000, Windows XP and Windows Server 2003.
([  
    ("Four versions", "are of", "Windows operating systems"),
    ("Four versions", "are", "targeted"),
    ("targeted", "is", "Windows NT"),
    ("targeted", "is", "Windows 2000"),
    ("targeted", "is", "Windows XP"),
    ("targeted", "is", "Windows Server 2003")
],
# The new worm affects these Windows systems: 2000, XP, NT 4.0 and Server 2003.
[
    ("new worm", "affects", "Windows systems"),
    ("new worm", "affects", "2000"),
    ("new worm", "affects", "XP"),
    ("new worm", "affects", "NT 4.0"),
    ("new worm", "affects", "Server 2003")
]),

# Shares of McDonald's Corp. and Wendy's International Inc. continued a modest run-up on the New York Stock Exchange Monday.
([
    ("Shares", "are of", "McDonald's Corp."),  
    ("Shares", "are of", "Wendy's International Inc."),
    ("Shares", "continued", "modest run-up"),
    ("modest run-up", "was on", "New York Stock Exchange"),
    ("modest run-up", "was on", "Monday")
],
# Shares of McDonald's and Wendy's continued their recent recovery Monday, rising more than 1 percent on the 
# New York Stock Exchange in afternoon trade.
[
    ("Shares", "are of", "McDonald's"),  
    ("Shares", "are of", "Wendy's"),
    ("Shares", "continued", "recent recovery"),
    ("recent recovery", "was on", "Monday"),
    ("Shares", "rising", "more than 1 percent"),
    ("Shares", "rising on", "New York Stock Exchange"),
    ("Shares", "rising in", "afternoon trade")
]),

# He playfully chided the Senate's "little bitty tax relief plan."
([
    ("He", "playfully chided", "little bitty plan"),
    ("little bitty plan", "is of", "Senate"),
    ("little bitty plan", "is for", "tax relief")
],
# We don't need a little bitty tax relief plan.
[
    ("We", "don't need", "little bitty plan"),
    ("little bitty plan", "is for", "tax relief")
]),

# Looking to buy the latest Harry Potter?
([
    ("are you", "looking to buy", "latest Harry Potter")
],
# Harry Potter's latest wizard trick?
[
    ("what", "is", "latest wizard trick"),
    ("latest wizard trick", "is of", "Harry Potter")
]),

# MediaQ's customers include major handheld makers Mitsubishi, Siemens, Palm, Sharp, Philips, Dell and Sony.
([
    ("MediaQ", "has", "customers"),
    ("customers", "include", "major handheld makers"),
    ("major handheld makers", "include", "Mitsubishi"),
    ("major handheld makers", "include", "Siemens"),
    ("major handheld makers", "include", "Palm"),
    ("major handheld makers", "include", "Sharp"),
    ("major handheld makers", "include", "Philips"),
    ("major handheld makers", "include", "Dell"),
    ("major handheld makers", "include", "Sony")
],
# Nvidia will take advantage of MediaQ customers, which include such players as Siemens AG, Sharp, Philips, 
# Dell, Mitsubishi and Sony Corp.
[
    ("Nvidia", "will take advantage of", "customers"),
    ("customers", "ar of", "MediaQ"),
    ("customers", "include", "players"),
    ("players", "include", "Siemens AG"),
    ("players", "include", "Sharp"),
    ("players", "include", "Philips"),
    ("players", "include", "Dell"),
    ("players", "include", "Mitsubishi"),
    ("players", "include", "Sony Corp.")
]),

# Aventis, based in Strasbourg, France, is one of a handful of companies that still make the flu vaccine.
([
    ("Aventis", "is based in", "Strasbourg"),
    ("Strasbourg", "is in", "France"),
    ("Aventis", "is one of", "handful of companies"),
    ("handful of companies", "still make", "flu vaccine")
],
# Aventis, based in Strasbourg, France, is one of the leading producers of the vaccine 
# and one of a handful of companies that still make it.
[
    ("Aventis", "is based in", "Strasbourg"),
    ("Strasbourg", "is in", "France"),
    ("Aventis", "is one of", "leading producers"),
    ("leading producers", "are of", "vaccine"),
    ("Aventis", "is one of", "handful of companies"),
    ("handful of companies", "still make", "vaccine")
]),

# Michael Bloomberg, NYC Mayor: "I'm gonna try march with a number of different groups.
([
    ("Michael Bloomberg", "is", "NYC Mayor"),
    ("Michael Bloomberg", "is gonna try march with", "different groups"),
    ("different groups", "are", "a number")
],
# "I'm going to try to march with a number of different groups," Bloomberg said.
[
    ("Bloomberg", "said about", "Bloomberg"),
    ("Bloomberg", "is going to try to march with", "different groups"),
    ("different groups", "are", "a number")
]),

# The attack seemed similar to others staged near foreign compounds in Riyadh on May 12.
([
    ("attack", "seemed similar to", "others attacks"),
    ("others attacks", "staged near", "foreign compounds"),
    ("others attacks", "staged in", "Riyadh"),
    ("others attacks", "staged on", "May 12")
],
# he attack seemed similar to attacks staged near foreign compounds in Riyadh on May 12, 
# for which officials have also blamed al-Qaida.
[
    ("attack", "seemed similar to", "attacks"),
    ("attacks", "staged near", "foreign compounds"),
    ("attacks", "staged in", "Riyadh"),
    ("attacks", "staged on", "May 12"),
    ("al-Qaida", "blamed for", "attacks"),
    ("officials", "blamed", "al-Qaida")
]),

# "We put a lot of effort and energy into improving our patching process, 
# probably later than we should have and now we're just gaining incredible speed.
([
    ("We", "put", "lot of effort"),
    ("We", "put", "lot of energy"),
    ("lot of effort", "improving", "patching process"),
    ("lot of energy", "improving", "patching process"),
    ("We", "are probably later in", "patching process"),
    ("We", "are probably later than", "we should have"),
    ("We", "are just gaining", "incredible speed")
],
# "We've put a lot of effort and energy into improving our patching progress, probably later than we should have.
[
    ("We", "have put", "lot of effort"),
    ("We", "have put", "lot of energy"),
    ("lot of effort", "improving", "patching process"),
    ("lot of energy", "improving", "patching process"),
    ("We", "are probably later in", "patching process"),
    ("We", "are probably later than", "we should have"),
]),

# The boy also sprayed the room full of retardant from fire extinguishers, which made it hard to see, the chief said.
([
    ("chief", "said about", "boy"),
    ("boy", "sprayed", "room"),
    ("room", "was full of", "retardant"),
    ("retardant", "was from", "fire extinguishers"), 
    ("retardant", "made", "hard to see"),
],
# The boy fired once into a wall and sprayed the room with fire extinguishers, making it hard to see, the chief said.
[
    ("chief", "said about", "boy"),
    ("boy", "fired once into", "wall"),
    ("boy", "sprayed", "room"),
    ("boy", "sprayed with", "fire extinguishers"),
    ("fire extinguishers", "made", "hard to see"),
]),

# "But HRT should not be used to prevent heart disease or any other chronic condition."
([
    ("HRT", "should not be used to prevent", "heart disease"),
    ("HRT", "should not be used to prevent", "other chronic condition")
],
# "The clear message is it should not be used to prevent cardiovascular disease," Manson said.
[
    ("Manson", "said", "clear message"),
    ("clear message", "is about", "it"),
    ("it", "should not be used to prevent", "cardiovascular disease"),
]),

# The meat, poultry, butter, cheese and nuts were impounded a year ago at a LaGrou Cold Storage warehouse in Chicago.
([
    ("meat, poultry, butter, cheese and nuts", "were impounded", "a year ago"),
    ("meat, poultry, butter, cheese and nuts", "were impounded at", "LaGrou Cold Storage warehouse"), 
    ("LaGrou Cold Storage warehouse", "was in", "Chicago")
],
# The meat, poultry, butter, cheese and nuts were being stored by more than 100 wholesalers in Chicago.
[
    ("meat, poultry, butter, cheese and nuts", "were being stored by", "more than 100 wholesalers"),
    ("more than 100 wholesalers", "were in", "Chicago")
]),

# The BlueCore3-Multimedia includes a 16-bit stereo audio CODEC with dual ADC and DAC for stereo audio.
([
    ("BlueCore3-Multimedia", "includes", "audio CODEC"), 
    ("audio CODEC", "is", "16-bit stereo"),
    ("audio CODEC", "is with", "dual ADC and DAC"),
    ("dual ADC and DAC", "is for", "stereo audio")
],
# BlueCore3-Multimedia contains an open platform DSP co-processor and also includes a 16-bit stereo audio codec 
# with dual ADC and DAC for stereo audio.
[
    ("BlueCore3-Multimedia", "contains", "DSP co-processor"),
    ("DSP co-processor", "is", "open platform"),
    ("BlueCore3-Multimedia", "includes", "audio codec"),
    ("audico CODEC", "is", "16-bit stereo"),
    ("audio codec", "has", "dual ADC and DAC"),
    ("dual ADC and DAC", "is for", "stereo audio")
]),

# Now, with the agency's last three shuttles grounded in the wake of the Columbia disaster, that wait could be even longer.
([
    ("agency", "has", "three shuttles"),
    ("three shuttles", "are", "last"),
    ("three shuttles", "are grounded in", "wake of the Columbia disaster"),
    ("wait", "could be", "even longer")
],
# With the remaining three shuttles grounded in the wake of the Columbia accident, the rookies will have to wait even longer.
[
    ("three shuttles", "are", "remaining"),
    ("three shuttles", "are grounded in", "wake of the Columbia accident"),
    ("rookies", "will have to wait", "even longer")
]),

# Bremer, 61, is a onetime assistant to former Secretaries of State William P. Rogers and Henry Kissinger 
# and was ambassador-at-large for counterterrorism from 1986 to 1989.
([
    ("Bremer", "is", "61"),
    ("Bremer", "is", "onetime assistant"),
    ("onetime assistant", "was to", "former Secretaries of State"),
    ("former Secretaries of State", "includes", "William P. Rogers"),
    ("former Secretaries of State", "includes", "Henry Kissinger"),
    ("Bremer", "was", "ambassador-at-large for counterterrorism"),
    ("ambassador-at-large from", "was from", "1986"), 
    ("ambassador-at-large from", "was to", "1989"),
],
# Bremer, 61, is a former assistant to former Secretaries of State William P. Rogers and Henry Kissinger.
[
    ("Bremer", "is", "61"),
    ("Bremer", "is", "former assistant"),
    ("former assistant", "was to", "former Secretaries of State"),
    ("former Secretaries of State", "includes", "William P. Rogers"),
    ("former Secretaries of State", "includes", "Henry Kissinger"),
]),

# Those conversations had not taken place as of Tuesday night, according to an Oracle spokeswoman.
([
    ("Oracle spokeswoman", "said about", "conversations"),
    ("conversations", "had not", "taken place"), 
    ("taken place", "was as of", "Tuesday night")
],
# Those talks have not taken place, according to an Oracle spokeswoman.
[
    ("Oracle spokeswoman", "said about", "talks"),
    ("talks", "have not", "taken place"),
]),

# Taiwan has attempted to gain observer status to the United Nations-affiliated WHO for seven years, 
# but again was rebuffed March 19 at its annual conference in Geneva.
([
    ("Taiwan", "has attempted to gain", "observer status"), 
    ("observer status", "is to", "WHO"),
    ("WHO", "is", "United Nations-affiliated"),
    ("Taiwan", "has attempted to gain for", "seven years"),
    ("Taiwan", "was again rebuffed", "March 19"),
    ("Taiwan", "was again rebuffed at", "annual conference"),
    ("annual conference", "was of", "WHO"),
    ("annual conference", "was in", "Geneva"),
],
# It has sought observer status for seven years, but was again rebuffed May 19 at the annual WHO conference in Geneva.
[
    ("It", "has sought", "observer status"),
    ("It", "has sought for", "seven years"),
    ("It", "was again rebuffed", "May 19"),
    ("It", "was again rebuffed at", "annual conference"),
    ("annual conference", "was of", "WHO"),
    ("annual conference", "was in", "Geneva")
]),

# A Washington County man may have the countys first human case of West Nile virus, the health department said Friday.
([
    ("health department", "said about", "man"),
    ("health department", "said", "Friday"),
    ("man", "is from", "Washington County"),
    ("man", "may have", "human case"), 
    ("human case", "is", "first"),
    ("human case", "is in", "Washington County"),
    ("human case", "is of", "West Nile virus"),
],
# The countys first and only human case of West Nile this year was confirmed by health officials on Sept. 8.
[   
    ("human case", "is of", "West Nile"),
    ("human case", "was confirmed by", "health officials"),
    ("human case", "was confirmed on", "Sept. 8"),
    ("human case", "is", "first"),
    ("human case", "is", "only"),
    ("human case", "is in", "county"),
    ("human case", "is in", "year"),
]),

# National Breast Cancer Centre chief executive Professor Christine Ewan said it was too early to quantify the risk to women.
([
    ("Professor Christine Ewan", "is", "chief executive"),
    ("chief executive", "is of", "National Breast Cancer Centre"),
    ("Professor Christine Ewan", "said about", "risk to women"),
    ("too early", "was to quantify", "risk to women")

],
# National Breast Cancer Centre head Professor Christine Ewan said there was no need for panic.
[
    ("Professor Christine Ewan", "is", "head"),
    ("head", "is of", "National Breast Cancer Centre"),
    ("Professor Christine Ewan", "said there was", "no need for panic"),
]),

# Brendsel and chief financial officer Vaughn Clarke resigned June 9.
([
    ("Vaughn Clarke", "was", "chief financial officer"),
    ("Brendsel", "resigned", "June 9"),
    ("Vaughn Clarke", "resigned", "June 9")
],
# The company's chief executive retired and chief financial officer resigned.
[
    ("chief executive", "was of", "company"),
    ("chief financial officer", "was of", "company"),
    ("chief executive", "retired", ""),
    ("chief financial officer", "resigned", "")
]),

# On health care, the NDP says there will be no privatization and no health-care premiums.
([
    ("NDP", "says about", "on health care"),
    ("on health care", "there will be", "no privatization"),
    ("on health care", "there will be", "no health-care premiums"),
],
# The New Democrats also renewed their commitment to no health-care privatization and no premiums.
[
    ("New Democrats", "renewed", "commitment"),
    ("commitment", "is to", "no privatization"),
    ("no privatization", "is of", "health-care"),
    ("commitment", "is to", "no premiums"),
    ("no premiums", "are of", "health-care")
]),

# The new companies will begin trading on Nasdaq today under the ticker symbols PLMO and PSRC.
([
    ("new companies", "will begin trading on", "Nasdaq"),
    ("new companies", "will begin trading", "today"),
    ("new companies", "will begin trading under", "ticker symbols"),
    ("ticker symbols", "include", "PLMO"),
    ("ticker symbols", "include", "PSRC")
],
# Also as part of the deal, PalmSource stock will begin trading on the NASDAQ stock market Wednesday under the ticker symbol: PSRC.
[
    ("stock", "is of", "PalmSource"),
    ("NASDAQ", "is", "stock market"),
    ("stock", "will begin trading on", "NASDAQ"),
    ("stock", "will begin trading", "Wednesday"),
    ("stock", "will begin trading under", "ticker symbol"),
    ("ticker symbol", "is", "PSRC")
]),

# Kids, adults, booksellers and postal workers all are preparing for "Harry Potter and the Order of the Phoenix."
([
    ("Kids", "are preparing for", "Harry Potter and the Order of the Phoenix"),
    ("adults", "are preparing for", "Harry Potter and the Order of the Phoenix"),
    ("booksellers", "are preparing for", "Harry Potter and the Order of the Phoenix"),
    ("postal workers", "are preparing for", "Harry Potter and the Order of the Phoenix")
],
# The crates are full of hardback copies of "Harry Potter and the Order of the Phoenix."
[
    ("crates", "are", "full"),
    ("full", "is of", "hardback copies"),
    ("hardback copies", "are of", "Harry Potter and the Order of the Phoenix")
]),

# The government did not identify the taikonauts — a term coined from ‘‘taikong,’’ the Chinese word for space — 
# who would travel on the second mission.
([
    ("government", "did not identify", "taikonauts"),
    ("taikonauts", "is coined from", "taikong"),
    ("taikong", "is", "Chinese word"),
    ("taikong", "is for", "space"),
    ("taikonauts", "would travel on", "second mission"),
],
# The government did not identify the taikonauts -- a term coined from taikong, the Chinese word for space.
[
    ("government", "did not identify", "taikonauts"),
    ("taikonauts", "is coined from", "taikong"),
    ("taikong", "is", "Chinese word"),
    ("taikong", "is for", "space"),
]),

# I think we made the right case and did the right thing."
([
    ("I", "think about", "we"),
    ("we", "made", "right case"),
    ("we", "did", "right thing")
],
# Mr Blair went on: "I think we did the right thing in relation to Iraq.

[
    ("Mr Blair", "went on about", "we"),
    ("Mr Blair", "thinks about", "we"),
    ("we", "did", "right thing"),
    ("right thing", "was in relation to", "Iraq"),
]),

# Kollar-Kotelly has scheduled another antitrust settlement compliance hearing for January.
([
    ("Kollar-Kotelly", "has scheduled", "hearing"),
    ("hearing", "is of", "antitrust settlement compliance"),
    ("hearing", "is scheduled for", "January")
],
# The judge scheduled another oversight hearing for late January.
[
    ("judge", "scheduled", "oversight hearing"),
    ("oversight hearing", "is scheduled for", "late January")
]),

# "Tomorrow at the Mission Inn, I have the opportunity to congratulate the governor-elect of the great state of California.
([
    ("I", "have", "opportunity"),
    ("opportunity", "is", "Tomorrow"),
    ("opportunity", "is at", "Mission Inn"),
    ("opportunity", "is to congratulate", "governor-elect"),
    ("governor-elect", "is of", "California"),
    ("California", "is", "great state")
],
# "I have the opportunity to congratulate the governor-elect of the great state of California, and I'm looking forward to it."
[
    ("I", "have", "opportunity"),
    ("opportunity", "is to congratulate", "governor-elect"),
    ("governor-elect", "is of", "California"),
    ("California", "is", "great state"),
    ("I", "am looking forward to", "opportunity")
]),

# "I expect Japan to keep conducting intervention, but the volume is likely to fall sharply," 
# said Junya Tanase, forex strategist at JP Morgan Chase.
([
    ("Junya Tanase", "is", "forex strategist"),
    ("Junya Tanase", "is at", "JP Morgan Chase"),
    ("Junya Tanase", "expects about", "Japan"),
    ("Japan", "is to keep conducting", "intervention"),
    ("intervention", "has", "volume"),
    ("volume", "is likely to fall", "sharply"),
],
# Junya Tanase, forex strategist at JP Morgan Chase, said "I expect Japan to keep conducting intervention, 
# but the volume is likely to fall sharply."
[
    ("Junya Tanase", "is", "forex strategist"),
    ("Junya Tanase", "is at", "JP Morgan Chase"),
    ("Junya Tanase", "said about", "Junya Tanase"),
    ("Junya Tanase", "expects about", "Japan"),
    ("Japan", "is to keep conducting", "intervention"),
    ("intervention", "has", "volume"),
    ("volume", "is likely to fall", "sharply"),
]),

# The Sunshine Group LTD represented the developers, The Related Companies and Apollo Real Estate Advisors LP, on the deal.
([
    ("Sunshine Group LTD", "represented", "developers"),
    ("developers", "include", "The Related Companies"),
    ("developers", "include", "Apollo Real Estate Advisors LP"),
    ("Sunshine Group LTD", "represented on", "deal")
],
# The developers, The Related Cos. and Apollo Real Estate Advisors, hope sales top $1 billion.
[
    ("developers", "hope", "sales top $1 billion"),
    ("developers", "includes", "The Related Cos."),
    ("developers", "includes", "Apollo Real Estate Advisors")
]),

# "It is about a third of what I owe in the world," he told reporters.
([
    ("he", "told", "reporters"),
    ("he", "told about", "it"),
    ("it", "is", "about a third"),
    ("about a third", "is of", "he owe in the world")
],
# It ain't coming to me, but it's only about a third of what I owe in the world.
[   
    ("it", "is not coming to", "I"),
    ("it", "is", "about a third",),
    ("about a third", "is of", "I owe in the world")
]),

# The tech-laced Nasdaq Composite Index gained 2.90 points, or 0.18 percent, to 1,606.87.
([
    ("Nasdaq Composite Index", "is", "tech-laced"),
    ("Nasdaq Composite Index", "gained", "2.90 points"),
    ("Nasdaq Composite Index", "gained", "0.18 percent"),
    ("Nasdaq Composite Index", "gained to", "1,606.87")
],
# At 12:10 p.m. EDT, Canada's benchmark S&P/TSX composite index was up 6.87 points or 0.1 per cent to 6,979.29.
[
    ("S&P/TSX composite index", "is", "benchmark"),
    ("S&P/TSX composite index", "is of", "Canada"),
    ("S&P/TSX composite index", "was up", "6.87 points"),
    ("S&P/TSX composite index", "was up", "0.1 per cent"),
    ("S&P/TSX composite index", "was up to", "6,979.29"),
    ("S&P/TSX composite index", "was up at", "12:10 p.m. EDT")
]),

# The benchmark 10-year Treasury note yield <US10YT=RR> dipped below 4.20 percent on Tuesday.
([
    ("<US10YT=RR>", "is", "10-year Treasury note yield"),  
    ("10-year Treasury note", "is", "benchmark"),
    ("yield", "is on", "10-year Treasury note"),
    ("yield", "dipped below", "4.20 percent"),
    ("yield", "dipped on", "Tuesday")
],
# Prices for Treasury securities also rose, with the yield on the benchmark 10-year note falling to 4.19 percent.
[
    ("Prices", "are for", "Treasury securities"),
    ("Prices", "rose with", "yield"),
    ("10-year note", "is", "benchmark"),
    ("yield", "is on", "10-year note"),
    ("yield", "falling to", "4.19 percent")
]),

# So was Edie Falco, the critically praised co-star of "Frankie and Johnny."
([
    ("Edie Falco", "was", "critically praised"),
    ("Edie Falco", "was", "co-star"),
    ("co-star", "was of", "Frankie and Johnny")
],
# Edie Falco was not nominated for "Frankie and Johnny."
[
    ("Edie Falco", "was not nominated for", "Frankie and Johnny")
]),

# "Saddam is gone, but we want the (U.S.) occupation to end," said Hit resident Abu Qasim.
([
    ("Abu Qasim", "resides in", "Hit"),
    ("Abu Qasim", "said about", "Saddam"),
    ("Saddam", "is", "gone"),
    ("Abu Qasim", "said about", "occupation"),
    ("occupation", "is of", "U.S"),
    ("occupation", "is wanted to", "end"),
],
# "Saddam is gone, but we want the (U.S.) occupation to end."
[
    ("Saddam", "is", "gone"),
    ("occupation", "is of", "U.S"),
    ("occupation", "is wanted to", "end")
]),

# Joe Kernan, who had been lieutenant governor for the past seven years, was sworn in as governor after O'Bannon died Saturday.
([
    ("Joe Kernan", "had been", "lieutenant governor"),
    ("lieutenant governor", "was for", "past seven years"),
    ("Joe Kernan", "was sworn in as", "governor"),
    ("Joe Kernan", "was sworn in after", "O'Bannon death"),
    ("O'Bannon death", "was on", "Saturday")
],
# Kernan, who was O'Bannon's lieutenant governor, friend and political partner, 
# was sworn in six hours after O'Bannon died Saturday.
[
    ("Kernan", "was", "lieutenant governor"),
    ("lieutenant governor", "was of", "O'Bannon"),
    ("Kernan", "was friend of", "O'Bannon"),
    ("Kernan", "was political partner of", "O'Bannon"),
    ("Kernan", "was sworn in after", "six hours"),
    ("six hours", "were after", "O'Bannon death"),
    ("O'Bannon death", "was on", "Saturday")
]),

# Advanced Micro Devices said Fujitsu Siemens Computers is offering a high-end workstation based on AMD's Opteron 200 Series.
([
    ("AMD", "is", "Advanced Micro Devices"),
    ("Advanced Micro Devices", "said about", "Fujitsu Siemens Computers"),  
    ("Fujitsu Siemens Computers", "is offering", "high-end workstation"),
    ("high-end workstation", "is based on", "Opteron 200 Series"),
    ("Opteron 200 Series", "is from", "AMD")

],
# Fujitsu Siemens Computers on Tuesday made good on a promise to offer a workstation based on Advanced Micro Devices' 
# Opteron processor.
[
    ("Fujitsu Siemens Computers", "made good on", "promise"),
    ("promise", "was made good on", "Tuesday"),
    ("promise", "was to offer", "workstation"),
    ("workstation", "is based on", "Opteron processor"),
    ("Opteron processor", "is from", "Advanced Micro Devices")
]),

# Kodak expects earnings of 5 cents to 25 cents a share in the quarter.
([
    ("Kodak", "expects", "earnings"),
    ("earnings", "expected of", "5 cents to 25 cents"),
    ("5 cents to 25 cents", "are for", "share"),
    ("earnings", "are in", "quarter")
],
# Analysts surveyed by Thomson First Call had expected Kodak to earn 68 cents a share for the quarter.
[
    ("Thomson First Call", "surveyed", "Analysts"),
    ("Analysts", "had expected about", "Kodak"),
    ("Kodak", "is to earn", "68 cents"),
    ("68 cents", "are for", "share"),
    ("Kodak", "is to earn for", "quarter"),
]),

# Shares of Corixa fell 12 cents to $6.88 on the Nasdaq stock market.
([
    ("Shares", "are of", "Corixa"),
    ("Shares", "fell", "12 cents"),
    ("Shares", "fell to", "$6.88"),
    ("Shares", "fell on", "Nasdaq stock market")
],
# Corixa's stock barely flinched on the news, dipping 12 cents to close at $6.88.
[
    ("stock", "is of", "Corixa"),
    ("stock", "barely flinched on", "news"),
    ("stock", "dipping", "12 cents"),
    ("stock", "to close at", "$6.88"),
]),

# He was referring to John S. Reed, the former Citicorp chief executive who became interim chairman 
# and chief executive of the exchange last Sunday .
([
    ("He", "was referring to", "John S. Reed"),
    ("John S. Reed", "is", "former chief executive"),
    ("former chief executive", "is of", "Citicorp"),
    ("John S. Reed", "became", "interim chairman"),
    ("John S. Reed", "became", "chief executive"),
    ("interim chairman", "is of", "exchange"),
    ("chief executive", "is of", "exchange"),
    ("John S. Reed", "became", "last Sunday")
],
# Next week, John S. Reed, the former Citicorp chief executive who Sunday became interim chairman and chief executive 
# of the exchange, will take up his position.
[
    ("John S. Reed", "is", "former chief executive"),
    ("former chief executive", "is of", "Citicorp"),
    ("John S. Reed", "became", "interim chairman"),
    ("John S. Reed", "became", "chief executive"),
    ("interim chairman", "is of", "exchange"),
    ("chief executive", "is of", "exchange"),
    ("John S. Reed", "became", "Sunday"),
    ("John S. Reed", "will take up", "position"),
    ("John S. Reed", "will take up", "next week")
]),

# He refused to reveal what percentage of flights carried sky marshals, or whether they would be increased. 
([
    ("He", "refused to reveal", "percentage"),
    ("percentage", "was of", "flights"),
    ("flights", "were carried", "sky marshals"),
    ("He", "refused to reveal", "weather would be increased"), 
    ("weather would be increased", "is about", "flights")
],
# He refused to say what percentage of domestic flights had security officers on board.
[
    ("He", "refused to say", "percentage"), 
    ("percentage", "was of", "domestic flights"),
    ("domestic flights", "had", "security officers"), 
    ("security officers", "were", "on board")
]),

# The Nasdaq Composite Index rose 19.67, or 1.3 percent, to 1523.71, its highest since June 18.
([
    ("Nasdaq Composite Index", "rose", "19.67"),
    ("Nasdaq Composite Index", "rose", "1.3 percent"),
    ("Nasdaq Composite Index", "rose to", "1523.71"),
    ("1523.71", "is highest since", "June 18")
],
# The S&P 500 had climbed 16 percent since its March low and yesterday closed at its highest since Dec. 2.
[
    ("S&P 500", "had climbed", "16 percent"),
    ("S&P 500", "had climbed since", "March low"),
    ("S&P 500", "closed at highest since", "Dec. 2"),
    ("S&P 500", "closed", "yesterday")
]),

# They said they had concluded that the film failed "to present a balanced portrayal" of the Reagans.
([
    ("they", "said about", "they"),
    ("they", "had concluded about", "film"),
    ("film", "failed to present", "balanced portrayal"), 
    ("balanced portrayal", "is of", "Reagans")
],
# CBS said the show "does not present a balanced portrayal of the Reagans for CBS and its audience.
[
    ("CBS", "said about", "show"), 
    ("show", "does not present", "balanced portrayal"),
    ("balanced portrayal", "is of", "Reagans"),
    ("balanced portrayal", "is for", "CBS"),
    ("balanced portrayal", "is for", "audience"),
    ("audience", "is of", "CBS")
]),

# State health officials said today a young northeast Kansas woman likely has the state's first case of 
# monkeypox among humans or animals.
([
    ("officialas", "are of", "State health"),
    ("officials", "said about", "young woman"),
    ("officials", "said", "today"),
    ("young woman", "is from", "northeast"),
    ("northeast", "is of", "Kansas"),
    ("young woman", "likely has", "first case"),
    ("first case", "is of", "Kansas"), 
    ("first case", "is of", "monkeypox"),
    ("first case", "is among", "humans"),
    ("first case", "is among", "animals"), 
],
# Health officials confirmed today that a northeast Kansas woman has the state's first case of 
# monkeypox and the first case west of the Mississippi River.
[
    ("Health officials", "confirmed", "today"),
    ("Health officials", "confirmed about", "woman"), 
    ("woman", "is from", "northeast"),
    ("northeast", "is of", "Kansas"),
    ("woman", "has", "first case"),
    ("first case", "is of", "Kansas"),
    ("first case", "is of", "monkeypox"),
    ("first case", "is in", "west"),
    ("west", "is of", "Mississippi River")
]),

# Navistar shares were down 44 cents, or 1.1 percent, at $41.19 on the New York Stock Exchange after falling as low as $39.93.
([
    ("shares", "are of", "Navistar"),
    ("shares", "were down", "44 cents"),
    ("shares", "were down", "1.1 percent"),
    ("shares", "were down at", "$41.19"),
    ("shares", "were down on", "New York Stock Exchange"),
    ("shares", "were down after", "falling"), 
    ("falling", "was as low as", "$39.93")
],
# Navistar shares rose a penny to $41.64 at late afternoon on the New York Stock Exchange after earlier falling as low as $39.93.
[
    ("shares", "are of", "Navistar"),
    ("shares", "rose", "a penny"),
    ("shares", "rose to", "$41.64"),
    ("shares", "rose at", "late afternoon"),
    ("shares", "rose on", "New York Stock Exchange"),
    ("shares", "rose after", "earlier falling"),
    ("earlier falling", "was as low as", "$39.93")
]),

# Only Intel Corp.'s 0.3 percent yield was lower.
([
    ("Intel Corp.", "had", "yield"),
    ("yield", "was", "0.3 percent"),
    ("yield", "was", "lower than others")
],
# Only Intel Corp. has a lower dividend yield.
[
    ("Intel Corp.", "has", "dividend yield"),
    ("dividend yield", "is", "lower than others")
]),

# MGM, NBC and Liberty executives were not immediately available for comment.
([
    ("MGM executives", "were not immediately", "available for comment"),
    ("NBC executives", "were not immediately", "available for comment"),
    ("Liberty executives", "were not immediately", "available for comment")
],
# A Microsoft spokesman was not immediately available to comment.
[
    ("Microsoft spokesman", "was not immediately", "available to comment")
]),

# The new analysis found that 32 of the 16,608 participants developed ovarian cancer during about 5 years of follow-up.
([
    ("new analysis", "found", "32 participants"),
    ("32 participants", "were of", "16,608 participants"),
    ("32 participants", "developed", "ovarian cancer"),
    ("ovarian cancer", "was developed during", "about 5 years"),
    ("about 5 years", "were of", "follow-up")
],
# The new analysis found that 32 of 16,608 participants developed ovarian cancer 
# in about 5 1/2 years of follow-up, including 20 women taking hormones.
[
    ("new analysis", "found", "32 participants"),
    ("32 participants", "were of", "16,608 participants"), 
    ("32 participants", "developed", "ovarian cancer"),
    ("ovarian cancer", "was developed in", "about 5 1/2 years"),
    ("about 5 1/2 years", "were of", "follow-up"),
    ("20 women", "included in", "32 participants"),
    ("20 women", "were taking", "hormones")
]),

# Veteran stage and screen actor Hume Cronyn died of cancer Sunday.
([
    ("Hume Cronyn", "wass", "veteran actor"), 
    ("veteran actor", "was in", "stage"),
    ("veteran actor", "was in", "screen"),
    ("Hume Cronyn", "died", "of cancer"),
    ("Hume Cronyn", "died", "Sunday"),
    
],
# Character actor Hume Cronyn, 91, died Sunday at his home in Connecticut.
[
    ("Hume Cronyn", "was", "character actor"),
    ("Hume Cronyn", "was", "91"),
    ("Hume Cronyn", "died", "Sunday"),
    ("Hume Cronyn", "died at", "home"),
    ("home", "was in", "Connecticut"),
]),

# Deirdre Hisler, Government Canyon's manager, said the state has long had its eye on this piece of property 
# and is eager to complete the deal to obtain it.
([
    ("Deirdre Hisler", "is", "manager"),
    ("manager", "is of", "Government Canyon"),
    ("Deirdre Hisler", "said about", "state"),
    ("state", "has long had its eye on", "piece of property"),
    ("state", "is", "eager"),
    ("eager", "is to complete", "deal"),
    ("deal", "is to obtain", "piece of property"),
],
# Deirdre Hisler, Government Canyon's manager, said the state long has coveted this piece of property, 
# and is eager to complete the deal.
[
    ("Deirdre Hisler", "is", "manager"),
    ("manager", "is of", "Government Canyon"),
    ("Deirdre Hisler", "said about", "state"),
    ("state", "long has coveted", "piece of property"),
    ("state", "is", "eager"),
    ("eager", "is to complete", "deal"),
]),

# Reuters witnesses said many houses had been flattened and the city squares were packed with crying children and 
# the homeless, huddled in blankets to protect them from the cold.
([
    ("Reuters witnesses", "said about", "many houses"),
    ("many houses", "had been", "flattened"),
    ("Reuters witnesses", "said about", "city squares"),
    ("city squares", "were packed with", "crying children"),
    ("city squares", "were packed with", "homeless"),
    ("homeless", "were huddled in", "blankets"),
    ("blankets", "are to protect from", "cold")
],
# Reuters witnesses said public squares were packed with crying children and people left homeless, 
# huddled in blankets to protect them from the cold.
[
    ("Reuters witnesses", "said about", "public squares"),
    ("public squares", "were packed with", "crying children"),
    ("public squares", "were packed with", "people left homeless"),
    ("people left homeless", "were huddled in", "blankets"),
    ("blankets", "are to protect from", "cold")
]),

# The three grocery chains were relying on store managers and replacement workers to keep their stores open.
([
    ("three grocery chains", "were relying on", "store managers"), 
    ("three grocery chains", "were relying on", "replacement workers"),
    ("store managers", "keep", "stores open"),
    ("replacement workers", "keep", "stores open"),
    ("stores open", "were of", "three grocery chains")
],
# The supermarket chains have used managers and replacement workers to keep their stores open, often at reduced hours.
[
    ("supermarket chains", "have used", "managers"),
    ("supermarket chains", "have used", "replacement workers"),
    ("managers", "keep", "stores open"),
    ("replacement workers", "keep", "stores open"),
    ("stores open", "were often at", "reduced hours"),
    ("stores open", "were of", "supermarket chains")
]),

# The security official's backup couldn't fill in because he was on active military duty, Strutt said.
([
    ("Strutt", "said about", "backup"),
    ("backup", "was of", "security official"),
    ("backup", "couldn't fill in because", "duty"),
    ("duty", "was of", "backup"),
    ("duty", "was", "active military")
],
# The security official's backup was on active duty, and the lottery association didn't have a replacement in New Jersey, 
# Strutt said.
[
    ("Strutt", "said about", "backup"),
    ("backup", "was of", "security official"),
    ("backup", "was on", "active duty"),
    ("lottery association", "didn't have", "replacement"),
    ("replacement", "was to be in", "New Jersey"),
]),

# Researchers found the fossils in a semidesert area of Venezuela, about 250 miles west of Caracas.
([
    ("Researchers", "found", "fossils"),
    ("fossils", "were in", "semidesert area"),
    ("semidesert area", "was of", "Venezuela"),
    ("semidesert area", "is about", "250 miles west"),
    ("250 miles west", "are of", "Caracas")
],
# Phoberomys' skeleton was unearthed 250 miles west of Caracas, Venezuela.
[
    ("skeleton", "is of", "Phoberomys"),
    ("skeleton", "was unearthed", "250 miles west"),
    ("250 miles west", "are of", "Caracas"),
    ("Caracas", "is in", "Venezuela")
]),

# Mr McDonnell is leading Grant Thornton International's inquiry into the Italian business.
([
    ("Grant Thornton International", "has", "inquiry"),
    ("Mr McDonnell", "is leading", "inquiry"),
    ("inquiry", "is into", "Italian business"),
],
# Mr McDonnell wants to establish if the Italian business followed Grant Thornton's audit procedures.
[
    ("Mr McDonnell", "wants to establish if", "Italian business"), 
    ("Italian business", "followed", "audit procedures"),
    ("audit procedures", "were of", "Grant Thornton"),
]),

# The industry's largest association is urging its members not call the more than 50 million home 
# and cellular numbers on the list.
([
    ("largest association", "is of", "industry"),
    ("largest association", "is urging", "members"),
    ("members", "are urged", "not to call"),
    ("not to call", "is for", "more than 50 million"),
    ("more than 50 million", "include", "home numbers"),
    ("more than 50 million", "include", "cellular numbers"),
    ("home numbers", "are on", "list"),
    ("cellular numbers", "are on", "list"),
],
# Meantime, the Direct Marketing Association said its members should not call the nearly 51 million numbers on the list.
[
    ("Direct Marketing Association", "said", "members"),
    ("members", "should not call", "nearly 51 million"), 
    ("nearly 51 million", "are", "numbers"),
    ("numbers", "are on", "list")
]),

# The workers accuse General Dynamics of "reverse age discrimination" because of a change in retirement benefits in 1997.
([
    ("workers", "accuse", "General Dynamics"),
    ("General Dynamics", "is accused of", "reverse age discrimination"),
    ("reverse age discrimination", "is because of", "change"),
    ("change", "was in", "retirement benefits"),
    ("change", "was in", "1997")
],
# General Dynamics was sued when it changed its retirement benefits in 1997.
[       
    ("General Dynamics", "changed", "retirement benefits"),
    ("retirement benefits", "were changed in", "1997"),
    ("General Dynamics", "was sued for", "retirement benefits")
]),

# The tech-laced Nasdaq Composite Index .IXIC eased 5.16 points, or 0.32 percent, at 1,590.75, 
# breaking a six-day string of gains.
([
    (".IXIC", "is", "Nasdaq Composite Index"),
    ("Nasdaq Composite Index", "is", "tech-laced"),
    ("Nasdaq Composite Index", "eased", "5.16 points"),
    ("Nasdaq Composite Index", "eased", "0.32 percent"),
    ("Nasdaq Composite Index", "eased at", "1,590.75"),
    ("Nasdaq Composite Index", "broke", "string of gains"),
    ("string of gains", "was of", "six-day")
],
# The tech-heavy Nasdaq Composite Index .IXIC was off 0.11 percent, or 1.78 points, at 1,594.13.
[
    (".IXIC", "is", "Nasdaq Composite Index"),
    ("Nasdaq Composite Index", "is", "tech-heavy"),
    ("Nasdaq Composite Index", "was off", "0.11 percent"),
    ("Nasdaq Composite Index", "was off", "1.78 points"),
    ("Nasdaq Composite Index", "was off at", "1,594.13")
]),

# The Space Infrared Telescope Facility's mission is to search for the beginnings of the universe.
([  
    ("mission", "is of", "Space Infrared Telescope Facility"),
    ("mission", "is to search for", "beginnings of the universe")
],
# NASA is scheduled to launch the Space Infrared Telescope Facility on Monday morning.
[
    ("NASA", "is scheduled to", "launch"),
    ("launch", "is of", "Space Infrared Telescope Facility"),
    ("launch", "is on", "Monday morning")
]),

# The respected medical journal Lancet has called for a complete ban on tobacco in the United Kingdom.
([
    ("Lancet", "is", "medical journal"),
    ("Lancet", "is", "respected"),
    ("Lancet", "has called for", "complete ban"),
    ("complete ban", "is on", "tobacco"),
    ("complete ban", "is in", "United Kingdom")
],
# A leading U.K. medical journal called Friday for a complete ban on tobacco, prompting outrage from smokers' groups.
[
    ("medical journal", "is from", "U.K."),
    ("medical journal", "is", "leading"),
    ("medical journal", "called", "Friday"),
    ("medical journal", "called for", "complete ban"),
    ("complete ban", "is on", "tobacco"),
    ("medical journal", "prompting", "outrage"),
    ("outrage", "is from", "smokers' groups")
]),

# The driver of the truck escaped and is now being sought by the police, Supoyo said.
([
    ("Supoyo", "said about", "driver of the truck"),
    ("driver of the truck", "escaped", ""),
    ("driver of the truck", "is now being sought by", "police"),
],
# But police say the driver of the truck has not been found and is wanted for questioning.
[
    ("police", "say about", "driver of the truck"),
    ("driver of the truck", "has not been found", ""),
    ("driver of the truck", "is wanted for", "questioning")
]),

# "In so many different ways, the artistry of black musicians has conveyed the experience of black Americans 
# throughout our history," Bush said.
([
    ("Bush", "said about", "black musicians"),
    ("black musicians", "have", "artistry"),
    ("artistry", "has conveyed", "experience"),
    ("experience", "is of", "black Americans"),
    ("experience", "is throughout", "history"),
    ("history", "is of", "Americans")
],
# Surrounded by singers from Harlem, Bush said: ''The artistry of black musicians has conveyed the experience 
# of black Americans throughout our history.
[
    ("Bush", "was surrounded by", "singers"),
    ("singers", "were from", "Harlem"),
    ("Bush", "said about", "black musicians"),
    ("black musicians", "have", "artistry"),
    ("artistry", "has conveyed", "experience"),
    ("experience", "is of", "black Americans"),
    ("experience", "is throughout", "history"),
    ("history", "is of", "Americans")
]),

# Geraldine Andrews, the pastor's daughter-in-law, said Robinson recently took her daughter out of a mental health facility.
([
    ("Geraldine Andrews", "is", "daughter-in-law"),
    ("daughter-in-law", "is of", "pastor"),
    ("Geraldine Andrews", "said about", "Robinson"),
    ("Robinson", "recently took out", "daughter"),
    ("daughter", "was taken out of", "mental health facility")
],
# Geraldine Andrews, Reynolds' daughter-in-law and a friend of Wilson's family, 
# said Robinson had recently taken Wilson out of a mental health facility.
[
    ("Geraldine Andrews", "is", "daughter-in-law"),
    ("daughter-in-law", "is of", "Reynolds"),
    ("daughter-in-law", "is friend of", "family"),
    ("family", "is of", "Wilson"),
    ("Geraldine Andrews", "said about", "Robinson"),
    ("Robinson", "had recently taken out", "Wilson"),
    ("Wilson", "was taken out of", "mental health facility")
]),

# Before Thursday's matinee, Baker called a clubhouse meeting, concerned that the controversy had distracted the Cubs.
([

    ("Baker", "called", "clubhouse meeting"),
    ("Baker", "called before", "Thursday's matinee"),
    ("Baker", "was concerned about", "controversy"),
    ("controversy", "had distracted", "Cubs")
],
# Baker called a pregame meeting, believing the the corked-bat episode had distracted the team.
[
    ("Baker", "called", "pregame meeting"),
    ("Baker", "believing about", "corked-bat episode"),
    ("corked-bat episode", "had distracted", "team")
]),

# She was taken by ambulance to Charing Cross Hospital in Hammersmith.
([
    ("She", "was taken by", "ambulance"),
    ("She", "was taken to", "Charing Cross Hospital"),
    ("Charing Cross Hospital", "is in", "Hammersmith")
],
# She was taken to Charing Cross Hospital, where she remained critically ill last night.
[
    ("She", "was taken to", "Charing Cross Hospital"),
    ("She", "remained at", "Charing Cross Hospital"),
    ("She", "remained", "critically ill"),
    ("She", "remained", "last night")
]),

# Shortly after the opening bell, the Dow Jones Industrial Average was up 11.13 to 9,228.48,
# while the S&P 500 index gained 1.74 to 982.33.
([
    ("Dow Jones Industrial Average", "was up", "11.13"),
    ("Dow Jones Industrial Average", "was up to", "9,228.48"),
    ("Dow Jones Industrial Average", "was up shortly after", "opening bell"),
    ("S&P 500 index", "gained", "1.74"),
    ("S&P 500 index", "gained to", "982.33"),
    ("S&P 500 index", "gained shortly after", "opening bell")
],
# After a weak start, the Dow Jones Industrial Average ended the day up 26.26 to 9,217.35, 
# while the S&P 500 index rose 3 to 980.59.
[
    ("Dow Jones Industrial Average", "had", "weak start"),
    ("Dow Jones Industrial Average", "ended", "day"),
    ("Dow Jones Industrial Average", "ended up", "26.26"),
    ("Dow Jones Industrial Average", "ended to", "9,217.35"),
    ("S&P 500 index", "rose", "3"),
    ("S&P 500 index", "rose to", "980.59"),
    ("S&P 500 index", "rose ended", "day")
]),

# In addition, primary care trusts (PCTs) were given star ratings for the first time this year.
([
    ("PCTs", "are", "primary care trusts"),
    ("primary care trusts", "were given", "star ratings"),
    ("star ratings", "were for", "first time this year"),
    ("star ratings", "were in", "addition")
],
# Primary Care Trusts and Mental Health Trusts have also been formally rated for the first time this year.
[
    ("Primary Care Trusts", "have also been", "formally rated"),
    ("Mental Health Trusts", "have also been", "formally rated"),
    ("formally rated", "was for", "first time this year")
]),

# "We are expending all available resources toward the investigation," said Assistant U.S. Attorney Todd Greenberg, 
# a counterterrorism prosecutor in Seattle.
([
    ("Todd Greenberg", "is", "Assistant U.S. Attorney"),
    ("Todd Greenberg", "is", "counterterrorism prosecutor"),
    ("counterterrorism prosecutor", "is in", "Seattle"),
    ("Todd Greenberg", "said about", "we"),
    ("we", "are expending", "all available resources"),
    ("all available resources", "are toward", "investigation")
],
# "We are aware of the situation," said Assistant US Attorney Todd Greenberg, a counter-terrorism prosecutor in Seattle.
[
    ("Todd Greenberg", "is", "Assistant US Attorney"),
    ("Todd Greenberg", "is", "counter-terrorism prosecutor"),
    ("counter-terrorism prosecutor", "is in", "Seattle"),
    ("Todd Greenberg", "said about", "we"),
    ("we", "are aware of", "situation"),
]),

# The technology-laced Nasdaq Composite Index .IXIC shed 15 points, or 0.98 percent, to 1,492.
([
    (".IXIC", "is", "Nasdaq Composite Index"),
    ("Nasdaq Composite Index", "is", "technology-laced"),
    ("Nasdaq Composite Index", "shed", "15 points"),
    ("Nasdaq Composite Index", "shed", "0.98 percent"),
    ("Nasdaq Composite Index", "shed to", "1,492")
],
# The broader Standard & Poor's 500 Index <.SPX> edged down 9 points, or 0.98 percent, to 921.
[   ("<.SPX>", "is", "Standard & Poor's 500 Index"),
    ("Standard & Poor's 500 Index", "is", "broader"),
    ("Standard & Poor's 500 Index", "edged down", "9 points"),
    ("Standard & Poor's 500 Index", "edged down", "0.98 percent"),
    ("Standard & Poor's 500 Index", "edged down to", "921")
]),

# The research firm earlier had forecast an increase of 4.9 percent.
([  
    ("research firm", "had forecast earlier", ""),
    ("research firm", "had forecast", "increase"),
    ("increase", "was of", "4.9 percent"),
    
],
# The firm had predicted earlier this year a 4.9 percent increase.
[
    ("firm", "had predicted earlier", "this year"),
    ("firm", "had predicted", "increase"),
    ("increase", "was of", "4.9 percent"),
]),

# PeopleSoft will commit $863 million in cash and issue 52.6 million new shares, the companies said.
([
    ("companies", "said about", "PeopleSoft"),
    ("PeopleSoft", "will commit", "$863 million") ,
    ("$863 million","will be in", "cash"),
    ("PeopleSoft", "will issue", "52.6 million"), 
    ("52.6 million", "will be", "new shares"),
],
# The new deal would be valued at $1.75 billion, including $863 million in cash and 52.6 million PeopleSoft shares.
[
    ("new deal", "would be valued at", "$1.75 billion"),
    ("new deal", "including", "$863 million"), 
    ("$863 million","are in", "cash"),
    ("new deal", "including", "52.6 million"),
    ("52.6 million", "are", "shares"),
    ("shares", "are of", "PeopleSoft")
]),

# So in his State of the Union address in January, Bush declared that the British government 
# "has learned that Saddam Hussein recently sought significant quantities of uranium from Africa."
([
    ("Bush", "declared in", "State of the Union address"),
    ("State of the Union address", "was in", "January"),
    ("Bush", "declared about", "British government"),
    ("British government", "has learned about", "Saddam Hussein"),
    ("Saddam Hussein", "recently sought", "uranium"),
    ("uranium", "to be in", "significant quantities"),
    ("uranium", "is from", "Africa")
],
# In his Jan. 28 State of the Union message, Bush said, "The British government has learned 
# that Saddam Hussein recently sought significant quantities of uranium from Africa."
[
    ("State of the Union message", "was in", "Jan. 28"),
    ("Bush", "said in", "State of the Union message"),
    ("Bush", "said about", "British government"),
    ("British government", "has learned about", "Saddam Hussein"),
    ("Saddam Hussein", "recently sought", "uranium"),
    ("uranium", "to be in", "significant quantities"),
    ("uranium", "is from", "Africa")
]),

# The other 24 members are split between representatives of the securities industry and so-called "public" board members.
([  
    ("24 members", "are", "other"),
    ("24 members", "are split between", "members"),
    ("members", "include", "representatives"),
    ("representatives", "are of", "securities industry"),
    ("members", "include so-called", "public board members")
],
# Of the 24 directors who are not exchange executives, half are representatives of the securities industry 
# and half are designated public members.
[   
    ("24 directors", "are not", "exchange executives"),
    ("half", "are of", "24 directors"),
    ("half", "are", "representatives"),
    ("representatives", "are of", "securities industry"),
    ("half", "are", "public members"),
    ("public members", "are", "designated")
]),

# The Episcopal Diocese of Central Florida became one of the first in the nation Saturday to officially reject 
# the national denomination's policies on homosexuality.
([
    ("Episcopal Diocese", "is of", "Central Florida"),
    ("Episcopal Diocese", "became", "one of the first"),
    ("Episcopal Diocese", "became", "Saturday"),
    ("one of the first", "was in", "nation"),
    ("one of the first", "to reject", "national denomination"),
    ("national denomination", "is of", "policies on homosexuality")
],
# The Episcopal Diocese of Central Florida voted Saturday to repudiate a decision 
# by the denomination's national convention to confirm a gay man as bishop.
[
    ("Episcopal Diocese", "is of", "Central Florida"),
    ("The Episcopal Diocese", "voted", "Saturday"),
    ("The Episcopal Diocese", "voted to repudiate", "decision"),
    ("decision", "taken by", "denomination's national convention"),
    ("decision", "was to confirm", "gay man"), 
    ("gay man", "was confirmed as", "bishop")
]),

# McGill also detailed the hole that had been cut in the Caprice's trunk.
([
    ("McGill", "also detailed", "hole"),
    ("hole", "had been cut in", "Caprice's trunk")
],
# McGill also said a dark glove was stuffed into a hole that had been cut in the Caprice's trunk.
[
    ("McGill", "also said about", "dark glove"),
    ("dark glove", "was stuffed into", "hole"),
    ("hole", "had been cut in", "Caprice's trunk")
]),

# That compared with a year-earlier profit of $102 million, or 13 cents a share.
([
    ("That", "compared with", "year-earlier profit"),
    ("year-earlier profit", "was of", "$102 million"),
    ("year-earlier profit", "was of", "13 cents a share")
],
# That was more than double the $102 million, or 13 cents a share, for the year-earlier quarter.
[
    ("That", "was more than", "double"),
    ("double", "is on", "$102 million"),
    ("double", "is on", "13 cents a share"),
    ("$102 million", "are for", "year-earlier quarter"),
    ("13 cents a share", "are for", "year-earlier quarter"),
]),

# "The economy, nonetheless, has yet to exhibit sustainable growth.
([
    ("economy", "has yet to exhibit", "sustainable growth")
],
# But the economy hasn't shown signs of sustainable growth.
[
    ("economy", "hasn't shown", "signs"),
    ("signs", "are of", "sustainable growth")
]),

# The commission estimated California lost $937 million to corporate tax shelters in 2001.
([
    ("commission", "estimated about", "California"),
    ("California", "lost", "$937 million"),
    ("$937 million", "were to", "corporate tax shelters"), 
    ("California", "lost in", "2001"),
],
# California's lost tax revenue was mostly due to international corporate tax shelters.
[
    ("California", "had", "lost"),
    ("lost", "was of", "tax revenue"),
    ("lost", "was mostly due to", "tax shelters"),
    ("tax shelters", "were of", "international corporate")
]),

# In other markets, U.S. Treasuries started off on Monday weaker, as stocks rose early.
([
    ("U.S. Treasuries", "started off in", "other markets"),
    ("U.S. Treasuries", "started off", "weaker"),
    ("U.S. Treasuries", "started off on", "Monday"),
    ("stocks", "rose", "early"),
    ("stocks", "rose on", "Monday")
],
# In other markets, U.S. Treasuries inched higher as declining stocks raised the appeal of safe-haven debt.
[
    ("U.S. Treasuries", "inched higher in", "other markets"),
    ("U.S. Treasuries", "inched higher", ""),
    ("declining stocks", "raised", "appeal"),
    ("appeal", "was of", "safe-haven debt")
]),

# The technology-laced Nasdaq Composite Index .IXIC was down 25.36 points, or 1.53 percent, at 1,628.26.
([
    (".IXIC", "is", "Nasdaq Composite Index"),
    ("Nasdaq Composite Index", "is", "technology-laced"),
    ("Nasdaq Composite Index", "was down", "25.36 points"),
    ("Nasdaq Composite Index", "was down", "1.53 percent"),
    ("Nasdaq Composite Index", "was down at", "1,628.26")
],
# The broader Standard & Poor's 500 Index .SPX gave up 11.91 points, or 1.19 percent, at 986.60.
[
    (".SPX", "is", "Standard & Poor's 500 Index"),
    ("Standard & Poor's 500 Index", "is", "broader"),
    ("Standard & Poor's 500 Index", "gave up", "11.91 points"),
    ("Standard & Poor's 500 Index", "gave up", "1.19 percent"),
    ("Standard & Poor's 500 Index", "gave up at", "986.60")
]),

# The Pentagon had hoped to retain control of the postwar effort, 
# so the decision is a victory for Secretary of State Colin L. Powell.
([
    ("Pentagon", "had hoped to retain", "control"),
    ("control", "was of", "postwar effort"),
    ("Colin L. Powell", "is", "Secretary of State"),
    ("decision", "is", "victory"),
    ("victory", "is for", "Colin L. Powell")
],
# The Pentagon had hoped to retain control of the postwar effort, 
# so the decision was seen by some insiders as a victory for Powell and the State Department.
[
    ("Pentagon", "had hoped to retain", "control"),
    ("control", "was of", "postwar effort"),
    ("insiders", "saw", "decision"),
    ("decision", "was seen as", "victory"),
    ("victory", "was for", "Powell"),
    ("victory", "was for", "State Department"),
]),

# Prof Sally Baldwin, 63, from York, fell into a cavity which opened up when the structure collapsed 
# at Tiburtina station, Italian railway officials said.
([
    ("Sally Baldwin", "was", "Prof"),
    ("railway officials", "were", "Italian"),
    ("railway officials", "said about", "Sally Baldwin"),
    ("Sally Baldwin", "was", "63"),
    ("Sally Baldwin", "was from", "York"),
    ("Sally Baldwin", "fell into", "cavity"),
    ("cavity", "opened up when", "structure"),
    ("structure", "collapsed at", "Tiburtina station"),
],
# Sally Baldwin, from York, was killed instantly when a walkway collapsed 
# and she fell into the machinery at Tiburtina station.
[
    ("Sally Baldwin", "was from", "York"),
    ("Sally Baldwin", "was killed", "instantly"),
    ("Sally Baldwin", "was killed when", "walkway collapsed"),
    ("Sally Baldwin", "fell into", "machinery"),
    ("machinery", "was in", "Tiburtina station")
]),

# It calls for the agency to plan an independent safety and engineering organization.
([
    ("It", "calls for", "agency"),
    ("agency", "to plan", "independent organization"),
    ("independent organization", "to be", "safety"),
    ("independent organization", "to be", "engineering"),
],
# he agency has yet to fully formulate a strategy for the creation of an independent engineering technical authority.
[
    ("agency", "has yet to fully formulate", "strategy"),
    ("strategy", "is for", "creation"),
    ("creation", "is of", "independent authority"),
    ("independent authority", "to be", "engineering"),
    ("independent authority", "to be", "technical"),
]),

# WorldCom's accounting problems came to light early last year, and the company filed for bankruptcy in July 2002, 
# citing massive accounting irregularities.
([
    ("accounting problems", "are of", "WorldCom"),
    ("accounting problems", "came to light", "early last year"),
    ("WorldCom", "filed for", "bankruptcy"),
    ("bankruptcy", "was in", "July 2002"),
    ("WorldCom", "citing", "accounting irregularities"),
    ("accounting irregularities", "were", "massive")
],
# WorldCom's financial troubles came to light last year and the company subsequently filed for bankruptcy in July, 2002.
[
    ("financial troubles", "were of", "WorldCom"),
    ("financial troubles", "came to light", "last year"),
    ("WorldCom", "subsequently filed for", "bankruptcy"),
    ("bankruptcy", "was in", "July, 2002"),
]),

# The study also found that consumer goods advertisers continued to spend the most dollars online, 
# representing 35% of all Web advertising.
([
    ("study", "also found about", "advertisers"),
    ("advertisers", "were of", "consumer goods"),
    ("advertisers", "continued to spend most", "dollars"),
    ("advertisers", "continued to spend", "online"),
    ("consumer goods","represented", "35%"),
    ("35%", "was of all", "Web advertising")
],
# In the second quarter, consumer advertisers continued to spend the most online, slightly increasing their share.
[
    ("consumer advertisers", "continued to spend most", "online"),
    ("consumer advertisers", "continued to spend in", "second quarter"),
    ("consumer advertisers", "slightly increasing", "share")
]),

# Kiernan testified that Seifert had received a gunshot wound to the back.
([
    ("Kiernan", "testified about", "Seifert"),
    ("Seifert", "had received", "gunshot wound"),
    ("gunshot wound", "was received to", "back")
],
# Seifert, he testified, had a gunshot wound in the back.
[
    ("Seifert", "testified about", "Seifert"),
    ("Seifert", "had", "gunshot wound"),
    ("gunshot wound", "was in", "back"),
]),

# It is priced at $5,995 for an unlimited number of users tapping into the single processor, 
# or $195 per user with a minimum of five users.
([
    ("It", "is priced at", "$5,995"), 
    ("$5,995", "is for", "unlimited number of users"),
    ("unlimited number of users", "tapping into", "single processor"),
    ("It", "is priced at", "$195"),
    ("$195", "is per", "user"),
    ("$195", "is with", "minimum of users"),
    ("minimum of users", "is", "five")
],
# It is priced at $5,995 or $195 on a per user licensing plan with a minimum of five users.
[
    ("It", "is priced at", "$5,995"),
    ("It", "is priced at", "$195"), 
    ("$195", "is per", "user licensing plan"),
    ("user licensing plan", "is with", "minimum of users"),
    ("minimum of users", "is", "five")
])

]

print('MSR par samples: ', len(msrpar_samples_ds))
# Out:
# MSR par samples:  250

# %%
sents = 0
triplets = 0
words = 0
unique_words = set()
for pair in msrpar_samples_ds:
    for sent in pair:
        sents += 1
        for triplet in sent:
            text = ' '.join(triplet)
            words += len(text.split())
            for word in text.split():
                unique_words.add(word)
            triplets += 1
print('Words:', words)
print("Vocab. size:", len(unique_words))
print('Triplets:', triplets)
print('Triplets by sentence:', triplets / sents)
# Out:
# Words: 13486
# Vocab. size: 2724
# Triplets: 2402
# Triplets by sentence: 4.804

# %%
with open('msrpar_samples.pkl', 'wb') as f:
    pickle.dump([msrpar_samples_ds, scores_250], f)

# %% [markdown]
# ### AI request

# %%
with open('msrpar_prompt_120_125.txt', 'rt') as f:
    prompt = f.read()
#print(prompt)

kgs = get_answer(prompt)
print(kgs)
# Out:
# ```python
# [
#     [
#         ("U.S. troops", "encountered", "no resistance"),
#         ("U.S. troops", "swept", "five-hour"),
#         ("U.S. troops", "swept near", "Tikrit"),
#         ("Tikrit", "is", "Saddam Hussein's hometown"),
#         ("Tikrit", "is", "the center of a region of Baath Party supporters")
#     ],
#     [
#         ("Tikrit", "is", "Saddam Hussein's hometown"),
#         ("region around Tikrit", "is known as", "hotbed of Baath Party supporters"),
#         ("region around Tikrit", "is known as", "hotbed of former high-ranking Iraqi military officials")
#     ],
#     [
#         ("Miodrag Zivkovic", "won", "31 percent of the vote"),
#         ("Dragan Hajdukovic", "got", "four percent")
#     ],
#     [
#         ("Miodrag Zivkovic", "came in", "second"),
#         ("Miodrag Zivkovic", "has", "31 percent of the vote"),
#         ("Liberal Alliance", "is", "pro-independence opposition")
#     ],
#     [
# ...

# %%
print(kgs)
# Out:
# ```python
# [
#     [("the giant rock", "was observed on", "August 24"), ("the giant rock", "was observed by", "Lincoln Near-Earth Asteroid Research Program"), ("Lincoln Near-Earth Asteroid Research Program", "is based in", "Socorro"), ("Lincoln Near-Earth Asteroid Research Program", "is based in", "New Mexico")],
#     [("the rock", "was observed by", "Lincoln Near Earth Asteroid Research Program"), ("Lincoln Near Earth Asteroid Research Program", "is also known as", "LINEAR")],
#     [("we", "need to", "change old habits"), ("we", "need to", "seriously rethink business-as-usual")],
#     [("He", "urged", "employees"), ("He", "urged", "to avoid complacency"), ("He", "urged", "to change old habits"), ("He", "urged", "to seriously rethink business-as-usual")],
#     [("despicable acts", "were committed by", "killers"), ("killers", "have faith", "hate"), ("the United States", "will find", "the killers")],
# ...

# %% [markdown]
# #### Tests

# %%
command = "Create a knowledge graph for the next sentence: "
instructions = ". Give results only as python code, where triplets \
(subject, relationship, object or attribute) must be under the form of python tuples. \
Do not show any type of comments in your answer, just the python code."

samples = []
for pair in pairs:
    s1 = pair[0]
    s2 = pair[1]
    #print(s1)
    a1 = get_answer(command + s1 + instructions)
    #print(s2)
    a2 = get_answer(command + s2 + instructions)
    samples.append('# ' + s1)
    samples.append('# ' + s2)
    samples.append(a1)
    samples.append(a2)
