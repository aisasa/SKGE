# %%
import pandas as pd
import pickle

# %%
df = pd.read_json("Datasets/STStest.jsonl", lines=True)
df = df.drop(['split', 'genre', 'year', 'sid'], axis=1)
df = df[df['dataset'] == 'answer-answer']
df
# Out:
#            dataset  score                                          sentence1  \
# 625  answer-answer    3.0  I remained under the banyan tree, exhausted by...
# 626  answer-answer    3.0           In the US, it will depend on the school.
# 627  answer-answer    0.0           There's also what the string is made of.
# 628  answer-answer    0.0  You also imply you may not be paid if they can...
# 629  answer-answer    2.0                       I did this one time as well.
# ..             ...    ...                                                ...
# 874  answer-answer    1.0            There are two possible causes for this:
# 875  answer-answer    5.0                   I agree with the other comments.
# 876  answer-answer    3.0              The answer to both questions is: Yes.
# 877  answer-answer    5.0      It rather depends on which country you're in.
# 878  answer-answer    5.0                           This is a terrible idea.
#
# ...

# %%
with open('sts_MSRanswer_df.pkl', 'wb') as f:
    pickle.dump(df, f)
