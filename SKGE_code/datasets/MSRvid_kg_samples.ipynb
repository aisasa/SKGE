# %%
#!pip3 install openai
from openai import OpenAI
#from rich import print
import pickle

api_key = "xxxxxx"
client = OpenAI(api_key=api_key)

def get_answer(prompt:str):
    completion = client.chat.completions.create(model="gpt-4o-mini", 
                                                store=True,
                                                messages=[{"role": "user",   # system assistant user function tool developer
                                                       "content": prompt}]) 
    return(completion.choices[0].message.content)

# %% [markdown]
# #### Loading complete dataset and saving complete text sentences and scores

# %%
with open('sts_MSRvid_df.pkl', 'rb') as f:
    msrvid_df = pickle.load(f)      

msrvid_txt_pairs = []
for idx in range(len(msrvid_df)):
    msrvid_txt_pairs.append((msrvid_df.iloc[idx]['sentence1'], msrvid_df.iloc[idx]['sentence2']))

msrvid_scores = msrvid_df['score'].values.tolist()

with open('msrvid_txt.pkl', 'wb') as f:
    pickle.dump([msrvid_txt_pairs, msrvid_scores], f)

# %% [markdown]
# #### Loading a dataset chunk to be treated by AI

# %%
with open('sts_MSRvid_df.pkl', 'rb') as f:
    msrvid_df = pickle.load(f)      

msrvid_scores = msrvid_df['score'].values.tolist()
pairs = []

lte_inf = 200
lte_sup = 250
scores = msrvid_scores[lte_inf:lte_sup]

# for idx in range(len(msrvid_df)):
for idx in range(lte_inf, lte_sup):
    pairs.append(msrvid_df.iloc[idx]['sentence1'])
    pairs.append(msrvid_df.iloc[idx]['sentence2'])

print('msrvid_df length: ', len(msrvid_df))
print('scores lenght: ', len(scores))
print('pairs length:', len(pairs))

scores_250 = msrvid_scores[0:lte_sup]
print('Complete scores length: ', len(scores_250))
# Out:
# msrvid_df length:  250
# scores lenght:  50
# pairs length: 100
# Complete scores length:  250

# %%
for sent in pairs:
    print(sent + '<#>')

# %%
msrvid_samples_ds = [

# A girl is styling her hair.
([
    ("girl", "is styling", "hair")
],
# A girl is brushing her hair.
[
    ("girl", "is brushing", "hair")
]),

# A group of men play soccer on the beach.
([
    ("group", "is of", "men"),
    ("group", "play", "soccer"), 
    ("group", "play on", "beach")
], 
# A group of boys are playing soccer on the beach.
[   
    ("group", "is of", "boys"),
    ("group", "are playing", "soccer"), 
    ("group", "are playing on", "beach")
]),

# One woman is measuring another woman's ankle.
([
    ("woman", "is measuring", "ankle"), 
    ("ankle", "is of", "another woman")
], 
# A woman measures another woman's ankle.
[
    ("woman", "measures", "ankle"), 
    ("ankle", "is of", "another woman")
]),

# A man is cutting up a cucumber.
([
    ("man", "is cutting up", "cucumber")
],
# A man is slicing a cucumber.
[
    ("man", "is slicing", "cucumber")
]),

# A man is playing a harp.
([
    ("man", "is playing", "harp")
], 
# A man is playing a keyboard.
[
    ("man", "is playing", "keyboard")
]),

# A woman is cutting onions.
([
    ("woman", "is cutting", "onions")
],
# A woman is cutting tofu.
[
    ("woman", "is cutting", "tofu")
]),

# A man is riding an electric bicycle.
([
    ("man", "is riding", "electric bicycle")
], 
# A man is riding a bicycle.
[
    ("man", "is riding", "bicycle")
]),

# A man is playing the drums.
([
    ("man", "is playing", "drums")
], 
# A man is playing the guitar.
[
    ("man", "is playing", "guitar")
]),

# A man is playing guitar.
([
    ("man", "is playing", "guitar")
], 
# A lady is playing the guitar.
[
    ("lady", "is playing", "guitar")
]),

# A man is playing a guitar.
([
    ("man", "is playing", "guitar")
], 
# A man is playing a trumpet.
[
    ("man", "is playing", "trumpet")
]),

# A man is playing a guitar.
([
    ("man", "is playing", "guitar")
], 
# A man is playing a trumpet.
[
    ("man", "is playing", "trumpet")
]),

# A man is cutting an onion.
([
    ("man", "is cutting", "onion")
], 
# A man cuts an onion.
[
    ("man", "cuts", "onion")
]),

# A man is cycling.
([
    ("man", "is cycling", "")
], 
# A man is talking.
[
    ("man", "is talking", "")
]),

# A man is slicing open a fish.
([
    ("man", "is slicing open", "fish")
],
# A man is cutting up a fish.
[
    ("man", "is cutting up", "fish")
]),

# A man is slicing a tomato.
([
    ("man", "is slicing", "tomato")
], 
# A man is slicing a bun.
[
    ("man", "is slicing", "bun")
]),

# A man is playing a guitar.
([
    ("man", "is playing", "guitar")
], 
# A man is playing a keyboard.
[
    ("man", "is playing", "keyboard")
]),

# A baby panda goes down a slide.
([
    ("baby panda", "goes down", "slide")
],
# A panda slides down a slide.
[
    ("panda", "slides down", "slide")
]),

# A man is singing and playing a guitar.
([
    ("man", "is singing", ""), 
    ("man", "is playing", "guitar")
], 
# A man is playing a guitar.
[
    ("man", "is playing", "guitar")]
),

# A man attacks a woman.
([
    ("man", "attacks", "woman")
], 
# A man slaps a woman.
[
    ("man", "slaps", "woman")
]),

# A man is driving a car.
([
    ("man", "is driving", "car")
], 
# A man is riding a horse.
[
    ("man", "is riding", "horse")
]),


# A woman is cutting tofu.
([("woman", "is cutting", "tofu")], 
# A woman is cutting an onion.
[("woman", "is cutting", "onion")]),

# The woman is styling her hair.
([("woman", "is styling", "hair")], 
# The woman is slicing herbs.
[("woman", "is slicing", "herbs")]),

# Two zebras play in an open field.
([("two zebras", "play in", "field"),
  ("field", "is", "open")], 
# Two zebras are playing in a field.
[("two zebras", "are playing in", "field")]),

# A man is cutting a potato.
([("man", "is cutting", "potato")], 
# A man is slicing some potato.
[("man", "is slicing", "potato")]),

# A man is slicing an onion.
([("man", "is slicing", "onion")], 
# A woman is slicing a pumpkin.
[("woman", "is slicing", "pumpkin")]),

# A man is dancing.
([("man", "is dancing", "")], 
# A man and woman is dancing.
[("man", "is dancing", ""),
 ("woman", "is dancing", "")]),

# A man is riding a motorcycle.
([("man", "is riding", "motorcycle")], 
# A woman is riding a horse.
[("woman", "is riding", "horse")]),

# A woman is slicing garlics.
([("woman", "is slicing", "garlics")], 
# A woman is slicing an onion.
[("woman", "is slicing", "onion")]),

# A man is speaking.
([("man", "is speaking", "")], 
# A man is cooking.
[("man", "is cooking", "")]),

# A little boy is singing and playing a guitar.
([("little boy", "is singing", ""), 
  ("little boy", "is playing", "guitar")], 
# A man is singing and playing the guitar.
[("man", "is singing", ""), 
 ("man", "is playing", "guitar")]),

# A turtle is swimming in water.
([("turtle", "is swimming in", "water")], 
# A turtle is walking underwater.
[("turtle", "is walking", "underwater")]),

# A young woman is putting stickers all over her face.
([("woman", "is", "young"),
  ("woman", "is putting", "stickers"), 
  ("stickers", "are all over", "face")], 
# A woman is applying stickers to her face.
[("woman", "is applying", "stickers"), 
 ("stickers", "are applied to", "face")]),

# A woman is wrapping tofu.
([("woman", "is wrapping", "tofu")], 
# A woman is balling dough.
[("woman", "is balling", "dough")]),

# A cat is eating some corn.
([("cat", "is eating", "corn")], 
# A cat is eating corn on the cob.
[("cat", "is eating", "corn"),
 ("corn", "is on", "cob")]),

# A man is eating a food.
([("man", "is eating", "food")], 
# A man is eating a piece of bread.
[("man", "is eating", "piece of bread")]),

# A man is playing a guitar.
([("man", "is playing", "guitar")], 
# A man is eating pasta.
[("man", "is eating", "pasta")]),

# A man is kicking pots of water.
([("man", "is kicking", "pots"),
  ("pots", "are of", "water")], 
# A man is picking flowers.
[("man", "is picking", "flowers")]),

# A man is cutting a pipe with scissors.
([("man", "is cutting", "pipe"), 
  ("man", "is cutting with", "scissors")], 
# A man is cutting carpet with a knife.
[("man", "is cutting", "carpet"), 
 ("man", "is cutting with", "knife")]),

# A woman is dancing in the rain.
([("woman", "is dancing in", "rain")], 
# A woman dances in the rain out side.
[("woman", "dances in", "rain"), 
 ("woman", "dances", "out side")]),

# A woman is taking a bath.
([("woman", "is taking", "bath")], 
# A woman is riding a horse.
[("woman", "is riding", "horse")]),

# A man mixes vegetables in a pot.
([("man", "mixes", "vegetables"), 
  ("man", "mixes", "in a pot")], 
# A person is stirring vegetables in a pot.
[("person", "is stirring", "vegetables"), 
 ("person", "is stirring", "in a pot")]),

# A woman is talking on a cell phone.
([("woman", "is talking on", "cell phone")], 
# A man and woman are talking on the phone.
[("man", "is talking on", "phone"),
 ("woman", "is talking on", "phone")]),

# A man is playing a guitar.
([("man", "is playing", "guitar")], 
# A man is singing while playing the guitar.
[("man", "is singing", ""), 
 ("man", "is playing", "guitar")]),

# A man is playing a guitar.
([("man", "is playing", "guitar")], 
# A man is driving a car.
[("man", "is driving", "car")]),

# A man is cutting apple by his hand.
([("man", "is cutting", "apple"), 
  ("man", "is cutting by", "hand")], 
# A man is cutting carpet with a knife.
[("man", "is cutting", "carpet"), 
 ("man", "is cutting with", "knife")]),

# A man is opening a door.
([("man", "is opening", "door")], 
# A man is cutting an onion.
[("man", "is cutting", "onion")]),

# A man is slicing a tomato.
([("man", "is slicing", "tomato")], 
# A man is riding a horse.
[("man", "is riding", "horse")]),

# A man is cutting paper with a sword.
([("man", "is cutting", "paper"), 
  ("man", "is cutting with", "sword")], 
# A woman is cutting a tomato.
[("woman", "is cutting", "tomato")]),

# A boy studies a calendar.
([("boy", "studies", "calendar")], 
# A boy is looking at a calendar.
[("boy", "is looking at", "calendar")]),

# The ballerina is dancing.
([("ballerina", "is dancing", "")], 
# A man is dancing.
[("man", "is dancing", "")]),

# A woman is dancing.
([("woman", "is dancing", "")], 
# A woman is playing violin.
[("woman", "is playing", "violin")]),

# A woman is slicing some tomatoes.
([("woman", "is slicing", "tomatoes")], 
# A woman is chopping a potato.
[("woman", "is chopping", "potato")]),

# A woman is water skiing.
([("woman", "is water skiing", "")], 
# A woman is slicing fish.
[("woman", "is slicing", "fish")]),

# A man is playing a flute.
([("man", "is playing", "flute")], 
# A man is riding a scooter.
[("man", "is riding", "scooter")]),

# A man is playing the piano.
([("man", "is playing", "piano")], 
# A man played the guitar.
[("man", "played", "guitar")]),

# A woman is picking a can.
([("woman", "is picking", "can")], 
# A man is playing a guitar.
[("man", "is playing", "guitar")]),

# A man puts three pieces of meat into a pan.
([("man", "puts", "three pieces"),
  ("three pieces", "are of", "meat"),
  ("man", "puts into", "pan")], 
# A man is putting meat in a pan.
[("man", "is putting", "meat"), 
 ("man", "is putting in", "pan")]),

# A woman is cutting an onion.
([("woman", "is cutting", "onion")], 
# A woman is cleaning a garden.
[("woman", "is cleaning", "garden")]),

# Some men are sawing.
([("some men", "are sawing", "")], 
# Men are sawing logs.
[("men", "are sawing", "logs")]),

# A car is driven down the road.
([("car", "is driven down", "road")], 
# A girl is walking down a road.
[("girl", "is walking down", "road")]),

# The man is kissing and hugging the woman.
([("man", "is kissing", "woman"), 
  ("man", "is hugging", "woman")], 
# A man is hugging and kissing a woman.
[("man", "is hugging", "woman"), 
 ("man", "is kissing", "woman")]),

# A train is moving.
([("train", "is moving", "")], 
# A man is doing yoga.
[("man", "is doing", "yoga")]),

# Someone is slicing an onion.
([("someone", "is slicing", "onion")], 
# A woman is cutting onion.
[("woman", "is cutting", "onion")]),

# A woman is playing in the ocean.
([("woman", "is playing in", "ocean")], 
# A woman is preparing shrimp to cook.
[("woman", "is preparing", "shrimp"), 
 ("shrimp", "is to", "cook")]),

# A person is playing an electronic keyboard.
([("person", "is playing", "electronic keyboard")], 
# A kid is playing keyboard.
[("kid", "is playing", "keyboard")]),

# A man is holding a leaf.
([("man", "is holding", "leaf")], 
# A monkey is fighting a man.
[("monkey", "is fighting", "man")]),

# A woman is peeling shrimp.
([("woman", "is peeling", "shrimp")], 
# A man is squeezing water.
[("man", "is squeezing", "water")]),

# A man is sitting and smoking.
([("man", "is sitting", ""), 
  ("man", "is smoking", "")], 
# A man is smoking a cigarette.
[("man", "is smoking", "cigarette")]),

# A man is playing a guitar.
([("man", "is playing", "guitar")], 
# A woman is riding a horse.
[("woman", "is riding", "horse")]),

# A man is standing in front of the window and looking outside.
([("man", "is standing in front", "window"), 
  ("man", "is looking", "outside")], 
# A man is staring out the window.
[("man", "is staring out", "window")]),

# A skunk is looking here and there.
([("skunk", "is looking", "here"),
  ("skunk", "is looking", "there")], 
# A skunk looks at the camera.
[("skunk", "looks at", "camera")]),

# A man is playing the guitar and singing.
([("man", "is playing", "guitar"), 
  ("man", "is singing", "")], 
# A man sings with a guitar.
[("man", "sings with", "guitar")]),

# A woman opens a window.
([("woman", "opens", "window")], 
# A man is crawling.
[("man", "is crawling", "")]),

# People are dancing outside.
([("people", "are dancing", "outside")], 
# A group of people are dancing.
[("group", "is of", "people"),
 ("group", "are dancing", "")]),

# The man is using a camera to hammer a nail.
([("man", "is using", "camera"), 
  ("camera", "is to", "hammer a nail")], 
# Someone is banging a camera lense against a nail.
[("someone", "is banging", "camera lense"), 
 ("camera lense", "is against", "nail")]),

# A woman is filing her nails.
([("woman", "is filing", "nails")], 
# A man is peeling a carrot.
[("man", "is peeling", "carrot")]),

# A boy is crawling into a dog house.
([("boy", "is crawling into", "dog house")], 
# A boy is playing a wooden flute.
[("boy", "is playing", "wooden flute")]),

# A woman is swimming underwater.
([("woman", "is swimming", "underwater")], 
# A man is slicing some carrots.
[("man", "is slicing", "carrots")]),

# A machine is sharpening a pencil.
([("machine", "is sharpening", "pencil")], 
# The machine shaved the end of the pencil.
[("machine", "shaved", "end"),
 ("end", "is of", "pencil")]),

# A monkey is playing drums.
([("monkey", "is playing", "drums")], 
# A gorilla plays the drums.
[("gorilla", "plays", "drums")]),

# A man is opening a box and taking out paper.
([("man", "is opening", "box"), ("man", "is taking out", "paper")], 
# A woman is peeling a potato.
[("woman", "is peeling", "potato")]),

# A woman is dancing.
([("woman", "is dancing", "")], 
# A woman plays the clarinet.
[("woman", "plays", "clarinet")]),

# A person is drawing on a large touchscreen.
([("person", "is drawing on", "large touchscreen")], 
# A man is drawing on a digital dry erase board.
[("man", "is drawing on", "board"),
 ("board", "is", "digital dry erase")]),

# The men played follow the leader on the grass.
([("men", "played", "follow the leader"), 
  ("men", "played", "on the grass")], 
# The rhino grazed on the grass.
[("rhino", "grazed on", "grass")]),

# A woman is cracking eggs.
([("woman", "is cracking", "eggs")], 
# A man is talking to a woman.
[("man", "is talking to", "woman")]),

# A woman peels garlic with her hands.
([("woman", "peels", "garlic"), 
  ("woman", "peel with", "hands")], 
# The woman is slicing herbs.
[("woman", "is slicing", "herbs")]),

# The polar bears fought over the kill.
([("polar bears", "fought over", "kill")], 
# Polar bears are fighting each other.
[("polar bears", "are fighting", "each other")]),

# A man is doing trick with play cards.
([("man", "is doing", "trick"), 
  ("trick", "is with", "play cards")], 
# A man is performing a card trick.
[("man", "is performing", "card trick")]),

# The cat is licking a bottle.
([("cat", "is licking", "bottle")], 
# A cat plays with a small bottle.
[("cat", "plays with", "small bottle")]),

# A person is slicing an onion.
([("person", "is slicing", "onion")], 
# A person cuts ginger.
[("person", "cuts", "ginger")]),

# A person is peeling a potato with a potato peeler.
([("person", "is peeling", "potato"), 
  ("person", "is peeling with", "potato peeler")], 
# A man is cutting tomatoes with a cleaver.
[("man", "is cutting", "tomatoes"), 
 ("man", "is cutting with", "cleaver")]),

# Two women are dancing and singing in front of a crowd.
([("two women", "are dancing", ""), 
  ("two women", "are singing", ""), 
  ("two women", "are dancing in", "front of a crowd"), 
  ("two women", "are singing in", "front of a crowd")], 
# The women are singing and dancing.
[("women", "are singing", ""), 
 ("women", "are dancing", "")]),

# A man is seasoning some carrots.
([("man", "is seasoning", "carrots")], 
# A woman is slicing garlic.
[("woman", "is slicing", "garlic")]),

# Two men pushed carts through the woods.
([("two men", "pushed", "carts"),
  ("two men", "pushed", "through the woods")], 
# Two men are pushing carts.
[("two men", "are pushing", "carts")]),

# A man is playing a football.
([("man", "is playing", "football")], 
# A man is maneuvering a soccer ball with his feet.
[("man", "is maneuvering", "soccer ball"), 
 ("man", "is maneuvering", "with his feet")]),

# The lady peeled the potatoe.
([("lady", "peeled", "potatoe")], 
# A woman is peeling a potato.
[("woman", "is peeling", "potato")]),

# A woman is slicing some tofu.
([("woman", "is slicing", "tofu")], 
# A woman is cutting a block of tofu into small cubes.
[("woman", "is cutting", "block of tofu"), 
 ("woman", "is cutting into", "small cubes")]),

# Someone typed on a keyboard.
([("someone", "typed on", "keyboard")], 
# Someone is typing.
[("someone", "is typing", "")]),

# Three young men run, jump, and kick off of a Coke machine.
([("three men", "are", "young"),
  ("three men", "run", ""), 
  ("three men", "jump", ""), 
  ("three men", "kick off of", "Coke machine")], 
# Three men are jumping off a wall.
[("three men", "are jumping off", "wall")]),

# A young Asian girl is applying eyeliner.
([("Asian girl", "is", "young"),
  ("Asian girl", "is applying", "eyeliner")], 
# A girl is putting on eye makeup.
[("girl", "is putting on", "eye makeup")]),

# A cat is walking around a house.
([("cat", "is walking around", "house")], 
# A woman is peeling potato.
[("woman", "is peeling", "potato")]),

# A woman is talking to her pet bunny as she fondles it.
([("woman", "is talking to", "pet bunny"), 
  ("woman", "fondles", "pet bunny")], 
# A woman walks her dog onto astro turf.
[("woman", "walks", "dog"), 
 ("woman", "walks onto", "astro turf")]),

# A monkey is playing drums.
([("monkey", "is playing", "drums")], 
# Someone in a gorilla costume is playing a set of drums.
[("someone", "is playing", "set of drums"), 
 ("someone", "is in", "gorilla costume")]),

# A man is riding a white horse on an enclosed ground.
([("man", "is riding", "white horse"), 
  ("man", "is riding on", "enclosed ground")], 
# Someone is riding a horse.
[("someone", "is riding", "horse")]),

# An oriental lady is cutting a carrot into thin pieces.
([("oriental lady", "is cutting", "carrot"),
  ("carrot", "is cut into", "thin pieces")], 
# A woman is slicing a carrot.
[("woman", "is slicing", "carrot")]),

# A group of people are dancing.
([("group", "is of", "people"),
  ("group", "are dancing", "")], 
# Women are dancing outside.
[("women", "are dancing", "outside")]),

# A man is playing guitar.
([("man", "is playing", "guitar")], 
# A boy is talking to a giant dog.
[("boy", "is talking to", "giant dog")]),

# A woman mixes up vegetables.
([("woman", "mixes up", "vegetables")], 
# A woman is adding ingredients to a skillet.
[("woman", "is adding", "ingredients"), 
 ("ingredients", "are added to", "skillet")]),

# A woman pours a mixture into a bowl and mixes it.
([("woman", "pours", "mixture"), 
  ("mixture", "is poured into", "bowl"), 
  ("woman", "mixes", "mixture")], 
# A woman is preparing an egg in a skillet.
[("woman", "is preparing", "egg"), 
 ("egg", "is prepared in", "skillet")]),

# A man is cutting pieces of butter into a mixing bowl.
([("man", "is cutting", "pieces of butter"), 
  ("pieces of butter", "are cut into", "mixing bowl")], 
# Pieces of butter is added in the stand mixer.
[("pieces of butter", "is added in", "stand mixer")]),

# A man is putting garlic on some bread slices.
([("man", "is putting", "garlic"), 
  ("garlic", "is put on", "bread slices")], 
# A man is sprinkling seasoning on several split and buttered loaves of bread.
[("man", "is sprinkling", "seasoning"), 
 ("seasoning", "is on", "loaves of bread"),
 ("loaves of bread", "are", "several"),
 ("loaves of bread", "are", "split"),
 ("loaves of bread", "are", "buttered")
 ]),

# The panda bear lay on the logs.
([("panda bear", "lay on", "logs")], 
# A panda is lying down.
[("panda", "is lying down", "")]),

# Five men jump into a swimming pool.
([("five men", "jump into", "swimming pool")], 
# A group of swimmers fall into a pool.
[("group", "is of", "swimmers"),
 ("group", "fall into", "pool")]),

# A cheetah is running behind its prey.
([("cheetah", "is running behind", "prey")], 
# A cheetah chases prey on across a field.
[("cheetah", "chases", "prey"), 
 ("cheetah", "chases on", "across a field")]),

# A cat is playing on the floor.
([("cat", "is playing on", "floor")], 
# A man is slicing garlic.
[("man", "is slicing", "garlic")]),

# A boy is playing violin on stage.
([("boy", "is playing", "violin"), 
  ("boy", "is playing on", "stage")], 
# A person is mixing a pot.
[("person", "is mixing", "pot")]),

# A dog is barking at a toy.
([("dog", "is barking at", "toy")], 
# The little dog barked at the electronic toy.
[("little dog", "barked at", "electronic toy")]),

# A man is cycling.
([("man", "is cycling", "")], 
# A boy is riding a bicycle.
[("boy", "is riding", "bicycle")]),

# A woman is slicing ginger.
([("woman", "is slicing", "ginger")], 
# A person is holding two baby lorises.
[("person", "is holding", "two baby lorises")]),

# A man is dragging a dead deer.
([("man", "is dragging", "dead deer")], 
# A man is jumping into water from a cliff.
[("man", "is jumping into", "water"), 
 ("man", "is jumping from", "cliff")]),


# A man is preparing a snake for cooking.
# The man is dropping sliced cucumbers into water.
(
  [("man", "is preparing", "snake"), 
   ("snake", "is for", "cooking")],
  [("man", "is dropping", "sliced cucumbers"), 
   ("sliced cucumbers", "are into", "water")]
),

# A woman is spreading mustard on a bread roll.
# A kitten is playing with a woman's finger.
(
  [("woman", "is spreading", "mustard"), 
   ("mustard", "is on", "bread roll")],
  [("kitten", "is playing with", "woman's finger")]
),

# Someone touched the kitten chewing on a string.
# Someone is cutting paper.
(
  [("someone", "touched", "kitten"), ("kitten", "is chewing on", "string")],
  [("someone", "is cutting", "paper")]
),

# Meat is being put into a skillet.
# A woman is putting a baby into a trash can.
(
  [("meat", "is being put into", "skillet")],
  [("woman", "is putting", "baby"), 
   ("baby", "is into", "trash can")]
),

# A baby elephant is eating a small tree.
# A little girl peddling a scooter.
(
  [("baby elephant", "is eating", "small tree")],
  [("little girl", "is peddling", "scooter")]
),

# A woman and man are dancing in the rain.
# A man and woman are dancing in rain.
(
  [("woman", "is dancing in", "rain"), 
   ("man", "is dancing in", "rain")],
  [("man", "is dancing in", "rain"), 
   ("woman", "is dancing in", "rain")]
),

# Someone is drawing.
# Someone is dancing.
(
  [("someone", "is drawing", "")],
  [("someone", "is dancing", "")]
),

# A man is playing a guitar.
# A woman is playing the guitar.
(
  [("man", "is playing", "guitar")],
  [("woman", "is playing", "guitar")]
),

# Two men are fistfighting in a ring.
# Two men fistfight in a ring.
(
  [("two men", "are fistfighting in", "ring")],
  [("two men", "fistfight in", "ring")]
),

# A person wipes butter on a tray.
# A person is buttering a tray.
(
  [("person", "wipes", "butter"), 
   ("butter", "is on", "tray")],
  [("person", "is buttering", "tray")]
),

# Two men are playing football.
# Two men are practicing football.
(
  [("two men", "are playing", "football")],
  [("two men", "are practicing", "football")]
),

# The man is playing the guitar.
# The girl is playing the guitar.
(
  [("man", "is playing", "guitar")],
  [("girl", "is playing", "guitar")]
),

# A man is peeling a potato.
# A man is slicing a potato.
(
  [("man", "is peeling", "potato")],
  [("man", "is slicing", "potato")]
),

# A woman is stabbing a potato with a fork.
# A woman is puncturing a potato with a fork.
(
  [("woman", "is stabbing", "potato"), 
   ("woman", "is stabbing with", "fork")],
  [("woman", "is puncturing", "potato"), 
   ("woman", "is puncturing with", "fork")]
),

# A child is waking up.
# A girl is waking up.
(
  [("child", "is waking up", "")],
  [("girl", "is waking up", "")]
),

# A boy is playing a key-board.
# A little boy is playing a keyboard.
(
  [("boy", "is playing", "key-board")],
  [("little boy", "is playing", "keyboard")]
),

# A woman plays the flute.
# A woman is playing the flute.
(
  [("woman", "plays", "flute")],
  [("woman", "is playing", "flute")]
),

# A woman is playing an electric guitar.
# A man is playing an acoustic guitar.
(
  [("woman", "is playing", "electric guitar")],
  [("man", "is playing", "acoustic guitar")]
),

# A man is playing a flute.
# A man is playing a guitar.
(
  [("man", "is playing", "flute")],
  [("man", "is playing", "guitar")]
),

# A group of people are sweeping water out of a house.
# People are sweeping water out of a house.
(
  [("group of people", "are sweeping", "water"), 
   ("group of people", "are sweeping out of", "house")],
  [("people", "are sweeping", "water"), 
   ("people", "are sweeping out of", "house")]
),

# A man plays a guitar.
# A man is playing a guitar.
(
  [("man", "plays", "guitar")],
  [("man", "is playing", "guitar")]
),

# A man and a woman is kissing each other.
# A man and a woman are hugging and kissing each other.
(
  [("man", "is kissing", "woman"), 
   ("woman", "is kissing", "man")],
  [("man", "are hugging", "woman"), 
   ("man", "are kissing", "woman"), 
   ("woman", "are hugging", "man"), 
   ("woman", "are kissing", "man")]
),

# A woman is climbing a cliff.
# A woman is climbing a rock face.
(
  [("woman", "is climbing", "cliff")],
  [("woman", "is climbing", "rock face")]
),

# A polar bear is running towards a group of walruses.
# A polar bear is chasing a group of walruses.
(
  [("polar bear", "is running towards", "group of walruses")],
  [("polar bear", "is chasing", "group of walruses")]
),

# A woman is cutting some fish.
# A woman is cutting tofu.
(
  [("woman", "is cutting", "fish")],
  [("woman", "is cutting", "tofu")]
),

# Someone is playing a piano.
# Someone is playing guitar.
(
  [("someone", "is playing", "piano")],
  [("someone", "is playing", "guitar")]
),

# A man is pouring rice a roni into a pan.
# A man poured ric-a-roni into a pan.
(
  [("man", "is pouring", "rice a roni"), 
   ("man", "is pouring into", "pan"),],
  [("man", "poured", "ric-a-roni"), 
   ("man", "poured into", "pan")]
),

# A man is breaking wooden boards with his hand.
# A man is breaking tiles with his hands.
(
  [("man", "is breaking", "wooden boards"), 
   ("man", "is breaking with", "hand")],
  [("man", "is breaking", "tiles"), 
   ("man", "is breaking with", "hands")]
),

# A girl is playing guitar.
# A girl is playing a piano.
(
  [("girl", "is playing", "guitar")],
  [("girl", "is playing", "piano")]
),

# A man is praying.
# A man is dancing.
(
  [("man", "is praying", "")],
  [("man", "is dancing", "")]
),


# A man is playing piano.
# A man is playing a violin.
(
  [("man", "is playing", "piano")],
  [("man", "is playing", "violin")]
),

# A woman is slicing an onion.
# A woman is slicing lemons.
(
  [("woman", "is slicing", "onion")],
  [("woman", "is slicing", "lemons")]
),

# A man is riding a horse by a creek.
# A man is riding a horse.
(
  [("man", "is riding", "horse"), 
    ("man", "is riding by", "creek")],
  [("man", "is riding", "horse")]
),

# A man is playing a guitar.
# A man is playing a guitar and singing.
(
  [("man", "is playing", "guitar")],
  [("man", "is playing", "guitar"), 
    ("man", "is singing", "")]
),

# A man is picking up a tree.
# A man is carrying a tree.
(
  [("man", "is picking up", "tree")],
  [("man", "is carrying", "tree")]
),

# A person is peeling a potato.
# The man is peeling a potato.
(
  [("person", "is peeling", "potato")],
  [("man", "is peeling", "potato")]
),

# A person is playing a piano.
# A person is slicing a potato.
(
  [("person", "is playing", "piano")],
  [("person", "is slicing", "potato")]
),

# A man is spitting.
# A man is talking.
(
  [("man", "is spitting", "")],
  [("man", "is talking", "")]
),

# A man is playing a musical keyboard.
# A man is playing a keyboard piano.
(
  [("man", "is playing", "musical keyboard")],
  [("man", "is playing", "keyboard piano")]
),

# A man is dancing.
# A man is thinking.
(
  [("man", "is dancing", "")],
  [("man", "is thinking", "")]
),

# A man plays a trumpet.
# A man is playing the trumpet.
(
  [("man", "plays", "trumpet")],
  [("man", "is playing", "trumpet")]
),

# A woman is riding a horse.
# A man rides a horse.
(
  [("woman", "is riding", "horse")],
  [("man", "rides", "horse")]
),

# A band is playing on stage.
# A woman is dancing on a stage.
(
  [("band", "is playing on", "stage")],
  [("woman", "is dancing on", "stage")]
),

# A woman is playing a guitar and singing.
# A woman is playing the guitar.
(
  [("woman", "is playing", "guitar"), 
    ("woman", "is singing", "")],
  [("woman", "is playing", "guitar")]
),

# The man is eating.
# A man is eating food.
(
  [("man", "is eating", "")],
  [("man", "is eating", "food")]
),

# A little boy hits a golf ball.
# The little boy swung at the golf ball.
(
  [("little boy", "hits", "golf ball")],
  [("little boy", "swung at", "golf ball")]
),

# A guy is taking off his sunglasses.
# A boy is removing his sunglasses.
(
  [("guy", "is taking off", "sunglasses")],
  [("boy", "is removing", "sunglasses")]
),

# Someone is reading an email.
# A man is reading his email.
(
  [("someone", "is reading", "email")],
  [("man", "is reading", "email")]
),

# A person is slicing onions.
# Someone is slicing an onion.
(
  [("person", "is slicing", "onions")],
  [("someone", "is slicing", "onion")]
),

# A girl is coming up on a car.
# A girl jumps on top of a car.
(
  [("girl", "is coming up on", "car")],
  [("girl", "jumps on", "top"),
    ("top", "is of", "car")]
),

# A man is playing drums.
# A man is playing his guitar.
(
  [("man", "is playing", "drums")],
  [("man", "is playing", "guitar")]
),

# Someone is slicing a onion.
# Someone is carrying a fish.
(
  [("someone", "is slicing", "onion")],
  [("someone", "is carrying", "fish")]
),

# A woman is dicing some peeled potatoes cut into thick strips.
# A woman is chopping a peeled potato into slices.
(
  [("woman", "is dicing", "peeled potatoes"),  
    ("peeled potatoes", "are cut into", "thick strips")],
  [("woman", "is chopping", "peeled potato"), 
    ("peeled potato", "is chopped into", "slices")]
),

# A little girl peddling a scooter.
# A girl is riding a scooter.
(
  [("girl", "is", "little"),
    ("girl", "peddling", "scooter")],
  [("girl", "is riding", "scooter")]
),

# A cat cleans itself.
# A cat is licking itself.
(
  [("cat", "cleans", "itself")],
  [("cat", "is licking", "itself")]
),

# A man is kicking a soccer ball.
# A man is performing tricks with a soccer ball.
(
  [("man", "is kicking", "soccer ball")],
  [("man", "is performing", "tricks"), 
    ("tricks", "are performed with", "soccer ball")]
),

# A woman opens a window.
# A woman is looking out a window.
(
  [("woman", "opens", "window")],
  [("woman", "is looking out", "window")]
),

# Three men are doing same dance in the street.
# Three shirtless men are dancing in the street.
(
  [("three men", "are doing", "same dance"), 
    ("three men", "are in", "street")],
  [("three men", "are", "shirtless"),
    ("three men", "are dancing in", "street")]
),

# The man is playing the guitar.
# The man is peeling a potato.
(
  [("man", "is playing", "guitar")],
  [("man", "is peeling", "potato")]
),

# A man is dancing.
# A woman is exercising.
(
  [("man", "is dancing", "")],
  [("woman", "is exercising", "")]
),

# A woman is exercising.
# A man is dancing.
(
  [("woman", "is exercising", "")],
  [("man", "is dancing", "")]
),

# A boy is playing the violin onstage.
# A boy is playing an instrument.
(
  [("boy", "is playing", "violin"), 
   ("boy", "is playing on", "stage")],
  [("boy", "is playing", "instrument")]
),

# The woman is measuring the other woman.
# The lady measured the other woman's ankle.
(
  [("woman", "is measuring", "other woman")],
  [("lady", "measured", "ankle"),
   ("ankle", "is of", "other woman")]
),

# A man is doing exercise.
# A man is firing a rifle.
(
  [("man", "is doing", "exercise")],
  [("man", "is firing", "rifle")]
),

# A dog is playing with a toy.
# A dog is eating a doll.
(
  [("dog", "is playing with", "toy")],
  [("dog", "is eating", "doll")]
),

# A man is playing a piano.
# A guy is peeling a potato.
(
  [("man", "is playing", "piano")],
  [("guy", "is peeling", "potato")]
),

# A man is bowling.
# A kitten is walking.
(
  [("man", "is bowling", "")],
  [("kitten", "is walking", "")]
),

# A woman is dancing near a fire.
# A woman is cutting a tomatoe.
(
  [("woman", "is dancing", "near fire")],
  [("woman", "is cutting", "tomatoe")]
),

# A man is making a bed.
# A man is speaking to an audience.
(
  [("man", "is making", "bed")],
  [("man", "is speaking to", "audience")]
),

# A person is riding a motorcyle.
# A person is chopping an onion.
(
  [("person", "is riding", "motorcyle")],
  [("person", "is chopping", "onion")]
),

# A man pours rice into a pot.
# A man is putting rice in a bowling pot.
(
  [("man", "pours", "rice"), 
   ("man", "pours into", "pot")],
  [("man", "is putting", "rice"), 
   ("rice", "is put in", "bowling pot")]
),

# A person is slicing some garlic.
# A person is dicing a clove of garlic with a knife.
(
  [("person", "is slicing", "garlic")],
  [("person", "is dicing", "clove of garlic"), 
   ("person", "is dicing with", "knife")]
),

# A woman is slicing ginger.
# A woman is cutting potatoes.
(
  [("woman", "is slicing", "ginger")],
  [("woman", "is cutting", "potatoes")]
),

# Men are playing soccer.
# Two teams play soccer.
(
  [("men", "are playing", "soccer")],
  [("two teams", "play", "soccer")]
),

# A person is scrubbing a zucchini.
# A woman is scrubbing a zucchini with a vegetable brush.
(
  [("person", "is scrubbing", "zucchini")],
  [("woman", "is scrubbing", "zucchini"), 
   ("woman", "is scrubbing with", "vegetable brush")]
),

# A panda bear is chewing on a stick.
# A baby panda plays with a stick.
(
  [("panda bear", "is chewing on", "stick")],
  [("baby panda", "plays with", "stick")]
),

# The people are lifting bags.
# Several people are carrying large bags.
(
  [("people", "are lifting", "bags")],
  [("several people", "are carrying", "large bags")]
),

# A man is talking on the phone.
# A man is moon-walking across a store.
(
  [("man", "is talking on", "phone")],
  [("man", "is moon-walking across", "store")]
),

# A woman is braiding her hair.
# A man is riding a motorcycle.
(
  [("woman", "is braiding", "her hair")],
  [("man", "is riding", "motorcycle")]
),

# The man is throwing knives at a tree.
# A man is throwing blades into a close target outside.
(
  [("man", "is throwing", "knives"), 
   ("man", "is throwing at", "tree")],
  [("man", "is throwing", "blades"), 
   ("man", "is trhowing into", "close target"), 
   ("close target", "is", "outside")]
),

# The woman is slicing tofu.
# The woman is putting on lipstick.
(
  [("woman", "is slicing", "tofu")],
  [("woman", "is putting on", "lipstick")]
),

# A woman is folding paper.
# A woman is applying eye shadow.
(
  [("woman", "is folding", "paper")],
  [("woman", "is applying", "eye shadow")]
),

# Someone is folding a piece of paper.
# A person is slicing a small pieces of ginger.
(
  [("someone", "is folding", "piece of paper")],
  [("person", "is slicing", "pieces of ginger"),
   ("pieces of ginger", "are", "small")]
),

# A man is lifting weights.
# A man is chopping egg plant.
(
  [("man", "is lifting", "weights")],
  [("man", "is chopping", "egg plant")]
),

# A man is playing a cello.
# A man is rapidly lifting small weights.
(
  [("man", "is playing", "cello")],
  [("man", "is rapidly lifting", "small weights")]
),

# The man is talking.
# A man is walking down stairs.
(
  [("man", "is talking", "")],
  [("man", "is walking down", "stairs")]
),

# A man tries to feed a mouse to a snake.
# A man is teasing a snake with a mouse.
(
  [("man", "tries to feed", "mouse"), 
   ("man", "tries to feed to", "snake")],
  [("man", "is teasing", "snake"),
   ("man", "is teasing with", "mouse")]
),

# A man is playing the drums.
# A woman is slicing some leaves.
(
  [("man", "is playing", "drums")],
  [("woman", "is slicing", "leaves")]
),

# A man is playing a ukulele.
# A man is sitting and playing a small guitar.
(
  [("man", "is playing", "ukulele")],
  [("man", "is sitting", ""),
   ("man", "is playing", "small guitar")]
),

# A kitten is drinking milk from a bowl.
# A small child is drinking water from a cup.
(
  [("kitten", "is drinking", "milk"), 
   ("kitten", "is drinking from", "bowl")],
  [("child", "is", "small"),
   ("child", "is drinking", "water"), 
   ("child", "is drinking from", "cup")]
),

# A man breaks cinder blocks on another man.
# A woman breaks an egg into a pan.
(
  [("man", "breaks", "cinder blocks"), 
   ("cinder blocks", "are broken on", "another man")],
  [("woman", "breaks", "egg"), 
   ("egg", "is broken into", "pan")]
),

# A man is hitting a boy with flower vase.
# A man is cutting a mat.
(
  [("man", "is hitting", "boy"), 
   ("man", "is hitting with", "flower vase")],
  [("man", "is cutting", "mat")]
),

# The man is mixing whipping cream.
# The man is holding a skunk.
(
  [("man", "is mixing", "whipping cream")],
  [("man", "is holding", "skunk")]
),

# A man is stirring juice.
# A man is peeling an onion.
(
  [("man", "is stirring", "juice")],
  [("man", "is peeling", "onion")]
),

# Someone is slicing two uncooked racks of ribs apart.
# Someone is cutting a piece of meat.
(
  [("someone", "is slicing", "two uncooked racks"), 
   ("two uncooked rack", "are of", "ribs"),
   ("someone", "is slicing", "apart")],
  [("someone", "is cutting", "piece of meat")]
),

# A man is kicking pots of water.
# A man is turning foods.
(
  [("man", "is kicking", "pots"),
   ("pots", "are of", "water")],
  [("man", "is turning", "foods")]
),

# Two little girls talk on the telephone.
# Two couple are talking with each other.
(
  [("two girls", "are", "little"),
   ("two girls", "talk on", "telephone")],
  [("two couple", "are talking with", "each other")]
),

# A cat gets stuck on a moving ceiling fan.
# A cat is swinging on a fan.
(
  [("cat", "gets stuck on", "ceiling fan"),
   ("ceiling fan", "is", "moving")],
  [("cat", "is swinging on", "fan")]
),

# The cat is drinking milk.
# A white cat is licking and drinking milk kept on a plate.
(
  [("cat", "is drinking", "milk")],
  [("white cat", "is licking", "milk"),
   ("white cat", "is drinking", "milk"), 
   ("milk", "is kept on", "plate")]
),

# Rocky and Apollo Creed are running down the beach.
# The men are jogging on the beach.
(
  [("Rocky", "is running down", "beach"),
   ("Apollo Creed", "is running down", "beach")],
  [("men", "are jogging on", "beach")]
),

# A man is singing while playing the guitar.
# A man is stuffing himself full with food.
(
  [("man", "is singing", ""), 
   ("man", "is playing", "guitar")],
  [("man", "is stuffing", "himself"),
   ("man", "is stuffing full with", "food")]
),

# A boat sails along the water.
# The man is playing the guitar.
(
  [("boat", "sails along", "water")],
  [("man", "is playing", "guitar")]
),

# An okapi is eating from a tree.
# A moose drinks from a sprinkler.
(
  [("okapi", "is eating from", "tree")],
  [("moose", "drinks from", "sprinkler")]
),

# Several kids jump up and down on a trampoline.
# A man is doing back flips on a trampoline.
(
  [("several kids", "jump up on", "trampoline"),
   ("several kids", "jump down on", "trampoline")],
  [("man", "is doing", "back flips"), 
   ("back flips", "are done on", "trampoline")]
),

# A woman is pouring egg into a frying pan.
# A man is petting two dogs.
(
  [("woman", "is pouring", "egg"),
   ("woman", "is pouring into", "frying pan")],
  [("man", "is petting", "two dogs")]
),

# A woman is frying ground meat.
# A man is cutting a trunk with an axe.
(
  [("woman", "is frying", "ground meat")],
  [("man", "is cutting", "trunk"), 
   ("man", "is cutting with", "axe")]
),

# Three boys in karate costumes are fighting.
# Three men are practicing karate moves in a field.
(
  [("three boys", "are fighting", ""), 
   ("three boys", "are in", "karate costumes")],
  [("three men", "are practicing", "karate moves"), 
   ("three men", "are practicing in", "field")]
),

# Swimmers are racing in a lake.
# Women swimmers are diving in from the starting platform.
(
  [("swimmers", "are racing in", "lake")],
  [("women swimmers", "are diving in from", "starting platform")]
),

# A person is boiling noodles.
# A cat is licking a bottle.
(
  [("person", "is boiling", "noodles")],
  [("cat", "is licking", "bottle")]
),

# A person is slicing some onions.
# A woman is chopping herbs.
(
  [("person", "is slicing", "onions")],
  [("woman", "is chopping", "herbs")]
),

# A man reels in a fish.
# A woman is pouring oil in a bowl.
(
  [("man", "reels in", "fish")],
  [("woman", "is pouring", "oil"), 
   ("woman", "is pouring in", "bowl")]
),

# A woman is cutting an onion.
# A horse is standing.
(
  [("woman", "is cutting", "onion")],
  [("horse", "is standing", "")]
),

# A lady mixed up a meat mixture in bowl.
# A woman is stirring meat in a bowl.
(
  [("lady", "mixed up", "meat mixture"), 
   ("lady", "mixed up in", "bowl")],
  [("woman", "is stirring", "meat"), 
   ("woman", "is stirring in", "bowl")]
),

# A girl is applying makeup on her face.
# A woman is putting on makeup.
(
  [("girl", "is applying", "makeup"), 
   ("makeup", "is applied on", "face")],
  [("woman", "is putting on", "makeup")]
),

# A woman puts make-up on.
# A woman is putting on eyeshadow.
(
  [("woman", "puts on", "make-up")],
  [("woman", "is putting on", "eyeshadow")]
),

# A cat plays in his water.
# The cat fished a straw out ouf his water dish.
(
  [("cat", "plays in", "water")],
  [("cat", "fished", "straw"), 
   ("cat", "fished out of", "water dish")]    
),

# A person is adding food in a pan.
# A man is dancing in the street.
(
  [("person", "is adding", "food"), 
   ("person", "is adding in", "pan")],
  [("man", "is dancing in", "street")]
),

# A man is smoking.
# A baby is sucking on a pacifier.
(
  [("man", "is smoking", "")],
  [("baby", "is sucking on", "pacifier")]
),

# A person is putting shredded cheese in a pot.
# A hamster is eating some seeds.
(
  [("person", "is putting", "shredded cheese"), 
   ("person", "is putting in", "pot")],
  [("hamster", "is eating", "seeds")]
),

# A man is erasing a chalk board.
# A woman is dancing, and singing.
(
  [("man", "is erasing", "chalk board")],
  [("woman", "is dancing", ""), 
   ("woman", "is singing", "")]
),

# The man is exercising.
# A man is doing pull-ups.
(
  [("man", "is exercising", "")],
  [("man", "is doing", "pull-ups")]
),

# A chimp is kicking a target.
# A woman is putting oil into a skillet.
(
  [("chimp", "is kicking", "target")],
  [("woman", "is putting", "oil"), 
   ("woman", "is putting into", "skillet")]
),

# A man is doing exercise.
# A baby is laughing.
(
  [("man", "is doing", "exercise")],
  [("baby", "is laughing", "")]
),

# The girl is carrying a baby.
# A man is eating a food.
(
  [("girl", "is carrying", "baby")],
  [("man", "is eating", "food")]
),

# Several swimmers jump into the water.
# Swimmers are racing in a lake.
(
  [("swimmers", "are", "several"),
   ("swimmers", "jump into", "water")],
  [("swimmers", "are racing in", "lake")]
),

# A man spins on a surf board.
# A man is putting barbecue sauce on chicken.
(
  [("man", "spins on", "surf board")],
  [("man", "is putting", "barbecue sauce"), 
   ("man", "is putting on", "chicken")]
),

# A young man is riding a skateboard and jumps onto a sidewalk then off at another curb.
# A man is riding a skateboard.
(
  [("man", "is", "young"),
   ("man", "is riding", "skateboard"), 
   ("man", "jumps onto", "sidewalk"), 
   ("man", "jumps off", "another curb")],
  [("man", "is riding", "skateboard")]
),

# A person dices up an orange pepper.
# The cook is slicing bell peppers.
(
  [("person", "dices up", "orange pepper")],
  [("cook", "is slicing", "bell peppers")]
),

# Two men are dancing together.
# A woman opens a closet.
(
  [("two men", "are dancing", "together")],
  [("woman", "opens", "closet")]
),

# A man is reading an email.
# A person opening a banana.
(
  [("man", "is reading", "email")],
  [("person", "opening", "banana")]
),


]

print('MSR vid samples: ', len(msrvid_samples_ds))
# Out:
# MSR vid samples:  250

# %%
sents = 0
triplets = 0
words = 0
unique_words = set()
for pair in msrvid_samples_ds:
    for sent in pair:
        sents += 1
        for triplet in sent:
            text = ' '.join(triplet)
            words += len(text.split())
            for word in text.split():
                unique_words.add(word)
            triplets += 1
print('Words:', words)
print("Vocab. size:", len(unique_words))
print('Triplets:', triplets)
print('Triplets by sentence:', triplets / sents)
# Out:
# Words: 2872
# Vocab. size: 565
# Triplets: 657
# Triplets by sentence: 1.314

# %%
with open('msrvid_samples.pkl', 'wb') as f:
    pickle.dump([msrvid_samples_ds, scores_250], f)

# %% [markdown]
# ### AI request

# %%
with open('msrpar_prompt_120_125.txt', 'rt') as f:
    prompt = f.read()
#print(prompt)

kgs = get_answer(prompt)
print(kgs)

# %%
command = "Create a knowledge graph for the next sentence: "
instructions = ". Give results only as python code, where triplets \
(subject, relationship, object or attribute) must be under the form of python tuples. \
Do not show any type of comments in your answer, just the python code."

samples = []
for pair in pairs:
    s1 = pair[0]
    s2 = pair[1]
    #print(s1)
    a1 = get_answer(command + s1 + instructions)
    #print(s2)
    a2 = get_answer(command + s2 + instructions)
    samples.append('# ' + s1)
    samples.append('# ' + s2)
    samples.append(a1)
    samples.append(a2)

# %% [markdown]
# ### Data back

# %%
msrvid_samples_ds = [

# A girl is styling her hair.
([
    ("girl", "is styling", "hair")
],
# A girl is brushing her hair.
[
    ("girl", "is brushing", "hair")
]),

# A group of men play soccer on the beach.
([
    ("group", "is of", "men"),
    ("group", "play", "soccer"), 
    ("group", "play on", "beach")
], 
# A group of boys are playing soccer on the beach.
[   
    ("group", "is of", "boys"),
    ("group", "are playing", "soccer"), 
    ("group", "are playing on", "beach")
]),

# One woman is measuring another woman's ankle.
([
    ("woman", "is measuring", "ankle"), 
    ("ankle", "is of", "another woman")
], 
# A woman measures another woman's ankle.
[
    ("woman", "measures", "ankle"), 
    ("ankle", "is of", "another woman")
]),

# A man is cutting up a cucumber.
([
    ("man", "is cutting up", "cucumber")
],
# A man is slicing a cucumber.
[
    ("man", "is slicing", "cucumber")
]),

# A man is playing a harp.
([
    ("man", "is playing", "harp")
], 
# A man is playing a keyboard.
[
    ("man", "is playing", "keyboard")
]),

# A woman is cutting onions.
([
    ("woman", "is cutting", "onions")
],
# A woman is cutting tofu.
[
    ("woman", "is cutting", "tofu")
]),

# A man is riding an electric bicycle.
([
    ("man", "is riding", "electric bicycle")
], 
# A man is riding a bicycle.
[
    ("man", "is riding", "bicycle")
]),

# A man is playing the drums.
([
    ("man", "is playing", "drums")
], 
# A man is playing the guitar.
[
    ("man", "is playing", "guitar")
]),

# A man is playing guitar.
([
    ("man", "is playing", "guitar")
], 
# A lady is playing the guitar.
[
    ("lady", "is playing", "guitar")
]),

# A man is playing a guitar.
([
    ("man", "is playing", "guitar")
], 
# A man is playing a trumpet.
[
    ("man", "is playing", "trumpet")
]),

# A man is playing a guitar.
([
    ("man", "is playing", "guitar")
], 
# A man is playing a trumpet.
[
    ("man", "is playing", "trumpet")
]),

# A man is cutting an onion.
([
    ("man", "is cutting", "onion")
], 
# A man cuts an onion.
[
    ("man", "cuts", "onion")
]),

# A man is cycling.
([
    ("man", "is cycling", "")
], 
# A man is talking.
[
    ("man", "is talking", "")
]),

# A man is slicing open a fish.
([
    ("man", "is slicing open", "fish")
],
# A man is cutting up a fish.
[
    ("man", "is cutting up", "fish")
]),

# A man is slicing a tomato.
([
    ("man", "is slicing", "tomato")
], 
# A man is slicing a bun.
[
    ("man", "is slicing", "bun")
]),

# A man is playing a guitar.
([
    ("man", "is playing", "guitar")
], 
# A man is playing a keyboard.
[
    ("man", "is playing", "keyboard")
]),

# A baby panda goes down a slide.
([
    ("baby panda", "goes down", "slide")
],
# A panda slides down a slide.
[
    ("panda", "slides down", "slide")
]),

# A man is singing and playing a guitar.
([
    ("man", "is singing", ""), 
    ("man", "is playing", "guitar")
], 
# A man is playing a guitar.
[
    ("man", "is playing", "guitar")]
),

# A man attacks a woman.
([
    ("man", "attacks", "woman")
], 
# A man slaps a woman.
[
    ("man", "slaps", "woman")
]),

# A man is driving a car.
([
    ("man", "is driving", "car")
], 
# A man is riding a horse.
[
    ("man", "is riding", "horse")
]),


# A woman is cutting tofu.
([("woman", "is cutting", "tofu")], 
# A woman is cutting an onion.
[("woman", "is cutting", "onion")]),

# The woman is styling her hair.
([("woman", "is styling", "hair")], 
# The woman is slicing herbs.
[("woman", "is slicing", "herbs")]),

# Two zebras play in an open field.
([("two zebras", "play in", "field"),
  ("field", "is", "open")], 
# Two zebras are playing in a field.
[("two zebras", "are playing in", "field")]),

# A man is cutting a potato.
([("man", "is cutting", "potato")], 
# A man is slicing some potato.
[("man", "is slicing", "potato")]),

# A man is slicing an onion.
([("man", "is slicing", "onion")], 
# A woman is slicing a pumpkin.
[("woman", "is slicing", "pumpkin")]),

# A man is dancing.
([("man", "is dancing", "")], 
# A man and woman is dancing.
[("man", "is dancing", ""),
 ("woman", "is dancing", "")]),

# A man is riding a motorcycle.
([("man", "is riding", "motorcycle")], 
# A woman is riding a horse.
[("woman", "is riding", "horse")]),

# A woman is slicing garlics.
([("woman", "is slicing", "garlics")], 
# A woman is slicing an onion.
[("woman", "is slicing", "onion")]),

# A man is speaking.
([("man", "is speaking", "")], 
# A man is cooking.
[("man", "is cooking", "")]),

# A little boy is singing and playing a guitar.
([("little boy", "is singing", ""), 
  ("little boy", "is playing", "guitar")], 
# A man is singing and playing the guitar.
[("man", "is singing", ""), 
 ("man", "is playing", "guitar")]),

# A turtle is swimming in water.
([("turtle", "is swimming in", "water")], 
# A turtle is walking underwater.
[("turtle", "is walking", "underwater")]),

# A young woman is putting stickers all over her face.
([("woman", "is", "young"),
  ("woman", "is putting", "stickers"), 
  ("stickers", "are all over", "face")], 
# A woman is applying stickers to her face.
[("woman", "is applying", "stickers"), 
 ("stickers", "are applied to", "face")]),

# A woman is wrapping tofu.
([("woman", "is wrapping", "tofu")], 
# A woman is balling dough.
[("woman", "is balling", "dough")]),

# A cat is eating some corn.
([("cat", "is eating", "corn")], 
# A cat is eating corn on the cob.
[("cat", "is eating", "corn"),
 ("corn", "is on", "cob")]),

# A man is eating a food.
([("man", "is eating", "food")], 
# A man is eating a piece of bread.
[("man", "is eating", "piece of bread")]),

# A man is playing a guitar.
([("man", "is playing", "guitar")], 
# A man is eating pasta.
[("man", "is eating", "pasta")]),

# A man is kicking pots of water.
([("man", "is kicking", "pots"),
  ("pots", "are of", "water")], 
# A man is picking flowers.
[("man", "is picking", "flowers")]),

# A man is cutting a pipe with scissors.
([("man", "is cutting", "pipe"), 
  ("man", "is cutting with", "scissors")], 
# A man is cutting carpet with a knife.
[("man", "is cutting", "carpet"), 
 ("man", "is cutting with", "knife")]),

# A woman is dancing in the rain.
([("woman", "is dancing in", "rain")], 
# A woman dances in the rain out side.
[("woman", "dances in", "rain"), 
 ("woman", "dances", "out side")]),

# A woman is taking a bath.
([("woman", "is taking", "bath")], 
# A woman is riding a horse.
[("woman", "is riding", "horse")]),

# A man mixes vegetables in a pot.
([("man", "mixes", "vegetables"), 
  ("man", "mixes", "in a pot")], 
# A person is stirring vegetables in a pot.
[("person", "is stirring", "vegetables"), 
 ("person", "is stirring", "in a pot")]),

# A woman is talking on a cell phone.
([("woman", "is talking on", "cell phone")], 
# A man and woman are talking on the phone.
[("man", "is talking on", "phone"),
 ("woman", "is talking on", "phone")]),

# A man is playing a guitar.
([("man", "is playing", "guitar")], 
# A man is singing while playing the guitar.
[("man", "is singing", ""), 
 ("man", "is playing", "guitar")]),

# A man is playing a guitar.
([("man", "is playing", "guitar")], 
# A man is driving a car.
[("man", "is driving", "car")]),

# A man is cutting apple by his hand.
([("man", "is cutting", "apple"), 
  ("man", "is cutting by", "hand")], 
# A man is cutting carpet with a knife.
[("man", "is cutting", "carpet"), 
 ("man", "is cutting with", "knife")]),

# A man is opening a door.
([("man", "is opening", "door")], 
# A man is cutting an onion.
[("man", "is cutting", "onion")]),

# A man is slicing a tomato.
([("man", "is slicing", "tomato")], 
# A man is riding a horse.
[("man", "is riding", "horse")]),

# A man is cutting paper with a sword.
([("man", "is cutting", "paper"), 
  ("man", "is cutting with", "sword")], 
# A woman is cutting a tomato.
[("woman", "is cutting", "tomato")]),

# A boy studies a calendar.
([("boy", "studies", "calendar")], 
# A boy is looking at a calendar.
[("boy", "is looking at", "calendar")]),

# The ballerina is dancing.
([("ballerina", "is dancing", "")], 
# A man is dancing.
[("man", "is dancing", "")]),

# A woman is dancing.
([("woman", "is dancing", "")], 
# A woman is playing violin.
[("woman", "is playing", "violin")]),

# A woman is slicing some tomatoes.
([("woman", "is slicing", "tomatoes")], 
# A woman is chopping a potato.
[("woman", "is chopping", "potato")]),

# A woman is water skiing.
([("woman", "is water skiing", "")], 
# A woman is slicing fish.
[("woman", "is slicing", "fish")]),

# A man is playing a flute.
([("man", "is playing", "flute")], 
# A man is riding a scooter.
[("man", "is riding", "scooter")]),

# A man is playing the piano.
([("man", "is playing", "piano")], 
# A man played the guitar.
[("man", "played", "guitar")]),

# A woman is picking a can.
([("woman", "is picking", "can")], 
# A man is playing a guitar.
[("man", "is playing", "guitar")]),

# A man puts three pieces of meat into a pan.
([("man", "puts", "three pieces"),
  ("three pieces", "are of", "meat"),
  ("man", "puts into", "pan")], 
# A man is putting meat in a pan.
[("man", "is putting", "meat"), 
 ("man", "is putting in", "pan")]),

# A woman is cutting an onion.
([("woman", "is cutting", "onion")], 
# A woman is cleaning a garden.
[("woman", "is cleaning", "garden")]),

# Some men are sawing.
([("some men", "are sawing", "")], 
# Men are sawing logs.
[("men", "are sawing", "logs")]),

# A car is driven down the road.
([("car", "is driven down", "road")], 
# A girl is walking down a road.
[("girl", "is walking down", "road")]),

# The man is kissing and hugging the woman.
([("man", "is kissing", "woman"), 
  ("man", "is hugging", "woman")], 
# A man is hugging and kissing a woman.
[("man", "is hugging", "woman"), 
 ("man", "is kissing", "woman")]),

# A train is moving.
([("train", "is moving", "")], 
# A man is doing yoga.
[("man", "is doing", "yoga")]),

# Someone is slicing an onion.
([("someone", "is slicing", "onion")], 
# A woman is cutting onion.
[("woman", "is cutting", "onion")]),

# A woman is playing in the ocean.
([("woman", "is playing in", "ocean")], 
# A woman is preparing shrimp to cook.
[("woman", "is preparing", "shrimp"), 
 ("shrimp", "is to", "cook")]),

# A person is playing an electronic keyboard.
([("person", "is playing", "electronic keyboard")], 
# A kid is playing keyboard.
[("kid", "is playing", "keyboard")]),

# A man is holding a leaf.
([("man", "is holding", "leaf")], 
# A monkey is fighting a man.
[("monkey", "is fighting", "man")]),

# A woman is peeling shrimp.
([("woman", "is peeling", "shrimp")], 
# A man is squeezing water.
[("man", "is squeezing", "water")]),

# A man is sitting and smoking.
([("man", "is sitting", ""), 
  ("man", "is smoking", "")], 
# A man is smoking a cigarette.
[("man", "is smoking", "cigarette")]),

# A man is playing a guitar.
([("man", "is playing", "guitar")], 
# A woman is riding a horse.
[("woman", "is riding", "horse")]),

# A man is standing in front of the window and looking outside.
([("man", "is standing in front", "window"), 
  ("man", "is looking", "outside")], 
# A man is staring out the window.
[("man", "is staring out", "window")]),

# A skunk is looking here and there.
([("skunk", "is looking", "here"),
  ("skunk", "is looking", "there")], 
# A skunk looks at the camera.
[("skunk", "looks at", "camera")]),

# A man is playing the guitar and singing.
([("man", "is playing", "guitar"), 
  ("man", "is singing", "")], 
# A man sings with a guitar.
[("man", "sings with", "guitar")]),

# A woman opens a window.
([("woman", "opens", "window")], 
# A man is crawling.
[("man", "is crawling", "")]),

# People are dancing outside.
([("people", "are dancing", "outside")], 
# A group of people are dancing.
[("group", "is of", "people"),
 ("group", "are dancing", "")]),

# The man is using a camera to hammer a nail.
([("man", "is using", "camera"), 
  ("camera", "is to", "hammer a nail")], 
# Someone is banging a camera lense against a nail.
[("someone", "is banging", "camera lense"), 
 ("camera lense", "is against", "nail")]),

# A woman is filing her nails.
([("woman", "is filing", "nails")], 
# A man is peeling a carrot.
[("man", "is peeling", "carrot")]),

# A boy is crawling into a dog house.
([("boy", "is crawling into", "dog house")], 
# A boy is playing a wooden flute.
[("boy", "is playing", "wooden flute")]),

# A woman is swimming underwater.
([("woman", "is swimming", "underwater")], 
# A man is slicing some carrots.
[("man", "is slicing", "carrots")]),

# A machine is sharpening a pencil.
([("machine", "is sharpening", "pencil")], 
# The machine shaved the end of the pencil.
[("machine", "shaved", "end"),
 ("end", "is of", "pencil")]),

# A monkey is playing drums.
([("monkey", "is playing", "drums")], 
# A gorilla plays the drums.
[("gorilla", "plays", "drums")]),


# A man is opening a box and taking out paper.
([("man", "is opening", "box"), ("man", "is taking out", "paper")], 
# A woman is peeling a potato.
[("woman", "is peeling", "potato")]),

# A woman is dancing.
([("woman", "is dancing", "")], 
# A woman plays the clarinet.
[("woman", "plays", "clarinet")]),

# A person is drawing on a large touchscreen.
([("person", "is drawing on", "large touchscreen")], 
# A man is drawing on a digital dry erase board.
[("man", "is drawing on", "board"),
 ("board", "is", "digital dry erase")]),

# The men played follow the leader on the grass.
([("men", "played", "follow the leader"), 
  ("men", "played", "on the grass")], 
# The rhino grazed on the grass.
[("rhino", "grazed on", "grass")]),

# A woman is cracking eggs.
([("woman", "is cracking", "eggs")], 
# A man is talking to a woman.
[("man", "is talking to", "woman")]),

# A woman peels garlic with her hands.
([("woman", "peels", "garlic"), 
  ("woman", "peel with", "hands")], 
# The woman is slicing herbs.
[("woman", "is slicing", "herbs")]),

# The polar bears fought over the kill.
([("polar bears", "fought over", "kill")], 
# Polar bears are fighting each other.
[("polar bears", "are fighting", "each other")]),

# A man is doing trick with play cards.
([("man", "is doing", "trick"), 
  ("trick", "is with", "play cards")], 
# A man is performing a card trick.
[("man", "is performing", "card trick")]),

# The cat is licking a bottle.
([("cat", "is licking", "bottle")], 
# A cat plays with a small bottle.
[("cat", "plays with", "small bottle")]),

# A person is slicing an onion.
([("person", "is slicing", "onion")], 
# A person cuts ginger.
[("person", "cuts", "ginger")]),

# A person is peeling a potato with a potato peeler.
([("person", "is peeling", "potato"), 
  ("person", "is peeling with", "potato peeler")], 
# A man is cutting tomatoes with a cleaver.
[("man", "is cutting", "tomatoes"), 
 ("man", "is cutting with", "cleaver")]),

# Two women are dancing and singing in front of a crowd.
([("two women", "are dancing", ""), 
  ("two women", "are singing", ""), 
  ("two women", "are dancing in", "front of a crowd"), 
  ("two women", "are singing in", "front of a crowd")], 
# The women are singing and dancing.
[("women", "are singing", ""), 
 ("women", "are dancing", "")]),

# A man is seasoning some carrots.
([("man", "is seasoning", "carrots")], 
# A woman is slicing garlic.
[("woman", "is slicing", "garlic")]),

# Two men pushed carts through the woods.
([("two men", "pushed", "carts"),
  ("two men", "pushed", "through the woods")], 
# Two men are pushing carts.
[("two men", "are pushing", "carts")]),

# A man is playing a football.
([("man", "is playing", "football")], 
# A man is maneuvering a soccer ball with his feet.
[("man", "is maneuvering", "soccer ball"), 
 ("man", "is maneuvering", "with his feet")]),

# The lady peeled the potatoe.
([("lady", "peeled", "potatoe")], 
# A woman is peeling a potato.
[("woman", "is peeling", "potato")]),

# A woman is slicing some tofu.
([("woman", "is slicing", "tofu")], 
# A woman is cutting a block of tofu into small cubes.
[("woman", "is cutting", "block of tofu"), 
 ("woman", "is cutting into", "small cubes")]),

# Someone typed on a keyboard.
([("someone", "typed on", "keyboard")], 
# Someone is typing.
[("someone", "is typing", "")]),

# Three young men run, jump, and kick off of a Coke machine.
([("three men", "are", "young"),
  ("three men", "run", ""), 
  ("three men", "jump", ""), 
  ("three men", "kick off of", "Coke machine")], 
# Three men are jumping off a wall.
[("three men", "are jumping off", "wall")]),

# A young Asian girl is applying eyeliner.
([("Asian girl", "is", "young"),
  ("Asian girl", "is applying", "eyeliner")], 
# A girl is putting on eye makeup.
[("girl", "is putting on", "eye makeup")]),

# A cat is walking around a house.
([("cat", "is walking around", "house")], 
# A woman is peeling potato.
[("woman", "is peeling", "potato")]),

# A woman is talking to her pet bunny as she fondles it.
([("woman", "is talking to", "pet bunny"), 
  ("woman", "fondles", "pet bunny")], 
# A woman walks her dog onto astro turf.
[("woman", "walks", "dog"), 
 ("woman", "walks onto", "astro turf")]),

# A monkey is playing drums.
([("monkey", "is playing", "drums")], 
# Someone in a gorilla costume is playing a set of drums.
[("someone", "is playing", "set of drums"), 
 ("someone", "is in", "gorilla costume")]),

# A man is riding a white horse on an enclosed ground.
([("man", "is riding", "white horse"), 
  ("man", "is riding on", "enclosed ground")], 
# Someone is riding a horse.
[("someone", "is riding", "horse")]),

# An oriental lady is cutting a carrot into thin pieces.
([("oriental lady", "is cutting", "carrot"),
  ("carrot", "is cut into", "thin pieces")], 
# A woman is slicing a carrot.
[("woman", "is slicing", "carrot")]),

# A group of people are dancing.
([("group", "is of", "people"),
  ("group", "are dancing", "")], 
# Women are dancing outside.
[("women", "are dancing", "outside")]),

# A man is playing guitar.
([("man", "is playing", "guitar")], 
# A boy is talking to a giant dog.
[("boy", "is talking to", "giant dog")]),

# A woman mixes up vegetables.
([("woman", "mixes up", "vegetables")], 
# A woman is adding ingredients to a skillet.
[("woman", "is adding", "ingredients"), 
 ("ingredients", "are added to", "skillet")]),

# A woman pours a mixture into a bowl and mixes it.
([("woman", "pours", "mixture"), 
  ("mixture", "is poured into", "bowl"), 
  ("woman", "mixes", "mixture")], 
# A woman is preparing an egg in a skillet.
[("woman", "is preparing", "egg"), 
 ("egg", "is prepared in", "skillet")]),

# A man is cutting pieces of butter into a mixing bowl.
([("man", "is cutting", "pieces of butter"), 
  ("pieces of butter", "are cut into", "mixing bowl")], 
# Pieces of butter is added in the stand mixer.
[("pieces of butter", "is added in", "stand mixer")]),

# A man is putting garlic on some bread slices.
([("man", "is putting", "garlic"), 
  ("garlic", "is put on", "bread slices")], 
# A man is sprinkling seasoning on several split and buttered loaves of bread.
[("man", "is sprinkling", "seasoning"), 
 ("seasoning", "is on", "loaves of bread"),
 ("loaves of bread", "are", "several"),
 ("loaves of bread", "are", "split"),
 ("loaves of bread", "are", "buttered")
 ]),

# The panda bear lay on the logs.
([("panda bear", "lay on", "logs")], 
# A panda is lying down.
[("panda", "is lying down", "")]),

# Five men jump into a swimming pool.
([("five men", "jump into", "swimming pool")], 
# A group of swimmers fall into a pool.
[("group", "is of", "swimmers"),
 ("group", "fall into", "pool")]),

# A cheetah is running behind its prey.
([("cheetah", "is running behind", "prey")], 
# A cheetah chases prey on across a field.
[("cheetah", "chases", "prey"), 
 ("cheetah", "chases on", "across a field")]),

# A cat is playing on the floor.
([("cat", "is playing on", "floor")], 
# A man is slicing garlic.
[("man", "is slicing", "garlic")]),

# A boy is playing violin on stage.
([("boy", "is playing", "violin"), 
  ("boy", "is playing on", "stage")], 
# A person is mixing a pot.
[("person", "is mixing", "pot")]),

# A dog is barking at a toy.
([("dog", "is barking at", "toy")], 
# The little dog barked at the electronic toy.
[("little dog", "barked at", "electronic toy")]),

# A man is cycling.
([("man", "is cycling", "")], 
# A boy is riding a bicycle.
[("boy", "is riding", "bicycle")]),

# A woman is slicing ginger.
([("woman", "is slicing", "ginger")], 
# A person is holding two baby lorises.
[("person", "is holding", "two baby lorises")]),

# A man is dragging a dead deer.
([("man", "is dragging", "dead deer")], 
# A man is jumping into water from a cliff.
[("man", "is jumping into", "water"), 
 ("man", "is jumping from", "cliff")]),


# A man is preparing a snake for cooking.
# The man is dropping sliced cucumbers into water.
(
  [("man", "is preparing", "snake"), 
   ("snake", "is for", "cooking")],
  [("man", "is dropping", "sliced cucumbers"), 
   ("sliced cucumbers", "are into", "water")]
),

# A woman is spreading mustard on a bread roll.
# A kitten is playing with a woman's finger.
(
  [("woman", "is spreading", "mustard"), 
   ("mustard", "is on", "bread roll")],
  [("kitten", "is playing with", "woman's finger")]
),

# Someone touched the kitten chewing on a string.
# Someone is cutting paper.
(
  [("someone", "touched", "kitten"), ("kitten", "is chewing on", "string")],
  [("someone", "is cutting", "paper")]
),

# Meat is being put into a skillet.
# A woman is putting a baby into a trash can.
(
  [("meat", "is being put into", "skillet")],
  [("woman", "is putting", "baby"), 
   ("baby", "is into", "trash can")]
),

# A baby elephant is eating a small tree.
# A little girl peddling a scooter.
(
  [("baby elephant", "is eating", "small tree")],
  [("little girl", "is peddling", "scooter")]
),

# A woman and man are dancing in the rain.
# A man and woman are dancing in rain.
(
  [("woman", "is dancing in", "rain"), 
   ("man", "is dancing in", "rain")],
  [("man", "is dancing in", "rain"), 
   ("woman", "is dancing in", "rain")]
),

# Someone is drawing.
# Someone is dancing.
(
  [("someone", "is drawing", "")],
  [("someone", "is dancing", "")]
),

# A man is playing a guitar.
# A woman is playing the guitar.
(
  [("man", "is playing", "guitar")],
  [("woman", "is playing", "guitar")]
),

# Two men are fistfighting in a ring.
# Two men fistfight in a ring.
(
  [("two men", "are fistfighting in", "ring")],
  [("two men", "fistfight in", "ring")]
),

# A person wipes butter on a tray.
# A person is buttering a tray.
(
  [("person", "wipes", "butter"), 
   ("butter", "is on", "tray")],
  [("person", "is buttering", "tray")]
),

# Two men are playing football.
# Two men are practicing football.
(
  [("two men", "are playing", "football")],
  [("two men", "are practicing", "football")]
),

# The man is playing the guitar.
# The girl is playing the guitar.
(
  [("man", "is playing", "guitar")],
  [("girl", "is playing", "guitar")]
),

# A man is peeling a potato.
# A man is slicing a potato.
(
  [("man", "is peeling", "potato")],
  [("man", "is slicing", "potato")]
),

# A woman is stabbing a potato with a fork.
# A woman is puncturing a potato with a fork.
(
  [("woman", "is stabbing", "potato"), 
   ("woman", "is stabbing with", "fork")],
  [("woman", "is puncturing", "potato"), 
   ("woman", "is puncturing with", "fork")]
),

# A child is waking up.
# A girl is waking up.
(
  [("child", "is waking up", "")],
  [("girl", "is waking up", "")]
),

# A boy is playing a key-board.
# A little boy is playing a keyboard.
(
  [("boy", "is playing", "key-board")],
  [("boy", "is", "little"),
   ("boy", "is playing", "keyboard")]
),

# A woman plays the flute.
# A woman is playing the flute.
(
  [("woman", "plays", "flute")],
  [("woman", "is playing", "flute")]
),

# A woman is playing an electric guitar.
# A man is playing an acoustic guitar.
(
  [("woman", "is playing", "electric guitar")],
  [("man", "is playing", "acoustic guitar")]
),

# A man is playing a flute.
# A man is playing a guitar.
(
  [("man", "is playing", "flute")],
  [("man", "is playing", "guitar")]
),

# A group of people are sweeping water out of a house.
# People are sweeping water out of a house.
(
  [("group of people", "are sweeping", "water"), 
   ("group of people", "are sweeping out of", "house")],
  [("people", "are sweeping", "water"), 
   ("people", "are sweeping out of", "house")]
),

# A man plays a guitar.
# A man is playing a guitar.
(
  [("man", "plays", "guitar")],
  [("man", "is playing", "guitar")]
),

# A man and a woman is kissing each other.
# A man and a woman are hugging and kissing each other.
(
  [("man", "is kissing", "woman"), 
   ("woman", "is kissing", "man")],
  [("man", "are hugging", "woman"), 
   ("man", "are kissing", "woman"), 
   ("woman", "are hugging", "man"), 
   ("woman", "are kissing", "man")]
),

# A woman is climbing a cliff.
# A woman is climbing a rock face.
(
  [("woman", "is climbing", "cliff")],
  [("woman", "is climbing", "rock face")]
),

# A polar bear is running towards a group of walruses.
# A polar bear is chasing a group of walruses.
(
  [("polar bear", "is running towards", "group of walruses")],
  [("polar bear", "is chasing", "group of walruses")]
),

# A woman is cutting some fish.
# A woman is cutting tofu.
(
  [("woman", "is cutting", "fish")],
  [("woman", "is cutting", "tofu")]
),

# Someone is playing a piano.
# Someone is playing guitar.
(
  [("someone", "is playing", "piano")],
  [("someone", "is playing", "guitar")]
),

# A man is pouring rice a roni into a pan.
# A man poured ric-a-roni into a pan.
(
  [("man", "is pouring", "rice a roni"), 
   ("man", "is pouring into", "pan"),],
  [("man", "poured", "ric-a-roni"), 
   ("man", "poured into", "pan")]
),

# A man is breaking wooden boards with his hand.
# A man is breaking tiles with his hands.
(
  [("man", "is breaking", "wooden boards"), 
   ("man", "is breaking with", "hand")],
  [("man", "is breaking", "tiles"), 
   ("man", "is breaking with", "hands")]
),

# A girl is playing guitar.
# A girl is playing a piano.
(
  [("girl", "is playing", "guitar")],
  [("girl", "is playing", "piano")]
),

# A man is praying.
# A man is dancing.
(
  [("man", "is praying", "")],
  [("man", "is dancing", "")]
),


# A man is playing piano.
# A man is playing a violin.
(
  [("man", "is playing", "piano")],
  [("man", "is playing", "violin")]
),

# A woman is slicing an onion.
# A woman is slicing lemons.
(
  [("woman", "is slicing", "onion")],
  [("woman", "is slicing", "lemons")]
),

# A man is riding a horse by a creek.
# A man is riding a horse.
(
  [("man", "is riding", "horse"), 
    ("man", "is riding by", "creek")],
  [("man", "is riding", "horse")]
),

# A man is playing a guitar.
# A man is playing a guitar and singing.
(
  [("man", "is playing", "guitar")],
  [("man", "is playing", "guitar"), 
    ("man", "is singing", "")]
),

# A man is picking up a tree.
# A man is carrying a tree.
(
  [("man", "is picking up", "tree")],
  [("man", "is carrying", "tree")]
),

# A person is peeling a potato.
# The man is peeling a potato.
(
  [("person", "is peeling", "potato")],
  [("man", "is peeling", "potato")]
),

# A person is playing a piano.
# A person is slicing a potato.
(
  [("person", "is playing", "piano")],
  [("person", "is slicing", "potato")]
),

# A man is spitting.
# A man is talking.
(
  [("man", "is spitting", "")],
  [("man", "is talking", "")]
),

# A man is playing a musical keyboard.
# A man is playing a keyboard piano.
(
  [("man", "is playing", "musical keyboard")],
  [("man", "is playing", "keyboard piano")]
),

# A man is dancing.
# A man is thinking.
(
  [("man", "is dancing", "")],
  [("man", "is thinking", "")]
),

# A man plays a trumpet.
# A man is playing the trumpet.
(
  [("man", "plays", "trumpet")],
  [("man", "is playing", "trumpet")]
),

# A woman is riding a horse.
# A man rides a horse.
(
  [("woman", "is riding", "horse")],
  [("man", "rides", "horse")]
),

# A band is playing on stage.
# A woman is dancing on a stage.
(
  [("band", "is playing on", "stage")],
  [("woman", "is dancing on", "stage")]
),

# A woman is playing a guitar and singing.
# A woman is playing the guitar.
(
  [("woman", "is playing", "guitar"), 
    ("woman", "is singing", "")],
  [("woman", "is playing", "guitar")]
),

# The man is eating.
# A man is eating food.
(
  [("man", "is eating", "")],
  [("man", "is eating", "food")]
),

# A little boy hits a golf ball.
# The little boy swung at the golf ball.
(
  [("little boy", "hits", "golf ball")],
  [("little boy", "swung at", "golf ball")]
),

# A guy is taking off his sunglasses.
# A boy is removing his sunglasses.
(
  [("guy", "is taking off", "sunglasses")],
  [("boy", "is removing", "sunglasses")]
),

# Someone is reading an email.
# A man is reading his email.
(
  [("someone", "is reading", "email")],
  [("man", "is reading", "email")]
),

# A person is slicing onions.
# Someone is slicing an onion.
(
  [("person", "is slicing", "onions")],
  [("someone", "is slicing", "onion")]
),

# A girl is coming up on a car.
# A girl jumps on top of a car.
(
  [("girl", "is coming up on", "car")],
  [("girl", "jumps on", "top"),
    ("top", "is of", "car")]
),

# A man is playing drums.
# A man is playing his guitar.
(
  [("man", "is playing", "drums")],
  [("man", "is playing", "guitar")]
),

# Someone is slicing a onion.
# Someone is carrying a fish.
(
  [("someone", "is slicing", "onion")],
  [("someone", "is carrying", "fish")]
),

# A woman is dicing some peeled potatoes cut into thick strips.
# A woman is chopping a peeled potato into slices.
(
  [("woman", "is dicing", "peeled potatoes"),  
    ("peeled potatoes", "are cut into", "thick strips")],
  [("woman", "is chopping", "peeled potato"), 
    ("peeled potato", "is chopped into", "slices")]
),

# A little girl peddling a scooter.
# A girl is riding a scooter.
(
  [("girl", "is", "little"),
    ("girl", "peddling", "scooter")],
  [("girl", "is riding", "scooter")]
),

# A cat cleans itself.
# A cat is licking itself.
(
  [("cat", "cleans", "itself")],
  [("cat", "is licking", "itself")]
),

# A man is kicking a soccer ball.
# A man is performing tricks with a soccer ball.
(
  [("man", "is kicking", "soccer ball")],
  [("man", "is performing", "tricks"), 
    ("tricks", "are performed with", "soccer ball")]
),

# A woman opens a window.
# A woman is looking out a window.
(
  [("woman", "opens", "window")],
  [("woman", "is looking out", "window")]
),

# Three men are doing same dance in the street.
# Three shirtless men are dancing in the street.
(
  [("three men", "are doing", "same dance"), 
    ("three men", "are in", "street")],
  [("three men", "are", "shirtless"),
    ("three men", "are dancing in", "street")]
),

# The man is playing the guitar.
# The man is peeling a potato.
(
  [("man", "is playing", "guitar")],
  [("man", "is peeling", "potato")]
),

# A man is dancing.
# A woman is exercising.
(
  [("man", "is dancing", "")],
  [("woman", "is exercising", "")]
),

# A woman is exercising.
# A man is dancing.
(
  [("woman", "is exercising", "")],
  [("man", "is dancing", "")]
),

# A boy is playing the violin onstage.
# A boy is playing an instrument.
(
  [("boy", "is playing", "violin"), 
   ("boy", "is playing on", "stage")],
  [("boy", "is playing", "instrument")]
),

# The woman is measuring the other woman.
# The lady measured the other woman's ankle.
(
  [("woman", "is measuring", "other woman")],
  [("lady", "measured", "ankle"),
   ("ankle", "is of", "other woman")]
),

# A man is doing exercise.
# A man is firing a rifle.
(
  [("man", "is doing", "exercise")],
  [("man", "is firing", "rifle")]
),

# A dog is playing with a toy.
# A dog is eating a doll.
(
  [("dog", "is playing with", "toy")],
  [("dog", "is eating", "doll")]
),

# A man is playing a piano.
# A guy is peeling a potato.
(
  [("man", "is playing", "piano")],
  [("guy", "is peeling", "potato")]
),

# A man is bowling.
# A kitten is walking.
(
  [("man", "is bowling", "")],
  [("kitten", "is walking", "")]
),

# A woman is dancing near a fire.
# A woman is cutting a tomatoe.
(
  [("woman", "is dancing", "near fire")],
  [("woman", "is cutting", "tomatoe")]
),

# A man is making a bed.
# A man is speaking to an audience.
(
  [("man", "is making", "bed")],
  [("man", "is speaking to", "audience")]
),

# A person is riding a motorcyle.
# A person is chopping an onion.
(
  [("person", "is riding", "motorcyle")],
  [("person", "is chopping", "onion")]
),

# A man pours rice into a pot.
# A man is putting rice in a bowling pot.
(
  [("man", "pours", "rice"), 
   ("man", "pours into", "pot")],
  [("man", "is putting", "rice"), 
   ("rice", "is put in", "bowling pot")]
),

# A person is slicing some garlic.
# A person is dicing a clove of garlic with a knife.
(
  [("person", "is slicing", "garlic")],
  [("person", "is dicing", "clove of garlic"), 
   ("person", "is dicing with", "knife")]
),

# A woman is slicing ginger.
# A woman is cutting potatoes.
(
  [("woman", "is slicing", "ginger")],
  [("woman", "is cutting", "potatoes")]
),

# Men are playing soccer.
# Two teams play soccer.
(
  [("men", "are playing", "soccer")],
  [("two teams", "play", "soccer")]
),

# A person is scrubbing a zucchini.
# A woman is scrubbing a zucchini with a vegetable brush.
(
  [("person", "is scrubbing", "zucchini")],
  [("woman", "is scrubbing", "zucchini"), 
   ("woman", "is scrubbing with", "vegetable brush")]
),

# A panda bear is chewing on a stick.
# A baby panda plays with a stick.
(
  [("panda bear", "is chewing on", "stick")],
  [("baby panda", "plays with", "stick")]
),

# The people are lifting bags.
# Several people are carrying large bags.
(
  [("people", "are lifting", "bags")],
  [("several people", "are carrying", "large bags")]
),

# A man is talking on the phone.
# A man is moon-walking across a store.
(
  [("man", "is talking on", "phone")],
  [("man", "is moon-walking across", "store")]
),

# A woman is braiding her hair.
# A man is riding a motorcycle.
(
  [("woman", "is braiding", "her hair")],
  [("man", "is riding", "motorcycle")]
),

# The man is throwing knives at a tree.
# A man is throwing blades into a close target outside.
(
  [("man", "is throwing", "knives"), 
   ("man", "is throwing at", "tree")],
  [("man", "is throwing", "blades"), 
   ("man", "is trhowing into", "close target"), 
   ("close target", "is", "outside")]
),

# The woman is slicing tofu.
# The woman is putting on lipstick.
(
  [("woman", "is slicing", "tofu")],
  [("woman", "is putting on", "lipstick")]
),

# A woman is folding paper.
# A woman is applying eye shadow.
(
  [("woman", "is folding", "paper")],
  [("woman", "is applying", "eye shadow")]
),

# Someone is folding a piece of paper.
# A person is slicing a small pieces of ginger.
(
  [("someone", "is folding", "piece of paper")],
  [("person", "is slicing", "pieces of ginger"),
   ("pieces of ginger", "are", "small")]
),

# A man is lifting weights.
# A man is chopping egg plant.
(
  [("man", "is lifting", "weights")],
  [("man", "is chopping", "egg plant")]
),

# A man is playing a cello.
# A man is rapidly lifting small weights.
(
  [("man", "is playing", "cello")],
  [("man", "is rapidly lifting", "small weights")]
),

# The man is talking.
# A man is walking down stairs.
(
  [("man", "is talking", "")],
  [("man", "is walking down", "stairs")]
),

# A man tries to feed a mouse to a snake.
# A man is teasing a snake with a mouse.
(
  [("man", "tries to feed", "mouse"), 
   ("man", "tries to feed to", "snake")],
  [("man", "is teasing", "snake"),
   ("man", "is teasing with", "mouse")]
),

# A man is playing the drums.
# A woman is slicing some leaves.
(
  [("man", "is playing", "drums")],
  [("woman", "is slicing", "leaves")]
),

# A man is playing a ukulele.
# A man is sitting and playing a small guitar.
(
  [("man", "is playing", "ukulele")],
  [("man", "is sitting", ""),
   ("man", "is playing", "small guitar")]
),

# A kitten is drinking milk from a bowl.
# A small child is drinking water from a cup.
(
  [("kitten", "is drinking", "milk"), 
   ("kitten", "is drinking from", "bowl")],
  [("small child", "is drinking", "water"), 
   ("small child", "is drinking from", "cup")]
),

# A man breaks cinder blocks on another man.
# A woman breaks an egg into a pan.
(
  [("man", "breaks", "cinder blocks"), 
   ("cinder blocks", "are broken on", "another man")],
  [("woman", "breaks", "egg"), 
   ("egg", "is broken into", "pan")]
),

# A man is hitting a boy with flower vase.
# A man is cutting a mat.
(
  [("man", "is hitting", "boy"), 
   ("man", "is hitting with", "flower vase")],
  [("man", "is cutting", "mat")]
),

# The man is mixing whipping cream.
# The man is holding a skunk.
(
  [("man", "is mixing", "whipping cream")],
  [("man", "is holding", "skunk")]
),

# A man is stirring juice.
# A man is peeling an onion.
(
  [("man", "is stirring", "juice")],
  [("man", "is peeling", "onion")]
),

# Someone is slicing two uncooked racks of ribs apart.
# Someone is cutting a piece of meat.
(
  [("someone", "is slicing", "two uncooked racks"), 
   ("two uncooked rack", "are of", "ribs"),
   ("someone", "is slicing", "apart")],
  [("someone", "is cutting", "piece of meat")]
),

# A man is kicking pots of water.
# A man is turning foods.
(
  [("man", "is kicking", "pots"),
   ("pots", "are of", "water")],
  [("man", "is turning", "foods")]
),

# Two little girls talk on the telephone.
# Two couple are talking with each other.
(
  [("two girls", "are", "little"),
   ("two girls", "talk on", "telephone")],
  [("two couple", "are talking with", "each other")]
),

# A cat gets stuck on a moving ceiling fan.
# A cat is swinging on a fan.
(
  [("cat", "gets stuck on", "ceiling fan"),
   ("ceiling fan", "is", "moving")],
  [("cat", "is swinging on", "fan")]
),

# The cat is drinking milk.
# A white cat is licking and drinking milk kept on a plate.
(
  [("cat", "is drinking", "milk")],
  [("white cat", "is licking", "milk"),
   ("white cat", "is drinking", "milk"), 
   ("milk", "is kept on", "plate")]
),

# Rocky and Apollo Creed are running down the beach.
# The men are jogging on the beach.
(
  [("Rocky", "is running down", "beach"),
   ("Apollo Creed", "is running down", "beach")],
  [("men", "are jogging on", "beach")]
),

# A man is singing while playing the guitar.
# A man is stuffing himself full with food.
(
  [("man", "is singing", ""), 
   ("man", "is playing", "guitar")],
  [("man", "is stuffing", "himself"),
   ("man", "is stuffing full with", "food")]
),

# A boat sails along the water.
# The man is playing the guitar.
(
  [("boat", "sails along", "water")],
  [("man", "is playing", "guitar")]
),

# An okapi is eating from a tree.
# A moose drinks from a sprinkler.
(
  [("okapi", "is eating from", "tree")],
  [("moose", "drinks from", "sprinkler")]
),

# Several kids jump up and down on a trampoline.
# A man is doing back flips on a trampoline.
(
  [("several kids", "jump up on", "trampoline"),
   ("several kids", "jump down on", "trampoline")],
  [("man", "is doing", "back flips"), 
   ("back flips", "are done on", "trampoline")]
),

# A woman is pouring egg into a frying pan.
# A man is petting two dogs.
(
  [("woman", "is pouring", "egg"),
   ("woman", "is pouring into", "frying pan")],
  [("man", "is petting", "two dogs")]
),

# A woman is frying ground meat.
# A man is cutting a trunk with an axe.
(
  [("woman", "is frying", "ground meat")],
  [("man", "is cutting", "trunk"), 
   ("man", "is cutting with", "axe")]
),

# Three boys in karate costumes are fighting.
# Three men are practicing karate moves in a field.
(
  [("three boys", "are fighting", ""), 
   ("three boys", "are in", "karate costumes")],
  [("three men", "are practicing", "karate moves"), 
   ("three men", "are practicing in", "field")]
),

# Swimmers are racing in a lake.
# Women swimmers are diving in from the starting platform.
(
  [("swimmers", "are racing in", "lake")],
  [("women swimmers", "are diving in from", "starting platform")]
),

# A person is boiling noodles.
# A cat is licking a bottle.
(
  [("person", "is boiling", "noodles")],
  [("cat", "is licking", "bottle")]
),

# A person is slicing some onions.
# A woman is chopping herbs.
(
  [("person", "is slicing", "onions")],
  [("woman", "is chopping", "herbs")]
),

# A man reels in a fish.
# A woman is pouring oil in a bowl.
(
  [("man", "reels in", "fish")],
  [("woman", "is pouring", "oil"), 
   ("woman", "is pouring in", "bowl")]
),

# A woman is cutting an onion.
# A horse is standing.
(
  [("woman", "is cutting", "onion")],
  [("horse", "is standing", "")]
),

# A lady mixed up a meat mixture in bowl.
# A woman is stirring meat in a bowl.
(
  [("lady", "mixed up", "meat mixture"), 
   ("lady", "mixed up in", "bowl")],
  [("woman", "is stirring", "meat"), 
   ("woman", "is stirring in", "bowl")]
),

# A girl is applying makeup on her face.
# A woman is putting on makeup.
(
  [("girl", "is applying", "makeup"), 
   ("makeup", "is applied on", "face")],
  [("woman", "is putting on", "makeup")]
),

# A woman puts make-up on.
# A woman is putting on eyeshadow.
(
  [("woman", "puts on", "make-up")],
  [("woman", "is putting on", "eyeshadow")]
),

# A cat plays in his water.
# The cat fished a straw out ouf his water dish.
(
  [("cat", "plays in", "water")],
  [("cat", "fished", "straw"), 
   ("cat", "fished out of", "water dish")]    
),

# A person is adding food in a pan.
# A man is dancing in the street.
(
  [("person", "is adding", "food"), 
   ("person", "is adding in", "pan")],
  [("man", "is dancing in", "street")]
),

# A man is smoking.
# A baby is sucking on a pacifier.
(
  [("man", "is smoking", "")],
  [("baby", "is sucking on", "pacifier")]
),

# A person is putting shredded cheese in a pot.
# A hamster is eating some seeds.
(
  [("person", "is putting", "shredded cheese"), 
   ("person", "is putting in", "pot")],
  [("hamster", "is eating", "seeds")]
),

# A man is erasing a chalk board.
# A woman is dancing, and singing.
(
  [("man", "is erasing", "chalk board")],
  [("woman", "is dancing", ""), 
   ("woman", "is singing", "")]
),

# The man is exercising.
# A man is doing pull-ups.
(
  [("man", "is exercising", "")],
  [("man", "is doing", "pull-ups")]
),

# A chimp is kicking a target.
# A woman is putting oil into a skillet.
(
  [("chimp", "is kicking", "target")],
  [("woman", "is putting", "oil"), 
   ("woman", "is putting into", "skillet")]
),

# A man is doing exercise.
# A baby is laughing.
(
  [("man", "is doing", "exercise")],
  [("baby", "is laughing", "")]
),

# The girl is carrying a baby.
# A man is eating a food.
(
  [("girl", "is carrying", "baby")],
  [("man", "is eating", "food")]
),

# Several swimmers jump into the water.
# Swimmers are racing in a lake.
(
  [("swimmers", "are", "several"),
   ("swimmers", "jump into", "water")],
  [("swimmers", "are racing in", "lake")]
),

# A man spins on a surf board.
# A man is putting barbecue sauce on chicken.
(
  [("man", "spins on", "surf board")],
  [("man", "is putting", "barbecue sauce"), 
   ("man", "is putting on", "chicken")]
),

# A young man is riding a skateboard and jumps onto a sidewalk then off at another curb.
# A man is riding a skateboard.
(
  [("man", "is", "young"),
   ("man", "is riding", "skateboard"), 
   ("man", "jumps onto", "sidewalk"), 
   ("man", "jumps off", "another curb")],
  [("man", "is riding", "skateboard")]
),

# A person dices up an orange pepper.
# The cook is slicing bell peppers.
(
  [("person", "dices up", "orange pepper")],
  [("cook", "is slicing", "bell peppers")]
),

# Two men are dancing together.
# A woman opens a closet.
(
  [("two men", "are dancing", "together")],
  [("woman", "opens", "closet")]
),

# A man is reading an email.
# A person opening a banana.
(
  [("man", "is reading", "email")],
  [("person", "opening", "banana")]
),


]

print('MSR vid samples: ', len(msrvid_samples_ds))
# Out:
# MSR vid samples:  250
